# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# # PART- 1 Data Cleaning

# %% [markdown]
# ### Importing Libraries

# %%
# import lineer algebra and data analysis library
import numpy as np
import pandas as pd

# import visualisation library
import matplotlib.pyplot as plt
from matplotlib import patches
import seaborn as sns

# import warning library to suppress warnings
import warnings

# %% [markdown]
# ### Settings

# %%
# Suppressing a warning 
warnings.filterwarnings("ignore") 

# It is a magic function that renders the figure in the notebook
# %matplotlib inline 

# Changing the figure size of a seaborn axes 
sns.set(rc={"figure.figsize": (10, 6)})

# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid")

# To display maximum columns
pd.set_option('display.max_columns', None)

# To display maximum rows
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Reading scout_car.json file as a dataframe named df

# %%
df = pd.read_json("scout_car/scout_car.json", lines=True)

# %% [markdown]
# ### Creating a copy from df named df_copy

# %%
df_copy = df.copy()

# %% [markdown]
# ## Checking the dataframe with head, tail and sample

# %%
# Checking the head of df

df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# ...

# %%
# Checking the tail of df

df.tail()
# Out:
#                                                      url      make_model  \
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                   vat        km registration        prev_owner  kW      hp  \
# ...

# %%
# Checking the df by taking samples

df.sample(10)
# Out:
#                                                      url     make_model  \
# 3307   https://www.autoscout24.com//offers/audi-a3-sp...        Audi A3
# 4282   https://www.autoscout24.com//offers/audi-a3-sp...        Audi A3
# 10796  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 12882  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 6051   https://www.autoscout24.com//offers/opel-astra...     Opel Astra
# 4947   https://www.autoscout24.com//offers/audi-a3-li...        Audi A3
# 9471   https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
# 9582   https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
# 2079   https://www.autoscout24.com//offers/audi-a1-sp...        Audi A1
# 8528   https://www.autoscout24.com//offers/opel-corsa...     Opel Corsa
#
#                                        short_description      body_type  \
# 3307                          SPB 1.6 TDI S tronic Sport         Sedans
# ...

# %% [markdown]
# ## Checking the summary information of df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %% [markdown]
# ## Checking the null values of df

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# ...

# %% [markdown]
# ## Checking the duplicated values in df

# %%
# df.duplicated()

# As there is list type values in the columns, duplicated method didn't work.
# After fixing the list type values, duplicated values will be check.

# %% [markdown]
# ## Cleaning column names

# %% [markdown]
# Column names was cleaned using skimpy library clean_columns method.

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
# Importing skimpy clean_columns method

from skimpy import clean_columns

# %%
# Cleaning column names using skimpy clean_columns method

df= clean_columns(df)
# Out:
# 42 column names have been cleaned

# %% [markdown]
# ## Checking the number of unique values in df

# %%
# df.nunique()  # As some columns values are in the form of list, this code raised with "TypeError: unhashable type: 'list'" error.

# %% [markdown]
# While checking the unique values in df, it has been determined that the data in some columns are in the form of a list. For this reason, it was decided to convert the data of the columns containing the list into strings, before applying the string methods in order to clean data.

# %% [markdown]
# ## Changing data types of columns containing list type values to string

# %%
# Changing data types of columns containing list type values to string

df = df.applymap(lambda x: ','.join(map(str, x)) if isinstance(x, list) else x)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %% [markdown]
# ## Checking duplicated values after fixing data types

# %%
# Checking duplicated values in df after fixing list type values

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking the nuniques in columns

# %%
df.nunique()
# Out:
# url                              15919
# make_model                           9
# short_description                10001
# body_type                            9
# price                             2956
# vat                                  2
# km                                6690
# registration                        48
# prev_owner                           4
# k_w                                  0
# hp                                  81
# type                               169
# previous_owners                    101
# next_inspection                   1384
# inspection_new                     201
# warranty                           507
# full_service                       122
# non_smoking_vehicle                 94
# null                                 1
# make                                 3
# model                                9
# offer_number                     11440
# first_registration                   4
# body_color                          14
# ...

# %% [markdown]
# ## Defining a function to check null values, number of uniques and value counts for each column

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Percent_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Number_of_Nulls   : ', df[col].isnull().sum())
    print('Number_of_Uniques : ', df[col].nunique())
    print("Value_counts :\n",df[col].value_counts(dropna = False))
    print()
    print("Value_counts with sort index :\n",df[col].value_counts(dropna = False).sort_index())
    print("##"*20)
    print()

# %%
# Checking the informations for each column using defined function first_look

for col in df.columns :
    first_look(col)
# Out:
# column name :  url
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  15919
# Value_counts :
#  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
# ...

# %% [markdown]
# ## First cleaning of df

# %% [markdown]
# There are so many strange values that should be cleaned.
#
# Firstly, "\n" character will be cleaned.

# %%
# Cleaning "\n" character and strip "," character from both side in df columns

df= df.apply(lambda x: x.str.replace("\n","").str.strip(",") if x.dtype == "O" else x)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %% [markdown]
# ### Checking columns with first_look function after first cleaning of df

# %%
# Checking the informations for each column using defined function first_look

for col in df.columns :
    first_look(col)
# Out:
# column name :  url
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  15919
# Value_counts :
#  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
# ...

# %% [markdown]
# ## Checking the descriptive values of df

# %% [markdown]
# ### Checking the descriptive values of object columns

# %%
df.describe(include='O').T
# Out:
#                                count unique  \
# url                            15919  15919
# make_model                     15919      9
# short_description              15873  10001
# body_type                      15859      9
# vat                            11406      2
# km                             15919   6690
# registration                   15919     48
# prev_owner                      9091      4
# hp                             15919     81
# type                           15917    169
# previous_owners                 9279    101
# next_inspection                 3535   1384
# inspection_new                  3932    201
# warranty                       10499    506
# full_service                    8215    121
# non_smoking_vehicle             7177     93
# null                           15919      1
# make                           15919      3
# model                          15919      9
# offer_number                   12744  11440
# ...

# %% [markdown]
# ### Checking the descriptive values of numeric columns

# %%
df.describe(exclude="O").T
# Out:
#          count          mean          std   min      25%      50%      75%  \
# price  15919.0  18019.896727  7386.169409  13.0  12850.0  16900.0  21900.0
# k_w        0.0           NaN          NaN   NaN      NaN      NaN      NaN
#
#            max
# price  74600.0
# k_w        NaN

# %% [markdown]
# ## First conclusion about df after checking the first_look results and descriptive values of each column

# %% [markdown]
# After checking the first_look results and descriptive values of each column, it was decided
#
#    * to replace empty rows with np.nan
#
#    * to replace "[],[],[]" values with np.nan
#
#    * to drop columns containing greater than or equal %95 null values
#
#    * to apply data cleaning column by column.

# %% [markdown]
# ### Replacing empty rows with np.nan

# %%
# Checking columns having empty rows

df.isin(['']).sum()
# Out:
# url                                  0
# make_model                           0
# short_description                    0
# body_type                            0
# price                                0
# vat                                  0
# km                                   0
# registration                         0
# prev_owner                           0
# k_w                                  0
# hp                                   0
# type                                 0
# previous_owners                      0
# next_inspection                      0
# inspection_new                       0
# warranty                          1343
# full_service                      1985
# non_smoking_vehicle               3717
# null                             15919
# make                                 0
# model                                0
# offer_number                         0
# first_registration                   0
# body_color                           0
# ...

# %%
# replacing empty rows with np.nan (1st method)

df[df.isin([''])] = np.nan

# %%
# 2nd method to replace empty rows with np.nan

df.replace(to_replace=r'^\s*$', value=np.nan, regex=True).isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# k_w                              15919
# hp                                   0
# type                                 2
# previous_owners                   6640
# next_inspection                  12384
# inspection_new                   11987
# warranty                          6763
# full_service                      9689
# non_smoking_vehicle              12459
# null                             15919
# make                                 0
# model                                0
# offer_number                      3175
# first_registration                1597
# body_color                         597
# ...

# %% [markdown]
# ### Replacing rows containing only empt list with np.nan

# %%
# Checking the columns having "[],[],[]" values

df.isin(['[],[],[]']).sum()
# Out:
# url                                0
# make_model                         0
# short_description                  0
# body_type                          0
# price                              0
# vat                                0
# km                                 0
# registration                       0
# prev_owner                         0
# k_w                                0
# hp                                 0
# type                               0
# previous_owners                    0
# next_inspection                    0
# inspection_new                     0
# warranty                           0
# full_service                       0
# non_smoking_vehicle                0
# null                               0
# make                               0
# model                              0
# offer_number                       0
# first_registration                 0
# body_color                         0
# paint_type                         0
# ...

# %%
# replacing rows containing "[],[],[]" with np.nan (1st method)

df[df.isin(['[],[],[]'])] = np.nan

# %%
# 2nd method to replace "[],[],[]" values with np.nan

df.replace(to_replace=r'\[\]', value=np.nan, regex=True)
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %% [markdown]
# ### Drop columns containing greater than or equal %95 null values

# %% [markdown]
# As mentioned above, it was decided to drop columns having greater than or equal %95 null values.

# %%
# Checking columns having greater than or equal %95 null values

print(df.shape)
for col in df.columns :
    if (df[col].isnull().sum() / df.shape[0]*100 ) >= 95:
        print("Column_Name :", col)
        print('Percent_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
        print("-"*25)
# Out:
# (15919, 54)
# Column_Name : k_w
# Percent_of_Nulls   :  % 100.0
# -------------------------
# Column_Name : null
# Percent_of_Nulls   :  % 100.0
# -------------------------
# Column_Name : electricity_consumption
# Percent_of_Nulls   :  % 99.14
# -------------------------
# Column_Name : last_service_date
# Percent_of_Nulls   :  % 96.44
# -------------------------
# Column_Name : other_fuel_types
# Percent_of_Nulls   :  % 100.0
# -------------------------
# Column_Name : availability
# Percent_of_Nulls   :  % 96.01
# -------------------------
# Column_Name : last_timing_belt_service_date
# Percent_of_Nulls   :  % 99.9
# -------------------------
# Column_Name : available_from
# Percent_of_Nulls   :  % 98.29
# -------------------------

# %%
# dropping columns having greater than or equal %95 null values

for col in df.columns :
    if (df[col].isnull().sum() / df.shape[0]*100 ) >= 95:
        df.drop(col, axis=1, inplace=True)

# %%
# checking the shape of df

print(df.shape)
# Out:
# (15919, 46)

# %% [markdown]
# ## Data cleaning column by column  and fixing data types

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'hp', 'type', 'previous_owners',
#        'next_inspection', 'inspection_new', 'warranty', 'full_service',
#        'non_smoking_vehicle', 'make', 'model', 'offer_number',
#        'first_registration', 'body_color', 'paint_type', 'body_color_original',
#        'upholstery', 'body', 'nr_of_doors', 'nr_of_seats', 'model_code',
#        'gearing_type', 'displacement', 'cylinders', 'weight', 'drive_chain',
#        'fuel', 'consumption', 'co_2_emission', 'emission_class',
#        'comfort_&_convenience', 'entertainment_&_media', 'extras',
#        'safety_&_security', 'description', 'emission_label', 'gears',
#        'country_version'],
#       dtype='object')

# %% [markdown]
# ### url column

# %%
first_look("url")
# Out:
# column name :  url
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  15919
# Value_counts :
#  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
# ...

# %%
# "url" column can be used to fill null values in other columns.
# For this reason it will be dropped after investigating other columns.

# %% [markdown]
# ### make_model, make and model columns

# %%
# Checking the make_model column

first_look("make_model")
# Out:
# column name :  make_model
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  9
# Value_counts :
#  Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
#
# Value_counts with sort index :
#  Audi A1           2614
# Audi A2              1
# Audi A3           3097
# Opel Astra        2526
# Opel Corsa        2219
# Opel Insignia     2598
# Renault Clio      1839
# Renault Duster      34
# Renault Espace     991
# Name: make_model, dtype: int64
# ########################################

# %%
# checking the "make_model","make","model" columns together

df[["make_model","make","model"]].sample(20)
# Out:
#           make_model     make     model
# 1852         Audi A1     Audi        A1
# 11651  Opel Insignia     Opel  Insignia
# 10279     Opel Corsa     Opel     Corsa
# 11985  Opel Insignia     Opel  Insignia
# 6970      Opel Astra     Opel     Astra
# 13462   Renault Clio  Renault      Clio
# 7205      Opel Astra     Opel     Astra
# 12472  Opel Insignia     Opel  Insignia
# 970          Audi A1     Audi        A1
# 7689      Opel Astra     Opel     Astra
# 10033     Opel Corsa     Opel     Corsa
# 12580  Opel Insignia     Opel  Insignia
# 3857         Audi A3     Audi        A3
# 2997         Audi A3     Audi        A3
# 5489         Audi A3     Audi        A3
# 4508         Audi A3     Audi        A3
# 3963         Audi A3     Audi        A3
# 9830      Opel Corsa     Opel     Corsa
# 3341         Audi A3     Audi        A3
# 11951  Opel Insignia     Opel  Insignia

# %%
# checking null values of "make_model","make" and "model" columns

df[["make_model","make","model"]].isna().sum()
# Out:
# make_model    0
# make          0
# model         0
# dtype: int64

# %%
# checking the value_counts of "make_model","make" and "model" columns

df[["make_model","make","model"]].value_counts()
# Out:
# make_model      make     model
# Audi A3         Audi     A3          3097
# Audi A1         Audi     A1          2614
# Opel Insignia   Opel     Insignia    2598
# Opel Astra      Opel     Astra       2526
# Opel Corsa      Opel     Corsa       2219
# Renault Clio    Renault  Clio        1839
# Renault Espace  Renault  Espace       991
# Renault Duster  Renault  Duster        34
# Audi A2         Audi     A2             1
# dtype: int64

# %% [markdown]
# As it is seen from the results above "make_model","make" and "model" columns have same values. So it was decided to drop "make" and "model" columns.

# %%
# dropping "make" and "model" columns

df.drop(columns=["make", "model"], inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### short_description column

# %%
# Checking the short_description column

first_look("short_description")
# Out:
# column name :  short_description
# --------------------------------
# Percent_of_Nulls   :  % 0.29
# Number_of_Nulls   :  46
# Number_of_Uniques :  10001
# Value_counts :
#  SPB 1.6 TDI 116 CV S tronic Sport                 64
# NaN                                               46
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 10002, dtype: int64
#
# Value_counts with sort index :
#   1,6 CDTI**NAVI*Klimaaut*Tempomat*EURO6*TÜV NEU     1
#  1.4 75 cv5 porte b-color                           1
# ...

# %%
# "url" column can be used to fill null values in other columns.
# For this reason it will be dropped after investigating other columns.

# %% [markdown]
# ### body_type and body columns

# %%
# Checking the body_type and body columns

first_look("body_type")
# Out:
# column name :  body_type
# --------------------------------
# Percent_of_Nulls   :  % 0.38
# Number_of_Nulls   :  60
# Number_of_Uniques :  9
# Value_counts :
#  Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
#
# Value_counts with sort index :
#  Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body_type, dtype: int64
# ########################################

# %%
# Checking the body_type column

first_look("body")
# Out:
# column name :  body
# --------------------------------
# Percent_of_Nulls   :  % 0.38
# Number_of_Nulls   :  60
# Number_of_Uniques :  9
# Value_counts :
#  Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body, dtype: int64
#
# Value_counts with sort index :
#  Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body, dtype: int64
# ########################################

# %%
# Checking the value_counts of body_type and body columns together

df[["body_type","body"]].value_counts(dropna=False)
# Out:
# body_type      body
# Sedans         Sedans           7903
# Station wagon  Station wagon    3553
# Compact        Compact          3153
# Van            Van               783
# Other          Other             290
# Transporter    Transporter        88
# NaN            NaN                60
# Off-Road       Off-Road           56
# Coupe          Coupe              25
# Convertible    Convertible         8
# dtype: int64

# %% [markdown]
# As it is seen from the results above "body_type" and "body" columns contains same values. So it was decided to drop "body" column. Also, there are 60 null values in body_type column.

# %%
# drop body column

df.drop(columns="body", inplace=True)

# %%
df.shape
# Out:
# (15919, 43)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### price column

# %%
# Checking the price column

first_look("price")
# Out:
# column name :  price
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  2956
# Value_counts :
#  14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64
#
# Value_counts with sort index :
#  13       1
# 120      1
# 255      1
# 331      1
# 4950     1
#         ..
# 64332    1
# 64900    1
# 67600    1
# 68320    1
# 74600    1
# Name: price, Length: 2956, dtype: int64
# ########################################

# %% [markdown]
# price column is already clean and there isn't any null values.

# %%
# Checking the data type of price column

df.price.dtypes
# Out:
# dtype('int64')

# %%
# fixing data type

df["price"] = df.price.astype(float)

# %% [markdown]
# ### vat column

# %%
df.vat
# Out:
# 0          VAT deductible
# 1        Price negotiable
# 2          VAT deductible
# 3                    None
# 4                    None
#                ...
# 15914      VAT deductible
# 15915      VAT deductible
# 15916      VAT deductible
# 15917      VAT deductible
# 15918      VAT deductible
# Name: vat, Length: 15919, dtype: object

# %%
# Checking the vat column

first_look("vat")
# Out:
# column name :  vat
# --------------------------------
# Percent_of_Nulls   :  % 28.35
# Number_of_Nulls   :  4513
# Number_of_Uniques :  2
# Value_counts :
#  VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
#
# Value_counts with sort index :
#  Price negotiable      426
# VAT deductible      10980
# NaN                  4513
# Name: vat, dtype: int64
# ########################################

# %% [markdown]
# vat column is already clean. There are 4513 null values.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### km column

# %%
# checking the km column

first_look("km")
# Out:
# column name :  km
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  6690
# Value_counts :
#  10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
#
# Value_counts with sort index :
#  - km         1024
# 0 km           19
# 1 km          367
# 1,000 km       46
# 1,001 km        4
#              ...
# 99,999 km       1
# 990 km          2
# 991 km          1
# 995 km          1
# 999 km          3
# Name: km, Length: 6690, dtype: int64
# ########################################

# %% [markdown]
# There are "km" and "," characters that should be cleaned in km column.

# %%
# Cleaning "km" and "," characters in km column and fixing data type : 1st method

df["km"] = df.km.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
# Cleaning "km" and "," characters in km column and fixing data type : 2nd method

# df["km"] = df.km.str.strip(" km").str.replace(",", "").replace(r"-", np.nan, regex=True).astype(float)

# %%
# Checking the km columns' values after cleaning

first_look("km")
# Out:
# column name :  km
# --------------------------------
# Percent_of_Nulls   :  % 6.43
# Number_of_Nulls   :  1024
# Number_of_Uniques :  6689
# Value_counts :
#  10.0       1045
# NaN        1024
# 1.0         367
# 5.0         170
# 50.0        148
#            ...
# 67469.0       1
# 43197.0       1
# 10027.0       1
# 35882.0       1
# 57.0          1
# Name: km, Length: 6690, dtype: int64
#
# Value_counts with sort index :
#  0.0           19
# 1.0          367
# 2.0            6
# 3.0           33
# 4.0           15
#             ...
# 248000.0       1
# 260000.0       1
# 291800.0       1
# 317000.0       1
# NaN         1024
# Name: km, Length: 6690, dtype: int64
# ########################################

# %% [markdown]
# As it is seen from results given above, there are 1024 null values in km column.

# %% [markdown]
# ### registration and first_registration columns

# %%
# Checking the registration column

first_look("registration")
# Out:
# column name :  registration
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  48
# Value_counts :
#  -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# ...

# %%
# Checking the registration and first_registration columns together

df[["registration","first_registration"]].value_counts(dropna=False)
# Out:
# registration  first_registration
# -/-           NaN                   1597
# 03/2018       2018                   695
# 02/2019       2019                   585
# 05/2018       2018                   572
# 03/2019       2019                   543
# 01/2019       2019                   541
# 04/2018       2018                   541
# 02/2018       2018                   539
# 03/2016       2016                   536
# 06/2018       2018                   532
# 04/2016       2016                   532
# 01/2018       2018                   511
# 04/2019       2019                   506
# 02/2016       2016                   472
# 03/2017       2017                   471
# 05/2016       2016                   459
# 06/2016       2016                   452
# 05/2019       2019                   440
# 06/2017       2017                   409
# 05/2017       2017                   404
# 07/2018       2018                   396
# 04/2017       2017                   380
# ...

# %% [markdown]
# As it is seen from the results above "registration" and "first_registration" columns have similar values. So it was decided to drop "registration" column.

# %%
# drop registration column

df.drop(columns="registration", inplace=True)

# %%
df.shape
# Out:
# (15919, 42)

# %%
# fixing data type

df["first_registration"] = df.first_registration.astype(float)

# %% [markdown]
# A new column in the name of age can be created using first_registration column values. After that first_registration column can be  dropped.
#
# There are 1597 null values in first_registration column.

# %%
# Null values will be worked and age column will be created in next notebook.

# %% [markdown]
# ### prev_owner and previous_owners columns

# %%
# Checking the prev_owner column

first_look("prev_owner")
# Out:
# column name :  prev_owner
# --------------------------------
# Percent_of_Nulls   :  % 42.89
# Number_of_Nulls   :  6828
# Number_of_Uniques :  4
# Value_counts :
#  1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
#
# Value_counts with sort index :
#  1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6828
# Name: prev_owner, dtype: int64
# ########################################

# %%
# Checking previous_owners column

first_look("previous_owners")
# Out:
# column name :  previous_owners
# --------------------------------
# Percent_of_Nulls   :  % 41.71
# Number_of_Nulls   :  6640
# Number_of_Uniques :  101
# Value_counts :
#  1                                                                      8103
# NaN                                                                    6640
# 2                                                                       766
# 0                                                                       163
# 3                                                                        17
#                                                                        ...
# 1,111 g CO2/km (comb)                                                     1
# 1,Euro 6                                                                  1
# 2,119 g CO2/km (comb)                                                     1
# 1,,6.6 l/100 km (comb),,8.1 l/100 km (city),,5.7 l/100 km (country)       1
# ...

# %%
# previous_owners column can be used to fill missing values at other columns such as prew_owner, consumption, ..
# So it will be decided to drop this column after checking other columns.

# %%
# extracting number of owners from prev_owner column

df["prev_owner"] = df.prev_owner.str.extract("(\d)").astype(float)

# %%
# Checking null values in prev_owner and previous_owners columns

df[["prev_owner","previous_owners"]].isnull().sum()
# Out:
# prev_owner         6828
# previous_owners    6640
# dtype: int64

# %% [markdown]
# There are 6828 and 6640 null values in prev_owner and prev_owner columns respectively.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### hp column

# %%
# Checking the hp column

first_look("hp")
# Out:
# column name :  hp
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  81
# Value_counts :
#  85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 78 kW       20
# 1 kW        20
# 294 kW      18
# 146 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# ...

# %%
# Extracting hp values from hp column and assign them to hp_kw column and fixing data type

df["hp_kw"]= df.hp.str.extract(r"(\d+)").astype(float)

# %%
# Dropping hp column

df.drop(columns="hp",inplace=True)

# %%
df.shape
# Out:
# (15919, 42)

# %%
# Checking null values in hp_kw column after cleaning

df.hp_kw.isnull().sum()
# Out:
# 88

# %% [markdown]
# There are 88 null values in hp_kw column.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### type column

# %%
# Checking the type column

first_look("type")
# Out:
# column name :  type
# --------------------------------
# Percent_of_Nulls   :  % 0.01
# Number_of_Nulls   :  2
# Number_of_Uniques :  169
# Value_counts :
#  Used,,Diesel (Particulate Filter)                                                                                 3475
# Used,,Diesel                                                                                                      2516
# Used,,Gasoline                                                                                                    2367
# Used,,Super 95                                                                                                    1818
# Pre-registered,,Super 95                                                                                           500
#                                                                                                                   ...
# ...

# %%
# Checking type and fuel column together

df[["type","fuel"]].head(50)
# Out:
#                                            type                         fuel
# 0             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 1                                Used,,Gasoline                     Gasoline
# 2             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 3             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 4             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 5             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 6             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 7             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 8             Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# 9                                Used,,Gasoline                     Gasoline
# 10            Used,,Diesel (Particulate Filter)  Diesel (Particulate Filter)
# ...

# %%
# Extracting necessary values from type column : 1st method

df["type"] = df.type.str.extract(r"(.+),,")
df.type.value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: type, dtype: int64

# %%
# Extracting necessary values from type column : 2nd method

# df.type.str.split(",").str[1].value_counts()

# %%
# Checking null values after cleaning

df.type.isnull().sum()
# Out:
# 2

# %% [markdown]
# There are only 2 null values in type column.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### next_inspection column

# %%
# Checking the next_inspection column

first_look("next_inspection")
# Out:
# column name :  next_inspection
# --------------------------------
# Percent_of_Nulls   :  % 77.79
# Number_of_Nulls   :  12384
# Number_of_Uniques :  1384
# Value_counts :
#  NaN                            12384
# 04/2022                           62
# 06/2021                           47
# 03/2021                           39
# 03/2022                           36
#                                ...
# 06/2021,121 g CO2/km (comb)        1
# 02/2020,139 g CO2/km (comb)        1
# 10/2021,136 g CO2/km (comb)        1
# 06/2019,139 g CO2/km (comb)        1
# 01/2022,168 g CO2/km (comb)        1
# Name: next_inspection, Length: 1385, dtype: int64
#
# Value_counts with sort index :
#  01/1921,120 g CO2/km (comb)        1
# 01/1955                            1
# 01/1999                            1
# 01/2001,120 g CO2/km (comb)        1
# 01/2001,122 g CO2/km (comb)        2
#                                ...
# 12/2021,153 g CO2/km (comb)        4
# 12/2021,167 g CO2/km (comb)        1
# ...

# %%
# Checking next_inspection and inspection_new columns together

df[["next_inspection","inspection_new"]].head(50)
# Out:
#                 next_inspection           inspection_new
# 0    06/2021,99 g CO2/km (comb)               Yes,Euro 6
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN  Yes,109 g CO2/km (comb)
# 5                           NaN                      NaN
# 6                           NaN   Yes,98 g CO2/km (comb)
# 7                           NaN   Yes,97 g CO2/km (comb)
# 8    02/2020,97 g CO2/km (comb)                      NaN
# 9                           NaN                      NaN
# 10                          NaN                      NaN
# 11                          NaN  Yes,112 g CO2/km (comb)
# 12  09/2019,112 g CO2/km (comb)                      NaN
# 13                          NaN                      NaN
# 14   10/2019,99 g CO2/km (comb)                      NaN
# ...

# %% [markdown]
# There isn't any similarities between next_inspection and inspection_new columns. So these columns will be examined seperately.

# %%
# Extracting date information from next_inspection columns and assign them to a new column named next_insp_date

df["next_insp_date"] = df.next_inspection.str.extract(r"(\d+/\d{0,4})")

# %%
df["next_insp_date"].isnull().sum()
# Out:
# 12384

# %% [markdown]
# There are 12384 null values.
#
# next_inspection column can be used to fill missing values in other columns. So it will drop later.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### inspection_new column

# %%
# Checking the inspection_new column

first_look("inspection_new")
# Out:
# column name :  inspection_new
# --------------------------------
# Percent_of_Nulls   :  % 75.3
# Number_of_Nulls   :  11987
# Number_of_Uniques :  201
# Value_counts :
#  NaN                                                                      11987
# Yes,Euro 6                                                                 523
# Yes                                                                        442
# Yes,102 g CO2/km (comb)                                                    174
# Yes,4 (Green)                                                              166
#                                                                          ...
# Yes,,5.2 l/100 km (comb),,6.7 l/100 km (city),,4.2 l/100 km (country)        1
# Yes,100 g CO2/km (comb)                                                      1
# Yes,,4.9 l/100 km (comb),,5.9 l/100 km (city),,4.3 l/100 km (country)        1
# Yes,,5.1 l/100 km (comb),,6.4 l/100 km (city),,4.3 l/100 km (country)        1
# ...

# %%
# Extracting necessary information from inspection_new column and assign them into a new column
# named insp_new

df["insp_new"] = df.inspection_new.str.extract(r"(Yes)")

# %%
df["insp_new"].isnull().sum()
# Out:
# 11987

# %% [markdown]
# There are 11987 null values.
#
# inspection_new column can be used to fill missing values in other columns. So it will drop later.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### warranty column

# %%
# Checking the warranty column

first_look("warranty")
# Out:
# column name :  warranty
# --------------------------------
# Percent_of_Nulls   :  % 42.48
# Number_of_Nulls   :  6763
# Number_of_Uniques :  505
# Value_counts :
#  NaN                                                                          6763
# Euro 6                                                                       1868
# 12 months                                                                    1305
# 24 months                                                                     585
# 4 (Green)                                                                     517
#                                                                              ...
# 2 months                                                                        1
# 72 months,125 g CO2/km (comb)                                                   1
# 60 months,14 g CO2/km (comb)                                                    1
# ...

# %%
# Extracting necessary values from warranty column and assign them into a new column named warranty_month
# fixing data type

df["warranty_month"] = df.warranty.str.extract(r"(\d+)\s*month").astype(float)

# %%
df["warranty_month"].isnull().sum()
# Out:
# 11066

# %% [markdown]
# warranty column can be used to fill other columns. Then can be dropped.
#
# There are 11066 null values.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### full_service column

# %%
# Checking the full_service column

first_look("full_service")
# Out:
# column name :  full_service
# --------------------------------
# Percent_of_Nulls   :  % 60.86
# Number_of_Nulls   :  9689
# Number_of_Uniques :  120
# Value_counts :
#  NaN                                                                 9689
# 4 (Green)                                                           2235
# Euro 6                                                              2097
# Euro 6d-TEMP                                                         399
# 120 g CO2/km (comb)                                                  105
#                                                                     ...
# 6 l/100 km (comb),,8 l/100 km (city),,4.9 l/100 km (country)           1
# 84 g CO2/km (comb)                                                     1
# 87 g CO2/km (comb)                                                     1
# 5.7 l/100 km (comb),,7.3 l/100 km (city),,4.9 l/100 km (country)       1
# Euro 4                                                                 1
# ...

# %%
# full_service column can be used to fill other columns' missing values. So it will drop later.

# %%
df[df.full_service.notna()][["full_service","co_2_emission","emission_class", "emission_label"]].sample(50)
# Out:
#               full_service        co_2_emission emission_class  emission_label
# 4791             4 (Green)  114 g CO2/km (comb)         Euro 6             NaN
# 3556             4 (Green)  106 g CO2/km (comb)         Euro 6             NaN
# 13123            4 (Green)  126 g CO2/km (comb)         Euro 6             NaN
# 1849             4 (Green)   97 g CO2/km (comb)         Euro 6             NaN
# 10065            4 (Green)  143 g CO2/km (comb)   Euro 6d-TEMP             NaN
# 11411               Euro 6  150 g CO2/km (comb)         Euro 6             NaN
# 11424            4 (Green)  134 g CO2/km (comb)         Euro 6             NaN
# 7685   154 g CO2/km (comb)  154 g CO2/km (comb)   Euro 6d-TEMP       4 (Green)
# 4307   106 g CO2/km (comb)  106 g CO2/km (comb)         Euro 6             NaN
# 10101            4 (Green)  140 g CO2/km (comb)         Euro 6             NaN
# 1712                Euro 6   89 g CO2/km (comb)         Euro 6             NaN
# ...

# %% [markdown]
# ### non_smoking_vehicle column

# %%
# Checking the non_smoking_vehicle column

first_look("non_smoking_vehicle")
# Out:
# column name :  non_smoking_vehicle
# --------------------------------
# Percent_of_Nulls   :  % 78.26
# Number_of_Nulls   :  12459
# Number_of_Uniques :  92
# Value_counts :
#  NaN                                                                 12459
# 4 (Green)                                                            1240
# Euro 6                                                               1127
# Euro 6d-TEMP                                                          345
# 120 g CO2/km (comb)                                                    63
# 85 g CO2/km (comb)                                                     46
# 107 g CO2/km (comb)                                                    36
# 104 g CO2/km (comb)                                                    36
# 153 g CO2/km (comb)                                                    31
# 124 g CO2/km (comb)                                                    29
# ...

# %% [markdown]
# Diğer kolonların doldurulmasında kullanılabilir. Sonrasında düşülecek.

# %% [markdown]
# ### offer_number column

# %%
# Checking the offer_number column

first_look("offer_number")
# Out:
# column name :  offer_number
# --------------------------------
# Percent_of_Nulls   :  % 19.94
# Number_of_Nulls   :  3175
# Number_of_Uniques :  11440
# Value_counts :
#  NaN                                         3175
# LT67679                                       27
# UN89904                                       27
# XJ38068                                       27
# JV03654                                       27
#                                             ...
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b       1
# 6701576                                        1
# 6701569                                        1
# 158121                                         1
# Re_30000008029                                 1
# Name: offer_number, Length: 11441, dtype: int64
#
# Value_counts with sort index :
#  # 250678          1
# # 8H6050830       1
# # G1024529        1
# # G6050580        1
# #8023778          2
#                ...
# x_45689v          2
# y8fx64x           1
# ...

# %%
df.offer_number.sample(50)
# Out:
# 6214                   6307JNR
# 13262         re77c1-ET-772-QG
# 5602                     56901
# 6246                     G-214
# 11097                      NaN
# 727                     020533
# 6558                   LT67679
# 2002                    63175X
# 10166                    11153
# 10210                   362173
# 1237                   TP62881
# 4502                   A122641
# 4938                    099338
# 10012                  4144104
# 1108                   U_18034
# 12651                    22735
# 15813                  2223117
# 2126                   4980985
# 5018                     26607
# 3738                       NaN
# 15112                 rv335533
# 11504                      NaN
# 3477                       NaN
# 9502                       NaN
# 7231                   AS1598C
# 13072                GW-STR094
# 10357                   420283
# 10714                   XN567K
# 4085                   4712247
# 6948                       853
# ...

# %%
# As offer_number column doesn't have any usefull/related data with car price,
# it was decided to drop this column.

df.drop(columns="offer_number",inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### body_color

# %%
# Checking the body_color column

first_look("body_color")
# Out:
# column name :  body_color
# --------------------------------
# Percent_of_Nulls   :  % 3.75
# Number_of_Nulls   :  597
# Number_of_Uniques :  14
# Value_counts :
#  Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
#
# Value_counts with sort index :
#  Beige      108
# Black     3745
# Blue      1431
# Bronze       6
# Brown      289
# Gold         2
# Green      154
# Grey      3505
# Orange       3
# Red        957
# Silver    1647
# Violet      18
# White     3406
# Yellow      51
# NaN        597
# Name: body_color, dtype: int64
# ########################################

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### paint_type column

# %%
# Checking the paint_type column

first_look("paint_type")
# Out:
# column name :  paint_type
# --------------------------------
# Percent_of_Nulls   :  % 36.26
# Number_of_Nulls   :  5772
# Number_of_Uniques :  3
# Value_counts :
#  Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64
#
# Value_counts with sort index :
#  Metallic       9794
# Perl effect       6
# Uni/basic       347
# NaN            5772
# Name: paint_type, dtype: int64
# ########################################

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### body_color_original column

# %%
# Checking the body_color_original column

first_look("body_color_original")
# Out:
# column name :  body_color_original
# --------------------------------
# Percent_of_Nulls   :  % 23.61
# Number_of_Nulls   :  3759
# Number_of_Uniques :  1927
# Value_counts :
#  NaN                              3759
# Onyx Schwarz                      338
# Bianco                            282
# Mythosschwarz Metallic            238
# Brillantschwarz                   216
#                                  ...
# Rouge-Braun (G0Y)                   1
# VARI COLRI DISPONIBILI              1
# Kokosnussbraun Metallic             1
# Farbe frei wählbar                  1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1928, dtype: int64
#
# Value_counts with sort index :
#  "PLATIN"                          1
# "satinsilber "                    1
# (0C0C) Monsungrau Metallic        1
# (B4B4) Cortinaweiss               1
# (NNP)                             1
#                                ...
# wählbar - ggf. mit Aufpreis     118
# ...

# %%
df[["body_color", "paint_type","body_color_original"]].sample(50)
# Out:
#       body_color paint_type             body_color_original
# 4252        Grey   Metallic                            GRIS
# 1187       White        NaN             (B4B4) Cortinaweiss
# 11568      White   Metallic                    Schnee Weiss
# 12902        NaN        NaN                             NaN
# 3155       White        NaN                          Blanco
# 3387       Black        NaN                             NaN
# 12466      White   Metallic  SchneeWeiss/SummitWhite/Arctic
# 5248        Grey   Metallic                    Grigio scuro
# 6188        Grey   Metallic             Karbongrau metallic
# 2641       White        NaN                             NaN
# 8141       Black   Metallic               Onyx Schwarz (M2)
# 1613      Silver   Metallic                   florettsilber
# 5021       White        NaN                        Ibisweiß
# 12228     Silver   Metallic                          silber
# 11982       Grey   Metallic                            grau
# ...

# %%
# The number of null values in body_color column

df.body_color.isnull().sum()
# Out:
# 597

# %%
# Checking how many of the null values in body_color column are not null in body_color_original column

df[df.body_color.isnull()]["body_color_original"].notna().sum()
# Out:
# 407

# %% [markdown]
# As a result of the analysis of above, it was decided that the null values in body_color
# can be filled with the corresponding values in body_color_original column.

# %% [markdown]
# ### upholstery column

# %%
#Checking the upholstery column

first_look("upholstery")
# Out:
# column name :  upholstery
# --------------------------------
# Percent_of_Nulls   :  % 23.37
# Number_of_Nulls   :  3720
# Number_of_Uniques :  46
# Value_counts :
#  Cloth, Black           5821
# NaN                    3720
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# ...

# %%
# splitting upholstery column into upholstery_type and upholstery_color seperate columns

df.upholstery.str.extract(r"(.+)[.+](.+)?")[1].value_counts(dropna=False)
# Out:
# NaN    15919
# Name: 1, dtype: int64

# %%
df.upholstery.str.extract(r"(.+),(.+)")
# Out:
#                   0       1
# 0             Cloth   Black
# 1             Cloth    Grey
# 2             Cloth   Black
# 3               NaN     NaN
# 4             Cloth   Black
# ...             ...     ...
# 15914           NaN     NaN
# 15915           NaN     NaN
# 15916  Full leather   Black
# 15917           NaN     NaN
# 15918  Full leather   Brown
#
# [15919 rows x 2 columns]

# %%
# creating upholstery type list from upholstery column values using extract, dropna and unique methods.

type_list = list(df.upholstery.str.extract(r"(.+),(.+)")[0].dropna().unique())
type_list
# Out:
# ['Cloth', 'Part leather', 'Full leather', 'Other', 'alcantara', 'Velour']

# %%
# creating upholstery color list from upholstery column values using extract, dropna and unique methods.

color_list = list(df.upholstery.str.extract(r"(.+),\s*(.+)")[1].dropna().unique())
color_list
# Out:
# ['Black',
#  'Grey',
#  'Other',
#  'White',
#  'Red',
#  'Blue',
#  'Orange',
#  'Brown',
#  'Beige',
#  'Yellow']

# %%
# splitting upholstery column values into two column

df[["upholstery_type","upholstery_color"]] = df.upholstery.str.split(", ", expand=True)

# %%
# As it is seen below output there are some color values in type column. So they need to be fixed.

df["upholstery_type"].value_counts(dropna=False)
# Out:
# Cloth           8423
# NaN             3720
# Part leather    1499
# Full leather    1009
# Black            491
# Other            368
# Grey             273
# Velour            60
# alcantara         57
# Brown             12
# Beige              3
# Blue               2
# White              2
# Name: upholstery_type, dtype: int64

# %%
# Checking upholstery_color values whether there is upholstery_type value in it.

df["upholstery_color"].value_counts(dropna=False)
# Out:
# Black     7710
# NaN       5861
# Grey      1103
# Other      960
# Brown      195
# Beige       51
# Blue        14
# White       11
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery_color, dtype: int64

# %%
# Determining color values in the upholstery_type column

df.upholstery_type[df.upholstery_type.isin(color_list)]
# Out:
# 29       Black
# 55       Other
# 64       Black
# 95       Other
# 112      Black
#          ...
# 15783    Other
# 15821    Other
# 15866    Brown
# 15896     Grey
# 15902    Brown
# Name: upholstery_type, Length: 1151, dtype: object

# %%
# Assigning the color values which are in upholstery_type column to upholstery_color column

df.upholstery_color.fillna(df.upholstery_type[df.upholstery_type.isin(color_list)], inplace=True)

# %%
# Checking the values in upholstery_color column

df["upholstery_color"].value_counts(dropna=False)
# Out:
# Black     8201
# NaN       5022
# Grey      1376
# Other     1016
# Brown      207
# Beige       54
# Blue        16
# White       13
# Red          9
# Yellow       4
# Orange       1
# Name: upholstery_color, dtype: int64

# %%
# Replacing color values which are in upholstery_type column with null. 

df.upholstery_type[df.upholstery_type.isin(color_list)] = np.nan

# %%
# Checking the values in upholstery_type column

df.upholstery_type.value_counts(dropna=False)
# Out:
# Cloth           8423
# NaN             4871
# Part leather    1499
# Full leather    1009
# Velour            60
# alcantara         57
# Name: upholstery_type, dtype: int64

# %%
df[["upholstery_type","upholstery_color"]].notna().sum()
# Out:
# upholstery_type     11048
# upholstery_color    10897
# dtype: int64

# %%
df[["upholstery_type","upholstery_color"]].isnull().sum()
# Out:
# upholstery_type     4871
# upholstery_color    5022
# dtype: int64

# %%
df[["upholstery", "upholstery_type","upholstery_color"]].sample(50)
# Out:
#                 upholstery upholstery_type upholstery_color
# 2152                   NaN             NaN              NaN
# 6813          Cloth, Black           Cloth            Black
# 2454                   NaN             NaN              NaN
# 1954                   NaN             NaN              NaN
# 6925          Cloth, Black           Cloth            Black
# 1412           Cloth, Grey           Cloth             Grey
# 15585  Part leather, Black    Part leather            Black
# 8890          Cloth, Black           Cloth            Black
# 10276         Cloth, Black           Cloth            Black
# 1720         Velour, Black          Velour            Black
# 247           Other, Other             NaN            Other
# 11239         Cloth, Black           Cloth            Black
# 1377          Cloth, Black           Cloth            Black
# 11536                  NaN             NaN              NaN
# 10706         Cloth, Black           Cloth            Black
# ...

# %%
# dropping upholstery column

df.drop(columns="upholstery", inplace=True)

# %% [markdown]
# ### nr_of_doors column

# %%
# Checking the nr_of_doors column

first_look("nr_of_doors")
# Out:
# column name :  nr_of_doors
# --------------------------------
# Percent_of_Nulls   :  % 1.33
# Number_of_Nulls   :  212
# Number_of_Uniques :  6
# Value_counts :
#  5      11575
# 4       3079
# 3        832
# 2        219
# NaN      212
# 1          1
# 7          1
# Name: nr_of_doors, dtype: int64
#
# Value_counts with sort index :
#  1          1
# 2        219
# 3        832
# 4       3079
# 5      11575
# 7          1
# NaN      212
# Name: nr_of_doors, dtype: int64
# ########################################

# %%
# fixing data type

df["nr_of_doors"]= df.nr_of_doors.astype(float)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### nr_of_seats column

# %%
# Checking the nr_of_seats column

first_look("nr_of_seats")
# Out:
# column name :  nr_of_seats
# --------------------------------
# Percent_of_Nulls   :  % 6.14
# Number_of_Nulls   :  977
# Number_of_Uniques :  6
# Value_counts :
#  5      13336
# 4       1125
# NaN      977
# 7        362
# 2        116
# 6          2
# 3          1
# Name: nr_of_seats, dtype: int64
#
# Value_counts with sort index :
#  2        116
# 3          1
# 4       1125
# 5      13336
# 6          2
# 7        362
# NaN      977
# Name: nr_of_seats, dtype: int64
# ########################################

# %%
# fixing data type

df["nr_of_seats"]= df.nr_of_seats.astype(float)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### model_code column

# %%
# Checking the model_code column

first_look("model_code")
# Out:
# column name :  model_code
# --------------------------------
# Percent_of_Nulls   :  % 68.73
# Number_of_Nulls   :  10941
# Number_of_Uniques :  232
# Value_counts :
#  NaN         10941
# 0035/BCB      268
# 0588/BNO      245
# 0588/BDB      206
# 0588/BHX      188
#             ...
# 0035/AVN        1
# 0035/BEM        1
# 0035/BAG        1
# 0035/BAA        1
# 3333/BKG        1
# Name: model_code, Length: 233, dtype: int64
#
# Value_counts with sort index :
#  0000/000       21
# 0000/035        1
# 0000/ACP        1
# 0035/AAA        1
# 0035/AAD        1
#             ...
# 3333/BJR       79
# 3333/BKG        1
# 3333/BKQ       18
# 3333/BKR        8
# NaN         10941
# Name: model_code, Length: 233, dtype: int64
# ########################################

# %%
# As there isn't any usefull/related information about car price,
# it was decided to drop model_code column.

df.drop(columns="model_code", inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### gearing_type column

# %%
# Checking the gearing_type column

first_look("gearing_type")
# Out:
# column name :  gearing_type
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  3
# Value_counts :
#  Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64
#
# Value_counts with sort index :
#  Automatic         7297
# Manual            8153
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# ########################################

# %% [markdown]
# This column is already clean.

# %% [markdown]
# ### displacement column

# %%
# Checking the displacement column

first_look("displacement")
# Out:
# column name :  displacement
# --------------------------------
# Percent_of_Nulls   :  % 3.12
# Number_of_Nulls   :  496
# Number_of_Uniques :  77
# Value_counts :
#  1,598 cc     4761
# 999 cc       2438
# 1,398 cc     1314
# 1,399 cc      749
# 1,229 cc      677
# 1,956 cc      670
# 1,461 cc      595
# 1,490 cc      559
# NaN           496
# 1,422 cc      467
# 1,197 cc      353
# 898 cc        351
# 1,395 cc      320
# 1,968 cc      301
# 1,149 cc      288
# 1,618 cc      212
# 1,798 cc      210
# 1,498 cc      196
# 1,600 cc      130
# 1,248 cc      110
# 1,997 cc      103
# 1,364 cc      102
# 1,400 cc       90
# 998 cc         72
# 1,500 cc       50
# 2,000 cc       46
# 1,000 cc       40
# 1 cc           36
# 1,998 cc       25
# 2,480 cc       20
# 1,200 cc       18
# 1,984 cc       18
# 1,397 cc       11
# 899 cc         11
# 160 cc          6
# 929 cc          5
# 1,499 cc        5
# 997 cc          4
# 1,596 cc        4
# 139 cc          4
# 900 cc          4
# ...

# %%
# Replacing "," character with "" and extracting digits from displacement column.

df["displacement"] = df.displacement.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
# Renaming the displacement column as displacement_cc

df.rename(columns={"displacement":"displacement_cc"}, inplace=True)

# %%
df.displacement_cc.isnull().sum()
# Out:
# 496

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### cylinders columns

# %%
# Checking the cylinders column

first_look("cylinders")
# Out:
# column name :  cylinders
# --------------------------------
# Percent_of_Nulls   :  % 35.68
# Number_of_Nulls   :  5680
# Number_of_Uniques :  7
# Value_counts :
#  4      8105
# NaN    5680
# 3      2104
# 5        22
# 6         3
# 8         2
# 2         2
# 1         1
# Name: cylinders, dtype: int64
#
# Value_counts with sort index :
#  1         1
# 2         2
# 3      2104
# 4      8105
# 5        22
# 6         3
# 8         2
# NaN    5680
# Name: cylinders, dtype: int64
# ########################################

# %%
# fixing data type

df["cylinders"] = df.cylinders.astype(float)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### weight column

# %%
# Checking the weight column

first_look("weight")
# Out:
# column name :  weight
# --------------------------------
# Percent_of_Nulls   :  % 43.81
# Number_of_Nulls   :  6974
# Number_of_Uniques :  434
# Value_counts :
#  NaN         6974
# 1,163 kg     574
# 1,360 kg     356
# 1,165 kg     301
# 1,335 kg     242
#             ...
# 1,960 kg       1
# 1,258 kg       1
# 1,167 kg       1
# 1,331 kg       1
# 2,037 kg       1
# Name: weight, Length: 435, dtype: int64
#
# Value_counts with sort index :
#  1 kg           2
# 1,009 kg       1
# 1,010 kg       3
# 1,017 kg       1
# 1,030 kg       1
#             ...
# 840 kg         1
# 900 kg         1
# 977 kg         2
# 980 kg        11
# NaN         6974
# Name: weight, Length: 435, dtype: int64
# ########################################

# %%
# Replacing "," character with "", extracting digits from weight column
# and assign as weight_kg column.

df["weight_kg"] = df.weight.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
# drop weight column

df.drop(columns="weight", inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %%
df.weight_kg.isnull().sum()
# Out:
# 6974

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### drive_chain column

# %%
# Checking the drive_chain column

first_look("drive_chain")
# Out:
# column name :  drive_chain
# --------------------------------
# Percent_of_Nulls   :  % 43.08
# Number_of_Nulls   :  6858
# Number_of_Uniques :  3
# Value_counts :
#  front    8886
# NaN      6858
# 4WD       171
# rear        4
# Name: drive_chain, dtype: int64
#
# Value_counts with sort index :
#  4WD       171
# front    8886
# rear        4
# NaN      6858
# Name: drive_chain, dtype: int64
# ########################################

# %% [markdown]
# This column is already clean.

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### fuel column

# %%
# Checking the fuel column

first_look("fuel")
# Out:
# column name :  fuel
# --------------------------------
# Percent_of_Nulls   :  % 0.0
# Number_of_Nulls   :  0
# Number_of_Uniques :  77
# Value_counts :
#  Diesel (Particulate Filter)                                                                                                       4315
# Super 95                                                                                                                          3338
# Gasoline                                                                                                                          3175
# Diesel                                                                                                                            2984
# Super 95 / Regular/Benzine 91                                                                                                      424
# Regular/Benzine 91                                                                                                                 354
# ...

# %%
# For further analysis it will be better to categorize fuel column.
# Defining lpg, diesel, bensine and electirc/hybrid lists with the related values in fuel column

lpg = ["lpg", "CNG", "Domestic gas H", "Biogas"]
diesel = ["Diesel", "Biodiesel"]
benzine =["Gasoline", "Benzine", "Regular", "Super", "Other"]
electric_hybride = ["Electric"]

# %%
# Defining a function to categorize fuel column

def fuelcategory(row) :
    if any(x in row for x in lpg):
        return "LPG/CNG"
    elif any(x in row for x in electric_hybride) :
        return "Electric/Hybride"
    elif any(x in row for x in diesel) :
        if "Particulate Filter" in row :
            return "Diesel (Particulate Filter)"
        else :
            return "Diesel"
    else :
        if "Particulate Filter" in row :
            return "Benzine (Particulate Filter)"
        else :
            return "Benzine"

# %%
# Application of defined function to fuel column

df["fuel"] = df.fuel.apply(fuelcategory)

# %%
# Checking the value counts of fuel column after categorization process

df.fuel.value_counts()
# Out:
# Benzine                         8075
# Diesel (Particulate Filter)     4315
# Diesel                          2985
# Benzine (Particulate Filter)     501
# LPG/CNG                           38
# Electric/Hybride                   5
# Name: fuel, dtype: int64

# %% [markdown]
# ### consumption column

# %%
# Checking the consumption column

first_look("consumption")
# Out:
# column name :  consumption
# --------------------------------
# Percent_of_Nulls   :  % 11.97
# Number_of_Nulls   :  1906
# Number_of_Uniques :  881
# Value_counts :
#  NaN                                                                           1906
# ['3.9 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.7 l/100 km (country)']     304
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']       276
# ['5.4 l/100 km (comb)'],['6.8 l/100 km (city)'],['4.5 l/100 km (country)']     257
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']     253
#                                                                               ...
# ['4.2 l/100 km (comb)'],['5.3 l/100 km (city)'],['3.6 l/100 km (country)']       1
# 5.1 l/100 km (comb),,6.4 l/100 km (city),,4.3 l/100 km (country)                 1
# ['4.6 l/100 km (comb)'],['5.4 l/100 km (city)'],['6.7 l/100 km (country)']       1
# ...

# %%
# Cleaning consumption column and taking fuel consumption values into separate columns
# Changing data types of new columns

df["consumption"]=df["consumption"].str.replace("[\[\]']?","")
df["consumption_comb"] = df.consumption.str.extract(r"(\d*\.\d+|\d+).+\(comb\)").astype(float)
df["consumption_city"] = df.consumption.str.extract(r"[.+]?,(\d*\.\d+|\d+).+\(city\)").astype(float)
df["consumption_country"] = df.consumption.str.extract(r".+,(\d*\.\d+|\d+).+\(country\)").astype(float)

# %%
# Comparing new columns' values with consumptions' values

df[["consumption","consumption_comb","consumption_city","consumption_country"]].sample(50)
# Out:
#                                              consumption  consumption_comb  \
# 2858   3.9 l/100 km (comb),4.4 l/100 km (city),3.6 l/...               3.9
# 1793   3.8 l/100 km (comb),4.6 l/100 km (city),3.3 l/...               3.8
# 14723  5 l/100 km (comb),6.3 l/100 km (city),4.2 l/10...               5.0
# 8638   5.1 l/100 km (comb),6.5 l/100 km (city),4.3 l/...               5.1
# 5225   5.5 l/100 km (comb),6.9 l/100 km (city),4.7 l/...               5.5
# 12682  5.4 l/100 km (comb),7 l/100 km (city),4.6 l/10...               5.4
# 1692   4.7 l/100 km (comb),5.8 l/100 km (city),4.1 l/...               4.7
# 3435   3.8 l/100 km (comb),4.3 l/100 km (city),3.5 l/...               3.8
# 12022  5.7 l/100 km (comb),7.5 l/100 km (city),4.6 l/...               5.7
# 9119         5.4 l/100 km (comb),,4.6 l/100 km (country)               5.4
# 15674  5.3 l/100 km (comb),6.2 l/100 km (city),4.7 l/...               5.3
# ...

# %%
# Checking the number of null values in new columns

df[["consumption_comb","consumption_city","consumption_country"]].isnull().sum()
# Out:
# consumption_comb       2033
# consumption_city       2436
# consumption_country    2376
# dtype: int64

# %%
# Checking the number of non-null values in new columns

df[["consumption_comb","consumption_city","consumption_country"]].notna().sum()
# Out:
# consumption_comb       13886
# consumption_city       13483
# consumption_country    13543
# dtype: int64

# %%
# dropping consumption column

df.drop(columns="consumption", inplace=True)

# %% [markdown]
# ### co_2_emission column

# %%
# Checking the co_2_emission column

first_look("co_2_emission")
# Out:
# column name :  co_2_emission
# --------------------------------
# Percent_of_Nulls   :  % 15.3
# Number_of_Nulls   :  2436
# Number_of_Uniques :  122
# Value_counts :
#  NaN                      2436
# 120 g CO2/km (comb)       740
# 99 g CO2/km (comb)        545
# 97 g CO2/km (comb)        537
# 104 g CO2/km (comb)       501
#                          ...
# 14 g CO2/km (comb)          1
# 1,060 g CO2/km (comb)       1
# 51 g CO2/km (comb)          1
# 165 g CO2/km (comb)         1
# 193 g CO2/km (comb)         1
# Name: co_2_emission, Length: 123, dtype: int64
#
# Value_counts with sort index :
#  0 g CO2/km (comb)           2
# 1 g CO2/km (comb)           1
# 1,060 g CO2/km (comb)       1
# 100 g CO2/km (comb)        36
# 101 g CO2/km (comb)       105
#                          ...
# 97 g CO2/km (comb)        537
# 98 g CO2/km (comb)        151
# 99 g CO2/km (comb)        545
# 990 g CO2/km (comb)         1
# NaN                      2436
# ...

# %%
# Replacing "," character with "", extracting digits from co_2_emission column.

df["co_2_emission"] = df.co_2_emission.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
df.co_2_emission.isnull().sum()
# Out:
# 2436

# %%
df.co_2_emission
# Out:
# 0         99.0
# 1        129.0
# 2         99.0
# 3         99.0
# 4        109.0
#          ...
# 15914    139.0
# 15915    168.0
# 15916    139.0
# 15917    139.0
# 15918    153.0
# Name: co_2_emission, Length: 15919, dtype: float64

# %%
df.co_2_emission.value_counts()
# Out:
# 120.0      740
# 99.0       545
# 97.0       537
# 104.0      501
# 102.0      477
#           ...
# 80.0         1
# 51.0         1
# 165.0        1
# 12324.0      1
# 193.0        1
# Name: co_2_emission, Length: 122, dtype: int64

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### emission_class column

# %%
# Checking the emission_class column

first_look("emission_class")
# Out:
# column name :  emission_class
# --------------------------------
# Percent_of_Nulls   :  % 22.79
# Number_of_Nulls   :  3628
# Number_of_Uniques :  6
# Value_counts :
#  Euro 6          10139
# NaN              3628
# Euro 6d-TEMP     1845
# Euro 6c           127
# Euro 5             78
# Euro 6d            62
# Euro 4             40
# Name: emission_class, dtype: int64
#
# Value_counts with sort index :
#  Euro 4             40
# Euro 5             78
# Euro 6          10139
# Euro 6c           127
# Euro 6d            62
# Euro 6d-TEMP     1845
# NaN              3628
# Name: emission_class, dtype: int64
# ########################################

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### comfort_&_convenience column

# %%
# Checking the comfort_&_convenience column

first_look("comfort_&_convenience")
# Out:
# column name :  comfort_&_convenience
# --------------------------------
# Percent_of_Nulls   :  % 5.78
# Number_of_Nulls   :  920
# Number_of_Uniques :  6198
# Value_counts :
#  NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  920
# ...

# %%
# Renaming the comfort_&_convenience column as comfort_convenience

df.rename(columns={"comfort_&_convenience":"comfort_convenience"}, inplace=True)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### entertainment_&_media column

# %%
# Checking the entertainment_&_media column

first_look("entertainment_&_media")
# Out:
# column name :  entertainment_&_media
# --------------------------------
# Percent_of_Nulls   :  % 8.63
# Number_of_Nulls   :  1374
# Number_of_Uniques :  346
# Value_counts :
#  NaN                                                                                                 1374
# Bluetooth,Hands-free equipment,On-board computer,Radio,USB                                          1282
# Bluetooth,Hands-free equipment,MP3,On-board computer,Radio,USB                                       982
# Bluetooth,CD player,Hands-free equipment,MP3,On-board computer,Radio,USB                             783
# On-board computer,Radio                                                                              487
#                                                                                                     ...
# Bluetooth,CD player,Digital radio,Hands-free equipment,Radio                                           1
# ...

# %%
# Renaming the entertainment_&_media column as entertainment_media

df.rename(columns={"entertainment_&_media":"entertainment_media"}, inplace=True)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### extras column

# %%
# Checking the extras column

first_look("extras")
# Out:
# column name :  extras
# --------------------------------
# Percent_of_Nulls   :  % 18.61
# Number_of_Nulls   :  2962
# Number_of_Uniques :  659
# Value_counts :
#  Alloy wheels                                                                                               3245
# NaN                                                                                                        2962
# Alloy wheels,Touch screen                                                                                   697
# Alloy wheels,Voice Control                                                                                  577
# Alloy wheels,Touch screen,Voice Control                                                                     541
#                                                                                                            ...
# Alloy wheels,Catalytic Converter,Shift paddles,Sport package,Sport seats,Sport suspension,Voice Control       1
# ...

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### safety_&_security column

# %%
# Checking the safety_&_security column

first_look("safety_&_security")
# Out:
# column name :  safety_&_security
# --------------------------------
# Percent_of_Nulls   :  % 6.17
# Number_of_Nulls   :  982
# Number_of_Uniques :  4443
# Value_counts :
#  NaN                                                                                                                                                                                                                                                                                                                                                               982
# ABS,Central door lock,Daytime running lights,Driver-side airbag,Electronic stability control,Fog lights,Immobilizer,Isofix,Passenger-side airbag,Power steering,Side airbag,Tire pressure monitoring system,Traction control                                                                                                                                      538
# ...

# %%
# Renaming the safety_&_security column as safety_security

df.rename(columns={"safety_&_security":"safety_security"}, inplace=True)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### description column

# %%
# Checking the description column

first_look("description")
# Out:
# column name :  description
# --------------------------------
# Percent_of_Nulls   :  % 4.19
# Number_of_Nulls   :  667
# Number_of_Uniques :  12863
# Value_counts :
# ...

# %%
# As description column doesn't contain usefull information and it is not related with price,
# it was decide to drop description column

df.drop(columns="description", inplace=True)

# %%
df.shape
# Out:
# (15919, 45)

# %% [markdown]
# ### emission_label column

# %%
# Checking the emission_label column

first_look("emission_label")
# Out:
# column name :  emission_label
# --------------------------------
# Percent_of_Nulls   :  % 75.22
# Number_of_Nulls   :  11974
# Number_of_Uniques :  5
# Value_counts :
#  NaN               11974
# 4 (Green)          3553
# 1 (No sticker)      381
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64
#
# Value_counts with sort index :
#  1 (No sticker)      381
# 2 (Red)               1
# 3 (Yellow)            2
# 4 (Green)          3553
# 5 (Blue)              8
# NaN               11974
# Name: emission_label, dtype: int64
# ########################################

# %%
# As it contains so many null values and it is not possible to fill null values in this column
# from other columns, it was decided to drop emission_label column.

df.drop(columns="emission_label", inplace=True)

# %%
df.shape
# Out:
# (15919, 44)

# %% [markdown]
# ### gears columns

# %%
# Checking the gears column

first_look("gears")
# Out:
# column name :  gears
# --------------------------------
# Percent_of_Nulls   :  % 29.6
# Number_of_Nulls   :  4712
# Number_of_Uniques :  10
# Value_counts :
#  6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64
#
# Value_counts with sort index :
#  1         2
# 2         1
# 3         2
# 4         2
# 5      3239
# 50        1
# 6      5822
# 7      1908
# 8       224
# 9         6
# NaN    4712
# Name: gears, dtype: int64
# ########################################

# %%
# Fixing data type

df["gears"] =  df.gears.astype(float)

# %%
# Null values will be worked in next notebook.

# %% [markdown]
# ### country_version column

# %%
# Checking the country_version column

first_look("country_version")
# Out:
# column name :  country_version
# --------------------------------
# Percent_of_Nulls   :  % 52.35
# Number_of_Nulls   :  8333
# Number_of_Uniques :  23
# Value_counts :
#  NaN               8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64
#
# Value_counts with sort index :
#  Austria            208
# Belgium            314
# Bulgaria             2
# Croatia              4
# Czech Republic      52
# Denmark             33
# ...

# %%
df.groupby("country_version").price.mean()
# Out:
# country_version
# Austria           20394.120192
# Belgium           17485.684713
# Bulgaria          17593.000000
# Croatia           15179.750000
# Czech Republic    23551.057692
# Denmark           22587.606061
# Egypt             16990.000000
# European Union    20291.230769
# France            14952.315789
# Germany           18362.484896
# Hungary           21490.285714
# Italy             17140.421965
# Japan             13343.000000
# Luxembourg        14200.000000
# Netherlands       25996.476293
# Poland            20071.163265
# Romania           19714.000000
# Serbia             8490.000000
# Slovakia          24612.500000
# Slovenia          20985.000000
# Spain             15077.224615
# Sweden            20837.666667
# Switzerland       16999.000000
# Name: price, dtype: float64

# %%
# drop country_version column as it contains so many null values and
# other values in this column doesn't related with price.

df.drop(columns="country_version", inplace=True)

# %%
df.shape
# Out:
# (15919, 43)

# %% [markdown]
# ## Conclusion after cleaning process

# %% [markdown]
# At the begining of the cleaning process firstly we made a general cleanin in dataframe. And then we cleaned columns one by one. During this process necessary values were taken from columns, and unnecessary columns was dropped. Finally cleaned dataframe was saved as "scout_car_cleaned.csv".
#
# Handling with null values process will be worked in another notebook.

# %% [markdown]
# ## Saving cleaned df as "scout_car_cleaned.csv"

# %%
df.to_csv("scout_car_cleaned.csv", index=False)

# %%
pd.read_csv("scout_car_cleaned.csv")
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type    price  \
# ...
