# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# # PART- 1 `( Data Cleaning )`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches
import seaborn as sns

import warnings

# Statistics functions
from scipy.stats import norm
from scipy import stats
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
# Suppressing a warning 
warnings.filterwarnings("ignore") 

# It is a magic function that renders the figure in the notebook
# %matplotlib inline 

# Changing the figure size of a seaborn axes 
sns.set(rc={"figure.figsize": (10, 6)})

# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid")

# To display maximum columns
pd.set_option('display.max_columns', None)


# To display maximum rows
pd.set_option('display.max_rows', 100)

# %%
df = pd.read_json("scout_car/scout_car.json", lines=True)

df_copy = df.copy()

# %%
df_copy.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
# 3              None  73,000 km      08/2016   1 previous owner NaN   66 kW
# 4              None  16,200 km      05/2016   1 previous owner NaN   66 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 3  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 4  [, Used, , Diesel (Particulate Filter)]           \n1\n
#
#                          Next Inspection                      Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]               [\nYes\n, \nEuro 6\n]
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN  [\nYes\n, \n109 g CO2/km (comb)\n]
#
#                            Warranty                      Full Service  \
# 0           [\n, \n, \n4 (Green)\n]                          [\n, \n]
# 1                               NaN                               NaN
# 2  [\n, \n, \n99 g CO2/km (comb)\n]                               NaN
# 3                               NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 4              [\n, \n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
#
#     Non-smoking Vehicle null      Make         Model     Offer Number  \
# 0              [\n, \n]   []  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]
# 1                   NaN   []  \nAudi\n  [\n, A1, \n]              NaN
# 2                   NaN   []  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]
# 3  [\n, \n, \nEuro 6\n]   []  \nAudi\n  [\n, A1, \n]              NaN
# 4              [\n, \n]   []  \nAudi\n  [\n, A1, \n]      [\nC1626\n]
#
#   First Registration       Body Color      Paint Type  \
# 0     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1     [\n, 2017, \n]    [\n, Red, \n]             NaN
# 2     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 3     [\n, 2016, \n]  [\n, Brown, \n]  [\nMetallic\n]
# 4     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
#
#             Body Color Original          Upholstery              Body  \
# 0           [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 1                           NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]
# 2  [\nmythosschwarz metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 3                           NaN                 NaN  [\n, Sedans, \n]
# 4  [\nMythosschwarz Metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
#
#   Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 0      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
# 1      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]
# 2      [\n4\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 3      [\n3\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 4      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
#
#      Displacement Cylinders          Weight  Drive chain  \
# 0  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
# 2  [\n1,598 cc\n]       NaN             NaN  [\nfront\n]
# 3  [\n1,422 cc\n]   [\n3\n]  [\n1,195 kg\n]          NaN
# 4  [\n1,422 cc\n]   [\n3\n]             NaN  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
# 2  [\n, Diesel (Particulate Filter), \n]
# 3  [\n, Diesel (Particulate Filter), \n]
# 4  [\n, Diesel (Particulate Filter), \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4  [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 3   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 4  [\n109 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Cruise control, Electrical ...
# 3  [Air suspension, Armrest, Auxiliary heating, E...
# 4  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
# 2                           [MP3, On-board computer]
# 3  [Bluetooth, CD player, Hands-free equipment, M...
# 4  [Bluetooth, CD player, Hands-free equipment, M...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
# 2                      [Alloy wheels, Voice Control]
# 3         [Alloy wheels, Sport seats, Voice Control]
# 4  [Alloy wheels, Sport package, Sport suspension...
#
#                                \nSafety & Security\n  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
# 2  [ABS, Central door lock, Daytime running light...
# 3  [ABS, Alarm system, Central door lock with rem...
# 4  [ABS, Central door lock, Driver-side airbag, E...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3  [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4  [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
# 2      NaN             NaN                     NaN               NaN
# 3  [\n6\n]             NaN                     NaN               NaN
# 4      NaN   [\nGermany\n]                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN
# 2              NaN          NaN                           NaN            NaN
# 3              NaN          NaN                           NaN            NaN
# 4              NaN          NaN                           NaN            NaN

# %%
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
# 3              None  73,000 km      08/2016   1 previous owner NaN   66 kW
# 4              None  16,200 km      05/2016   1 previous owner NaN   66 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 3  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 4  [, Used, , Diesel (Particulate Filter)]           \n1\n
#
#                          Next Inspection                      Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]               [\nYes\n, \nEuro 6\n]
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN  [\nYes\n, \n109 g CO2/km (comb)\n]
#
#                            Warranty                      Full Service  \
# 0           [\n, \n, \n4 (Green)\n]                          [\n, \n]
# 1                               NaN                               NaN
# 2  [\n, \n, \n99 g CO2/km (comb)\n]                               NaN
# 3                               NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 4              [\n, \n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
#
#     Non-smoking Vehicle null      Make         Model     Offer Number  \
# 0              [\n, \n]   []  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]
# 1                   NaN   []  \nAudi\n  [\n, A1, \n]              NaN
# 2                   NaN   []  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]
# 3  [\n, \n, \nEuro 6\n]   []  \nAudi\n  [\n, A1, \n]              NaN
# 4              [\n, \n]   []  \nAudi\n  [\n, A1, \n]      [\nC1626\n]
#
#   First Registration       Body Color      Paint Type  \
# 0     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1     [\n, 2017, \n]    [\n, Red, \n]             NaN
# 2     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 3     [\n, 2016, \n]  [\n, Brown, \n]  [\nMetallic\n]
# 4     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
#
#             Body Color Original          Upholstery              Body  \
# 0           [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 1                           NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]
# 2  [\nmythosschwarz metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 3                           NaN                 NaN  [\n, Sedans, \n]
# 4  [\nMythosschwarz Metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
#
#   Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 0      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
# 1      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]
# 2      [\n4\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 3      [\n3\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 4      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
#
#      Displacement Cylinders          Weight  Drive chain  \
# 0  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
# 2  [\n1,598 cc\n]       NaN             NaN  [\nfront\n]
# 3  [\n1,422 cc\n]   [\n3\n]  [\n1,195 kg\n]          NaN
# 4  [\n1,422 cc\n]   [\n3\n]             NaN  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
# 2  [\n, Diesel (Particulate Filter), \n]
# 3  [\n, Diesel (Particulate Filter), \n]
# 4  [\n, Diesel (Particulate Filter), \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4  [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 3   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 4  [\n109 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Cruise control, Electrical ...
# 3  [Air suspension, Armrest, Auxiliary heating, E...
# 4  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
# 2                           [MP3, On-board computer]
# 3  [Bluetooth, CD player, Hands-free equipment, M...
# 4  [Bluetooth, CD player, Hands-free equipment, M...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
# 2                      [Alloy wheels, Voice Control]
# 3         [Alloy wheels, Sport seats, Voice Control]
# 4  [Alloy wheels, Sport package, Sport suspension...
#
#                                \nSafety & Security\n  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
# 2  [ABS, Central door lock, Daytime running light...
# 3  [ABS, Alarm system, Central door lock with rem...
# 4  [ABS, Central door lock, Driver-side airbag, E...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3  [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4  [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
# 2      NaN             NaN                     NaN               NaN
# 3  [\n6\n]             NaN                     NaN               NaN
# 4      NaN   [\nGermany\n]                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN
# 2              NaN          NaN                           NaN            NaN
# 3              NaN          NaN                           NaN            NaN
# 4              NaN          NaN                           NaN            NaN

# %%
df.sample(10)
# Out:
#                                                      url      make_model  \
# 8805   https://www.autoscout24.com//offers/opel-corsa...      Opel Corsa
# 1860   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 6019   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 2872   https://www.autoscout24.com//offers/audi-a3-sp...         Audi A3
# 1674   https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 11356  https://www.autoscout24.com//offers/opel-insig...   Opel Insignia
# 1765   https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 13419  https://www.autoscout24.com//offers/renault-cl...    Renault Clio
# 7213   https://www.autoscout24.com//offers/opel-astra...      Opel Astra
# 15853  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description      body_type  \
# 8805                                 1.3CDTI Business 75        Compact
# 1860         Sportback 1.0 TFSI Navi MediaPaket SHZG GRA        Compact
# 6019               K ST Business 1.6 CDTI AGR-Sitze Navi  Station wagon
# 2872      sportback 2.0 TDI 150 Business Line S tronic 6         Sedans
# 1674       Sportback 1.6 TDI sport S tronic *S-LINE*EU6*         Sedans
# 11356  Sports Tourer 1.5T Aut Innovation el.Heckklapp...  Station wagon
# 1765   1.4 TDI ultra navi bi. xenon led GARANZIA UFF....         Sedans
# 13419                    ST 1.5dCi Energy Limited EDC 90  Station wagon
# 7213          K ST Innovation AT, Navi, DAB, Frontkamera  Station wagon
# 15853            2.0 Blue dCi Initiale Paris EDC (EU6.2)            Van
#
#        price             vat          km registration        prev_owner  kW  \
# 8805    6300            None  124,000 km      06/2016              None NaN
# 1860   16845  VAT deductible   26,819 km      05/2018  1 previous owner NaN
# 6019   12540  VAT deductible   87,164 km      01/2017  1 previous owner NaN
# 2872   16690            None  101,307 km      03/2016              None NaN
# 1674   21770  VAT deductible    6,700 km      03/2018  1 previous owner NaN
# 11356  21649  VAT deductible   28,277 km      01/2018  1 previous owner NaN
# 1765   16900            None   19,000 km      01/2018  1 previous owner NaN
# 13419  10500            None   23,000 km      07/2017              None NaN
# 7213   17940  VAT deductible   29,980 km      05/2018  1 previous owner NaN
# 15853  43950  VAT deductible      100 km          -/-              None NaN
#
#            hp                                     Type Previous Owners  \
# 8805    55 kW                       [, Used, , Diesel]             NaN
# 1860    70 kW                     [, Used, , Gasoline]           \n1\n
# 6019   100 kW  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 2872   110 kW                       [, Used, , Diesel]             NaN
# 1674    85 kW  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 11356  121 kW                     [, Used, , Super 95]           \n1\n
# 1765    66 kW                       [, Used, , Diesel]           \n1\n
# 13419   66 kW                       [, Used, , Diesel]             NaN
# 7213   110 kW                     [, Used, , Super 95]           \n1\n
# 15853  147 kW                        [, New, , Diesel]           \n0\n
#
#                               Next Inspection  \
# 8805                                      NaN
# 1860                                      NaN
# 6019                                      NaN
# 2872                                      NaN
# 1674   [\n03/2021\n, \n106 g CO2/km (comb)\n]
# 11356  [\n06/2021\n, \n147 g CO2/km (comb)\n]
# 1765                                      NaN
# 13419                                     NaN
# 7213                                      NaN
# 15853                                     NaN
#
#                            Inspection new                     Warranty  \
# 8805                                  NaN                \n12 months\n
# 1860    [\nYes\n, \n97 g CO2/km (comb)\n]         [\n, \n, \nEuro 6\n]
# 6019   [\nYes\n, \n119 g CO2/km (comb)\n]  [\n12 months\n, \nEuro 6\n]
# 2872                                  NaN                 \n6 months\n
# 1674                                  NaN         [\n, \n, \nEuro 6\n]
# 11356               [\nYes\n, \nEuro 6\n]      [\n, \n, \n4 (Green)\n]
# 1765                                  NaN  [\n12 months\n, \nEuro 6\n]
# 13419                                 NaN                          NaN
# 7213   [\nYes\n, \n128 g CO2/km (comb)\n]         [\n, \n, \nEuro 6\n]
# 15853                                 NaN                          NaN
#
#                   Full Service Non-smoking Vehicle null         Make  \
# 8805                       NaN                 NaN   []     \nOpel\n
# 1860   [\n, \n, \n4 (Green)\n]            [\n, \n]   []     \nAudi\n
# 6019   [\n, \n, \n4 (Green)\n]                 NaN   []     \nOpel\n
# 2872                       NaN                 NaN   []     \nAudi\n
# 1674   [\n, \n, \n4 (Green)\n]            [\n, \n]   []     \nAudi\n
# 11356                 [\n, \n]                 NaN   []     \nOpel\n
# 1765                       NaN                 NaN   []     \nAudi\n
# 13419                      NaN                 NaN   []  \nRenault\n
# 7213   [\n, \n, \n4 (Green)\n]            [\n, \n]   []     \nOpel\n
# 15853                      NaN                 NaN   []  \nRenault\n
#
#                     Model        Offer Number First Registration  \
# 8805      [\n, Corsa, \n]       [\n2839736\n]     [\n, 2016, \n]
# 1860         [\n, A1, \n]         [\n16600\n]     [\n, 2018, \n]
# 6019      [\n, Astra, \n]    [\n8034217BDK\n]     [\n, 2017, \n]
# 2872         [\n, A3, \n]      [\ncu373hft\n]     [\n, 2016, \n]
# 1674         [\n, A1, \n]  [\nPSB27194_Lim\n]     [\n, 2018, \n]
# 11356  [\n, Insignia, \n]        [\ns84758\n]     [\n, 2018, \n]
# 1765         [\n, A1, \n]                 NaN     [\n, 2018, \n]
# 13419      [\n, Clio, \n]                 NaN     [\n, 2017, \n]
# 7213      [\n, Astra, \n]          [\n3782\n]     [\n, 2018, \n]
# 15853    [\n, Espace, \n]                 NaN                NaN
#
#              Body Color      Paint Type               Body Color Original  \
# 8805    [\n, White, \n]             NaN                      [\nBlanco\n]
# 1860     [\n, Blue, \n]  [\nMetallic\n]          [\nScubablau Metallic\n]
# 6019    [\n, Black, \n]  [\nMetallic\n]                [\nonyx schwarz\n]
# 2872   [\n, Silver, \n]  [\nMetallic\n]                      [\nargent\n]
# 1674    [\n, White, \n]  [\nMetallic\n]  [\n2Y Gletscherweiss Metallic\n]
# 11356  [\n, Silver, \n]  [\nMetallic\n]                 [\nArgonsilber\n]
# 1765     [\n, Blue, \n]  [\nMetallic\n]                               NaN
# 13419   [\n, White, \n]             NaN                               NaN
# 7213     [\n, Grey, \n]  [\nMetallic\n]                  [\nQuarz Grau\n]
# 15853   [\n, Black, \n]  [\nMetallic\n]                               NaN
#
#                       Upholstery                     Body Nr. of Doors  \
# 8805                         NaN        [\n, Compact, \n]      [\n3\n]
# 1860          [\nCloth, Black\n]        [\n, Compact, \n]      [\n5\n]
# 6019          [\nCloth, Black\n]  [\n, Station wagon, \n]      [\n5\n]
# 2872                         NaN         [\n, Sedans, \n]      [\n5\n]
# 1674   [\nPart leather, Black\n]         [\n, Sedans, \n]      [\n5\n]
# 11356         [\nOther, Other\n]  [\n, Station wagon, \n]      [\n5\n]
# 1765          [\nCloth, Black\n]         [\n, Sedans, \n]      [\n3\n]
# 13419                        NaN  [\n, Station wagon, \n]      [\n5\n]
# 7213   [\nPart leather, Black\n]  [\n, Station wagon, \n]      [\n4\n]
# 15853   [\nFull leather, Grey\n]            [\n, Van, \n]      [\n5\n]
#
#       Nr. of Seats      Model Code         Gearing Type    Displacement  \
# 8805       [\n5\n]             NaN     [\n, Manual, \n]  [\n1,248 cc\n]
# 1860       [\n4\n]  [\n0588/BDB\n]     [\n, Manual, \n]    [\n999 cc\n]
# 6019       [\n5\n]             NaN  [\n, Automatic, \n]  [\n1,598 cc\n]
# 2872       [\n5\n]             NaN  [\n, Automatic, \n]  [\n1,968 cc\n]
# 1674       [\n4\n]  [\n0588/BDG\n]  [\n, Automatic, \n]  [\n1,598 cc\n]
# 11356      [\n5\n]  [\n1844/AAI\n]  [\n, Automatic, \n]  [\n1,490 cc\n]
# 1765       [\n4\n]             NaN     [\n, Manual, \n]  [\n1,422 cc\n]
# 13419      [\n5\n]             NaN  [\n, Automatic, \n]  [\n1,461 cc\n]
# 7213       [\n5\n]             NaN  [\n, Automatic, \n]  [\n1,399 cc\n]
# 15853      [\n5\n]             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]
#
#       Cylinders          Weight  Drive chain  \
# 8805    [\n4\n]  [\n1,199 kg\n]  [\nfront\n]
# 1860        NaN             NaN  [\nfront\n]
# 6019    [\n4\n]             NaN  [\nfront\n]
# 2872        NaN             NaN          NaN
# 1674    [\n4\n]  [\n1,275 kg\n]  [\nfront\n]
# 11356   [\n4\n]  [\n1,522 kg\n]  [\nfront\n]
# 1765    [\n3\n]  [\n1,130 kg\n]  [\nfront\n]
# 13419   [\n4\n]  [\n1,121 kg\n]          NaN
# 7213    [\n4\n]             NaN  [\nfront\n]
# 15853   [\n4\n]  [\n1,840 kg\n]  [\nfront\n]
#
#                                         Fuel  \
# 8805                        [\n, Diesel, \n]
# 1860                      [\n, Gasoline, \n]
# 6019   [\n, Diesel (Particulate Filter), \n]
# 2872                        [\n, Diesel, \n]
# 1674   [\n, Diesel (Particulate Filter), \n]
# 11356                     [\n, Super 95, \n]
# 1765                        [\n, Diesel, \n]
# 13419                       [\n, Diesel, \n]
# 7213                      [\n, Super 95, \n]
# 15853                       [\n, Diesel, \n]
#
#                                              Consumption  \
# 8805   [[3 l/100 km (comb)], [4 l/100 km (city)], [3 ...
# 1860   [[4.2 l/100 km (comb)], [5 l/100 km (city)], [...
# 6019   [[4.5 l/100 km (comb)], [5.7 l/100 km (city)],...
# 2872   [[4.4 l/100 km (comb)], [5.2 l/100 km (city)],...
# 1674   [[4 l/100 km (comb)], [4.8 l/100 km (city)], [...
# 11356  [[6.4 l/100 km (comb)], [8.1 l/100 km (city)],...
# 1765   [[3.4 l/100 km (comb)], [3.9 l/100 km (city)],...
# 13419  [[3.6 l/100 km (comb)], [4.1 l/100 km (city)],...
# 7213   [[5.6 l/100 km (comb)], [7.3 l/100 km (city)],...
# 15853  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
#
#                     CO2 Emission Emission Class  \
# 8805                         NaN            NaN
# 1860    [\n97 g CO2/km (comb)\n]   [\nEuro 6\n]
# 6019   [\n119 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2872   [\n116 g CO2/km (comb)\n]            NaN
# 1674   [\n106 g CO2/km (comb)\n]   [\nEuro 6\n]
# 11356  [\n147 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1765    [\n91 g CO2/km (comb)\n]   [\nEuro 6\n]
# 13419   [\n92 g CO2/km (comb)\n]   [\nEuro 6\n]
# 7213   [\n128 g CO2/km (comb)\n]   [\nEuro 6\n]
# 15853  [\n139 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                \nComfort & Convenience\n  \
# 8805                                                 NaN
# 1860   [Air conditioning, Automatic climate control, ...
# 6019   [Air conditioning, Armrest, Automatic climate ...
# 2872   [Air conditioning, Automatic climate control, ...
# 1674   [Air conditioning, Armrest, Automatic climate ...
# 11356  [Air conditioning, Armrest, Automatic climate ...
# 1765   [Air conditioning, Light sensor, Multi-functio...
# 13419  [Air conditioning, Cruise control, Electrical ...
# 7213   [Air conditioning, Armrest, Automatic climate ...
# 15853  [Air conditioning, Armrest, Automatic climate ...
#
#                                \nEntertainment & Media\n  \
# 8805                                                 NaN
# 1860   [Bluetooth, CD player, Hands-free equipment, M...
# 6019   [Bluetooth, Hands-free equipment, MP3, On-boar...
# 2872                                                 NaN
# 1674   [Bluetooth, CD player, Digital radio, Hands-fr...
# 11356  [Bluetooth, Hands-free equipment, On-board com...
# 1765   [Bluetooth, CD player, Digital radio, Hands-fr...
# 13419         [Bluetooth, On-board computer, Radio, USB]
# 7213   [Bluetooth, Digital radio, Hands-free equipmen...
# 15853  [Bluetooth, Digital radio, Hands-free equipmen...
#
#                                               \nExtras\n  \
# 8805                                                 NaN
# 1860    [Alloy wheels, Cab or rented Car, Voice Control]
# 6019                    [Catalytic Converter, Roof rack]
# 2872                                                 NaN
# 1674   [Alloy wheels, Sport package, Sport seats, Spo...
# 11356            [Alloy wheels, Roof rack, Touch screen]
# 1765   [Alloy wheels, Sport package, Sport suspension...
# 13419                          [Alloy wheels, Roof rack]
# 7213   [Alloy wheels, Roof rack, Touch screen, Voice ...
# 15853  [Alloy wheels, Catalytic Converter, Voice Cont...
#
#                                    \nSafety & Security\n  \
# 8805                                                 NaN
# 1860   [ABS, Central door lock, Daytime running light...
# 6019   [ABS, Central door lock, Daytime running light...
# 2872   [ABS, Central door lock, Fog lights, Immobiliz...
# 1674   [ABS, Central door lock, Daytime running light...
# 11356  [ABS, Adaptive headlights, Central door lock, ...
# 1765   [ABS, Adaptive headlights, Alarm system, Centr...
# 13419  [ABS, Central door lock, Driver-side airbag, E...
# 7213   [ABS, Central door lock, Daytime running light...
# 15853  [ABS, Adaptive Cruise Control, Blind spot moni...
#
#                                              description Emission Label  \
# 8805   [\nOpel Corsa 1. 3 CDTi 75cv 5p. Coche en perf...            NaN
# 1860   [\n, Highlights: , Qualitätssiegel GW:plus, 1....            NaN
# 6019   [\n, Getriebe:,  Automatik, Technik:,  Bordcom...            NaN
# 2872   [\n2.0 TDI 150 Business Line S tronic 6, diese...            NaN
# 1674   [\n, Ansprechpartner:, Ante Brajkovic 0881 604...            NaN
# 11356  [\n, Komfortpaket mit Rückfahrkamera,,  , sens...            NaN
# 1765   [\n, navigazione MMI, Compreso luce allo xeno ...            NaN
# 13419  [\nRenault CLIO Limited Energy dCi 66 KW (90 C...            NaN
# 7213   [\n, Sonderausstattung:, DAB-Tuner (Radioempfa...            NaN
# 15853                                                 []            NaN
#
#          Gears Country version Electricity consumption  \
# 8805   [\n5\n]             NaN                     NaN
# 1860       NaN   [\nGermany\n]                     NaN
# 6019   [\n6\n]   [\nGermany\n]                     NaN
# 2872       NaN             NaN                     NaN
# 1674       NaN   [\nGermany\n]                     NaN
# 11356      NaN   [\nGermany\n]                     NaN
# 1765   [\n5\n]     [\nItaly\n]                     NaN
# 13419  [\n6\n]             NaN                     NaN
# 7213       NaN   [\nBelgium\n]                     NaN
# 15853  [\n6\n]   [\nBelgium\n]                     NaN
#
#                            Last Service Date Other Fuel Types Availability  \
# 8805                                     NaN              NaN          NaN
# 1860                                     NaN              NaN          NaN
# 6019                                     NaN              NaN          NaN
# 2872                                     NaN              NaN          NaN
# 1674                                     NaN              NaN          NaN
# 11356                                    NaN              NaN          NaN
# 1765   [\n01/2019\n, \n91 g CO2/km (comb)\n]              NaN          NaN
# 13419                                    NaN              NaN          NaN
# 7213                                     NaN              NaN          NaN
# 15853                                    NaN              NaN          NaN
#
#       Last Timing Belt Service Date Available from
# 8805                            NaN            NaN
# 1860                            NaN            NaN
# 6019                            NaN            NaN
# 2872                            NaN            NaN
# 1674                            NaN            NaN
# 11356                           NaN            NaN
# 1765                            NaN            NaN
# 13419                           NaN            NaN
# 7213                            NaN            NaN
# 15853                           NaN            NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  kW  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners NaN
# 1      Price negotiable  80,000 km      03/2017               None NaN
# 2        VAT deductible  83,450 km      02/2016   1 previous owner NaN
# 3                  None  73,000 km      08/2016   1 previous owner NaN
# 4                  None  16,200 km      05/2016   1 previous owner NaN
# ...                 ...        ...          ...                ...  ..
# 15914    VAT deductible       - km          -/-               None NaN
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner NaN
# 15916    VAT deductible      15 km      03/2019   1 previous owner NaN
# 15917    VAT deductible      10 km      06/2019               None NaN
# 15918    VAT deductible       - km      01/2019   1 previous owner NaN
#
#            hp                                               Type  \
# 0       66 kW            [, Used, , Diesel (Particulate Filter)]
# 1      141 kW                               [, Used, , Gasoline]
# 2       85 kW            [, Used, , Diesel (Particulate Filter)]
# 3       66 kW            [, Used, , Diesel (Particulate Filter)]
# 4       66 kW            [, Used, , Diesel (Particulate Filter)]
# ...       ...                                                ...
# 15914  147 kW             [, New, , Diesel (Particulate Filter)]
# 15915  165 kW  [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916  146 kW                       [, Pre-registered, , Diesel]
# 15917  147 kW                       [, Pre-registered, , Diesel]
# 15918  165 kW                      [, Demonstration, , Super 95]
#
#                                          Previous Owners  \
# 0                                                  \n2\n
# 1                                                    NaN
# 2                                                  \n1\n
# 3                                                  \n1\n
# 4                                                  \n1\n
# ...                                                  ...
# 15914                                                NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                NaN
# 15918                                              \n1\n
#
#                               Next Inspection  \
# 0       [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15914                                     NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15916                                     NaN
# 15917                                     NaN
# 15918                                     NaN
#
#                            Inspection new                          Warranty  \
# 0                   [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
# 1                                     NaN                               NaN
# 2                                     NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 3                                     NaN                               NaN
# 4      [\nYes\n, \n109 g CO2/km (comb)\n]              [\n, \n, \nEuro 6\n]
# ...                                   ...                               ...
# 15914                                 NaN                     \n24 months\n
# 15915                                 NaN              [\n, \n, \nEuro 6\n]
# 15916         [\nYes\n, \nEuro 6d-TEMP\n]           [\n, \n, \n4 (Green)\n]
# 15917                                 NaN                                \n
# 15918  [\nYes\n, \n153 g CO2/km (comb)\n]                               NaN
#
#                            Full Service      Non-smoking Vehicle null  \
# 0                              [\n, \n]                 [\n, \n]   []
# 1                                   NaN                      NaN   []
# 2                                   NaN                      NaN   []
# 3      [\n, \n, \n99 g CO2/km (comb)\n]     [\n, \n, \nEuro 6\n]   []
# 4               [\n, \n, \n4 (Green)\n]                 [\n, \n]   []
# ...                                 ...                      ...  ...
# 15914                               NaN                      NaN   []
# 15915                               NaN  [\n, \n, \n4 (Green)\n]   []
# 15916                          [\n, \n]                 [\n, \n]   []
# 15917                               NaN                      NaN   []
# 15918                               NaN                      NaN   []
#
#               Make             Model          Offer Number First Registration  \
# 0         \nAudi\n      [\n, A1, \n]       [\nLR-062483\n]     [\n, 2016, \n]
# 1         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2017, \n]
# 2         \nAudi\n      [\n, A1, \n]        [\nAM-95365\n]     [\n, 2016, \n]
# 3         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2016, \n]
# 4         \nAudi\n      [\n, A1, \n]           [\nC1626\n]     [\n, 2016, \n]
# ...            ...               ...                   ...                ...
# 15914  \nRenault\n  [\n, Espace, \n]        [\n10988301\n]                NaN
# 15915  \nRenault\n  [\n, Espace, \n]     [\n507370_3223\n]     [\n, 2019, \n]
# 15916  \nRenault\n  [\n, Espace, \n]        [\nEspace16\n]     [\n, 2019, \n]
# 15917  \nRenault\n  [\n, Espace, \n]         [\n2691331\n]     [\n, 2019, \n]
# 15918  \nRenault\n  [\n, Espace, \n]  [\nRe_30000008029\n]     [\n, 2019, \n]
#
#             Body Color      Paint Type           Body Color Original  \
# 0      [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1        [\n, Red, \n]             NaN                           NaN
# 2      [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
# 3      [\n, Brown, \n]  [\nMetallic\n]                           NaN
# 4      [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz Metallic\n]
# ...                ...             ...                           ...
# 15914   [\n, Grey, \n]  [\nMetallic\n]            [\nGrigio scuro\n]
# 15915   [\n, Grey, \n]  [\nMetallic\n]     [\nStahl-Grau Metallic\n]
# 15916  [\n, White, \n]             NaN             [\narktis-weiß\n]
# 15917   [\n, Grey, \n]             NaN                  [\nGrigio\n]
# 15918   [\n, Grey, \n]  [\nMetallic\n]  [\nTitanium-Grau Metallic\n]
#
#                       Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1              [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
# 3                            NaN  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 4             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# ...                          ...               ...          ...          ...
# 15914                        NaN     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15915                [\nCloth\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15916  [\nFull leather, Black\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15917         [\nPart leather\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15918  [\nFull leather, Brown\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
#
#            Model Code         Gearing Type    Displacement Cylinders  \
# 0      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1      [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2                 NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
# 3                 NaN  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 4      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# ...               ...                  ...             ...       ...
# 15914             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15915  [\n0000/000\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 15916             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15917             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15918  [\n3333/BHJ\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
#
#                Weight  Drive chain  \
# 0      [\n1,220 kg\n]  [\nfront\n]
# 1      [\n1,255 kg\n]  [\nfront\n]
# 2                 NaN  [\nfront\n]
# 3      [\n1,195 kg\n]          NaN
# 4                 NaN  [\nfront\n]
# ...               ...          ...
# 15914  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,708 kg\n]  [\nfront\n]
# 15916             NaN  [\nfront\n]
# 15917  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                     Fuel  \
# 0                  [\n, Diesel (Particulate Filter), \n]
# 1                                     [\n, Gasoline, \n]
# 2                  [\n, Diesel (Particulate Filter), \n]
# 3                  [\n, Diesel (Particulate Filter), \n]
# 4                  [\n, Diesel (Particulate Filter), \n]
# ...                                                  ...
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                              Consumption  \
# 0      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1      [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2      [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4      [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# ...                                                  ...
# 15914  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918  [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
#
#                     CO2 Emission      Emission Class  \
# 0       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 1      [\n129 g CO2/km (comb)\n]        [\nEuro 6\n]
# 2       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 3       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 4      [\n109 g CO2/km (comb)\n]        [\nEuro 6\n]
# ...                          ...                 ...
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                \nComfort & Convenience\n  \
# 0      [Air conditioning, Armrest, Automatic climate ...
# 1      [Air conditioning, Automatic climate control, ...
# 2      [Air conditioning, Cruise control, Electrical ...
# 3      [Air suspension, Armrest, Auxiliary heating, E...
# 4      [Air conditioning, Armrest, Automatic climate ...
# ...                                                  ...
# 15914  [Air conditioning, Automatic climate control, ...
# 15915  [Air conditioning, Automatic climate control, ...
# 15916  [Air conditioning, Armrest, Automatic climate ...
# 15917  [Air conditioning, Automatic climate control, ...
# 15918  [Air conditioning, Automatic climate control, ...
#
#                                \nEntertainment & Media\n  \
# 0      [Bluetooth, Hands-free equipment, On-board com...
# 1      [Bluetooth, Hands-free equipment, On-board com...
# 2                               [MP3, On-board computer]
# 3      [Bluetooth, CD player, Hands-free equipment, M...
# 4      [Bluetooth, CD player, Hands-free equipment, M...
# ...                                                  ...
# 15914  [Bluetooth, Digital radio, Hands-free equipmen...
# 15915  [Bluetooth, Digital radio, Hands-free equipmen...
# 15916  [Bluetooth, Hands-free equipment, On-board com...
# 15917             [Bluetooth, Digital radio, Radio, USB]
# 15918                                              [USB]
#
#                                               \nExtras\n  \
# 0      [Alloy wheels, Catalytic Converter, Voice Cont...
# 1      [Alloy wheels, Sport seats, Sport suspension, ...
# 2                          [Alloy wheels, Voice Control]
# 3             [Alloy wheels, Sport seats, Voice Control]
# 4      [Alloy wheels, Sport package, Sport suspension...
# ...                                                  ...
# 15914                       [Alloy wheels, Touch screen]
# 15915        [Alloy wheels, Touch screen, Voice Control]
# 15916                                     [Alloy wheels]
# 15917                       [Alloy wheels, Touch screen]
# 15918                       [Alloy wheels, Touch screen]
#
#                                    \nSafety & Security\n  \
# 0      [ABS, Central door lock, Daytime running light...
# 1      [ABS, Central door lock, Central door lock wit...
# 2      [ABS, Central door lock, Daytime running light...
# 3      [ABS, Alarm system, Central door lock with rem...
# 4      [ABS, Central door lock, Driver-side airbag, E...
# ...                                                  ...
# 15914  [ABS, Central door lock, Central door lock wit...
# 15915  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918  [ABS, Blind spot monitor, Daytime running ligh...
#
#                                              description   Emission Label  \
# 0      [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1      [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2      [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3      [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4      [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
# ...                                                  ...              ...
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption Last Service Date  \
# 0          NaN             NaN                     NaN               NaN
# 1      [\n7\n]             NaN                     NaN               NaN
# 2          NaN             NaN                     NaN               NaN
# 3      [\n6\n]             NaN                     NaN               NaN
# 4          NaN   [\nGermany\n]                     NaN               NaN
# ...        ...             ...                     ...               ...
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]>

# %%
# Changing column names
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
# !pip install skimpy
from skimpy import clean_columns

# columns = df.columns

# messy_df = pd.DataFrame(data = [], columns = columns, index = [0])
# print(messy_df)
# clean_df = clean_columns(messy_df)
# clean_df.columns.tolist()

# %%
df= clean_columns(df)  # cleaning column names using skimpy clean_columns method
# Out:
# 42 column names have been cleaned

# %%
# df.nunique()  # Kolonlarda liste olduğu için çalışmıyor

# %%
df.warranty.str.strip("[")
# Out:
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#              ...
# 15914    \n24 months\n
# 15915              NaN
# 15916              NaN
# 15917               \n
# 15918              NaN
# Name: warranty, Length: 15919, dtype: object

# %%
df.null.str.lstrip("[")
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 15914   NaN
# 15915   NaN
# 15916   NaN
# 15917   NaN
# 15918   NaN
# Name: null, Length: 15919, dtype: float64

# %%
df.type.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 5231, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [, Used, , Diesel (Particulate Filter)]                                                                                 3475
# [, Used, , Diesel]                                                                                                      2516
# [, Used, , Gasoline]                                                                                                    2367
# [, Used, , Super 95]                                                                                                    1818
# [, Pre-registered, , Super 95]                                                                                           500
#                                                                                                                         ...
# [, New, , Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95]       1
# [, Used, , Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)]                               1
# [, Demonstration, , Super Plus 98]                                                                                         1
# [, New, , Super Plus E10 98]                                                                                               1
# [, Demonstration, , Regular/Benzine E10 91]                                                                                1
# Name: type, Length: 170, dtype: int64

# %%
df.type.apply(lambda x : ",".join(x) if isinstance(x, list) else x)
# Out:
# 0                       ,Used,,Diesel (Particulate Filter)
# 1                                          ,Used,,Gasoline
# 2                       ,Used,,Diesel (Particulate Filter)
# 3                       ,Used,,Diesel (Particulate Filter)
# 4                       ,Used,,Diesel (Particulate Filter)
#                                ...
# 15914                    ,New,,Diesel (Particulate Filter)
# 15915    ,Used,,Super 95 / Super Plus 98 (Particulate F...
# 15916                              ,Pre-registered,,Diesel
# 15917                              ,Pre-registered,,Diesel
# 15918                             ,Demonstration,,Super 95
# Name: type, Length: 15919, dtype: object

# %%
df.type.apply(lambda x : str(x) if isinstance(x, list) else x)
# Out:
# 0          ['', 'Used', '', 'Diesel (Particulate Filter)']
# 1                             ['', 'Used', '', 'Gasoline']
# 2          ['', 'Used', '', 'Diesel (Particulate Filter)']
# 3          ['', 'Used', '', 'Diesel (Particulate Filter)']
# 4          ['', 'Used', '', 'Diesel (Particulate Filter)']
#                                ...
# 15914       ['', 'New', '', 'Diesel (Particulate Filter)']
# 15915    ['', 'Used', '', 'Super 95 / Super Plus 98 (Pa...
# 15916                 ['', 'Pre-registered', '', 'Diesel']
# 15917                 ['', 'Pre-registered', '', 'Diesel']
# 15918                ['', 'Demonstration', '', 'Super 95']
# Name: type, Length: 15919, dtype: object

# %%
# Kolonlarda liste içindeki verilerin listeden çıkarılması

df.apply(lambda x: ",".join(x) if isinstance(x, list) else x)
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  k_w  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners  NaN
# 1      Price negotiable  80,000 km      03/2017               None  NaN
# 2        VAT deductible  83,450 km      02/2016   1 previous owner  NaN
# 3                  None  73,000 km      08/2016   1 previous owner  NaN
# 4                  None  16,200 km      05/2016   1 previous owner  NaN
# ...                 ...        ...          ...                ...  ...
# 15914    VAT deductible       - km          -/-               None  NaN
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner  NaN
# 15916    VAT deductible      15 km      03/2019   1 previous owner  NaN
# 15917    VAT deductible      10 km      06/2019               None  NaN
# 15918    VAT deductible       - km      01/2019   1 previous owner  NaN
#
#            hp                                               type  \
# 0       66 kW            [, Used, , Diesel (Particulate Filter)]
# 1      141 kW                               [, Used, , Gasoline]
# 2       85 kW            [, Used, , Diesel (Particulate Filter)]
# 3       66 kW            [, Used, , Diesel (Particulate Filter)]
# 4       66 kW            [, Used, , Diesel (Particulate Filter)]
# ...       ...                                                ...
# 15914  147 kW             [, New, , Diesel (Particulate Filter)]
# 15915  165 kW  [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916  146 kW                       [, Pre-registered, , Diesel]
# 15917  147 kW                       [, Pre-registered, , Diesel]
# 15918  165 kW                      [, Demonstration, , Super 95]
#
#                                          previous_owners  \
# 0                                                  \n2\n
# 1                                                    NaN
# 2                                                  \n1\n
# 3                                                  \n1\n
# 4                                                  \n1\n
# ...                                                  ...
# 15914                                                NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                NaN
# 15918                                              \n1\n
#
#                               next_inspection  \
# 0       [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15914                                     NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15916                                     NaN
# 15917                                     NaN
# 15918                                     NaN
#
#                            inspection_new                          warranty  \
# 0                   [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
# 1                                     NaN                               NaN
# 2                                     NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 3                                     NaN                               NaN
# 4      [\nYes\n, \n109 g CO2/km (comb)\n]              [\n, \n, \nEuro 6\n]
# ...                                   ...                               ...
# 15914                                 NaN                     \n24 months\n
# 15915                                 NaN              [\n, \n, \nEuro 6\n]
# 15916         [\nYes\n, \nEuro 6d-TEMP\n]           [\n, \n, \n4 (Green)\n]
# 15917                                 NaN                                \n
# 15918  [\nYes\n, \n153 g CO2/km (comb)\n]                               NaN
#
#                            full_service      non_smoking_vehicle null  \
# 0                              [\n, \n]                 [\n, \n]   []
# 1                                   NaN                      NaN   []
# 2                                   NaN                      NaN   []
# 3      [\n, \n, \n99 g CO2/km (comb)\n]     [\n, \n, \nEuro 6\n]   []
# 4               [\n, \n, \n4 (Green)\n]                 [\n, \n]   []
# ...                                 ...                      ...  ...
# 15914                               NaN                      NaN   []
# 15915                               NaN  [\n, \n, \n4 (Green)\n]   []
# 15916                          [\n, \n]                 [\n, \n]   []
# 15917                               NaN                      NaN   []
# 15918                               NaN                      NaN   []
#
#               make             model          offer_number first_registration  \
# 0         \nAudi\n      [\n, A1, \n]       [\nLR-062483\n]     [\n, 2016, \n]
# 1         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2017, \n]
# 2         \nAudi\n      [\n, A1, \n]        [\nAM-95365\n]     [\n, 2016, \n]
# 3         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2016, \n]
# 4         \nAudi\n      [\n, A1, \n]           [\nC1626\n]     [\n, 2016, \n]
# ...            ...               ...                   ...                ...
# 15914  \nRenault\n  [\n, Espace, \n]        [\n10988301\n]                NaN
# 15915  \nRenault\n  [\n, Espace, \n]     [\n507370_3223\n]     [\n, 2019, \n]
# 15916  \nRenault\n  [\n, Espace, \n]        [\nEspace16\n]     [\n, 2019, \n]
# 15917  \nRenault\n  [\n, Espace, \n]         [\n2691331\n]     [\n, 2019, \n]
# 15918  \nRenault\n  [\n, Espace, \n]  [\nRe_30000008029\n]     [\n, 2019, \n]
#
#             body_color      paint_type           body_color_original  \
# 0      [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1        [\n, Red, \n]             NaN                           NaN
# 2      [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
# 3      [\n, Brown, \n]  [\nMetallic\n]                           NaN
# 4      [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz Metallic\n]
# ...                ...             ...                           ...
# 15914   [\n, Grey, \n]  [\nMetallic\n]            [\nGrigio scuro\n]
# 15915   [\n, Grey, \n]  [\nMetallic\n]     [\nStahl-Grau Metallic\n]
# 15916  [\n, White, \n]             NaN             [\narktis-weiß\n]
# 15917   [\n, Grey, \n]             NaN                  [\nGrigio\n]
# 15918   [\n, Grey, \n]  [\nMetallic\n]  [\nTitanium-Grau Metallic\n]
#
#                       upholstery              body nr_of_doors nr_of_seats  \
# 0             [\nCloth, Black\n]  [\n, Sedans, \n]     [\n5\n]     [\n5\n]
# 1              [\nCloth, Grey\n]  [\n, Sedans, \n]     [\n3\n]     [\n4\n]
# 2             [\nCloth, Black\n]  [\n, Sedans, \n]     [\n4\n]     [\n4\n]
# 3                            NaN  [\n, Sedans, \n]     [\n3\n]     [\n4\n]
# 4             [\nCloth, Black\n]  [\n, Sedans, \n]     [\n5\n]     [\n5\n]
# ...                          ...               ...         ...         ...
# 15914                        NaN     [\n, Van, \n]     [\n5\n]     [\n5\n]
# 15915                [\nCloth\n]     [\n, Van, \n]     [\n5\n]     [\n5\n]
# 15916  [\nFull leather, Black\n]     [\n, Van, \n]     [\n5\n]     [\n7\n]
# 15917         [\nPart leather\n]     [\n, Van, \n]     [\n5\n]     [\n7\n]
# 15918  [\nFull leather, Brown\n]     [\n, Van, \n]     [\n5\n]     [\n5\n]
#
#            model_code         gearing_type    displacement cylinders  \
# 0      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1      [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2                 NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
# 3                 NaN  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 4      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# ...               ...                  ...             ...       ...
# 15914             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15915  [\n0000/000\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 15916             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15917             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15918  [\n3333/BHJ\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
#
#                weight  drive_chain  \
# 0      [\n1,220 kg\n]  [\nfront\n]
# 1      [\n1,255 kg\n]  [\nfront\n]
# 2                 NaN  [\nfront\n]
# 3      [\n1,195 kg\n]          NaN
# 4                 NaN  [\nfront\n]
# ...               ...          ...
# 15914  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,708 kg\n]  [\nfront\n]
# 15916             NaN  [\nfront\n]
# 15917  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                     fuel  \
# 0                  [\n, Diesel (Particulate Filter), \n]
# 1                                     [\n, Gasoline, \n]
# 2                  [\n, Diesel (Particulate Filter), \n]
# 3                  [\n, Diesel (Particulate Filter), \n]
# 4                  [\n, Diesel (Particulate Filter), \n]
# ...                                                  ...
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                              consumption  \
# 0      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1      [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2      [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4      [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# ...                                                  ...
# 15914  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918  [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
#
#                    co_2_emission      emission_class  \
# 0       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 1      [\n129 g CO2/km (comb)\n]        [\nEuro 6\n]
# 2       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 3       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 4      [\n109 g CO2/km (comb)\n]        [\nEuro 6\n]
# ...                          ...                 ...
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                    comfort_&_convenience  \
# 0      [Air conditioning, Armrest, Automatic climate ...
# 1      [Air conditioning, Automatic climate control, ...
# 2      [Air conditioning, Cruise control, Electrical ...
# 3      [Air suspension, Armrest, Auxiliary heating, E...
# 4      [Air conditioning, Armrest, Automatic climate ...
# ...                                                  ...
# 15914  [Air conditioning, Automatic climate control, ...
# 15915  [Air conditioning, Automatic climate control, ...
# 15916  [Air conditioning, Armrest, Automatic climate ...
# 15917  [Air conditioning, Automatic climate control, ...
# 15918  [Air conditioning, Automatic climate control, ...
#
#                                    entertainment_&_media  \
# 0      [Bluetooth, Hands-free equipment, On-board com...
# 1      [Bluetooth, Hands-free equipment, On-board com...
# 2                               [MP3, On-board computer]
# 3      [Bluetooth, CD player, Hands-free equipment, M...
# 4      [Bluetooth, CD player, Hands-free equipment, M...
# ...                                                  ...
# 15914  [Bluetooth, Digital radio, Hands-free equipmen...
# 15915  [Bluetooth, Digital radio, Hands-free equipmen...
# 15916  [Bluetooth, Hands-free equipment, On-board com...
# 15917             [Bluetooth, Digital radio, Radio, USB]
# 15918                                              [USB]
#
#                                                   extras  \
# 0      [Alloy wheels, Catalytic Converter, Voice Cont...
# 1      [Alloy wheels, Sport seats, Sport suspension, ...
# 2                          [Alloy wheels, Voice Control]
# 3             [Alloy wheels, Sport seats, Voice Control]
# 4      [Alloy wheels, Sport package, Sport suspension...
# ...                                                  ...
# 15914                       [Alloy wheels, Touch screen]
# 15915        [Alloy wheels, Touch screen, Voice Control]
# 15916                                     [Alloy wheels]
# 15917                       [Alloy wheels, Touch screen]
# 15918                       [Alloy wheels, Touch screen]
#
#                                        safety_&_security  \
# 0      [ABS, Central door lock, Daytime running light...
# 1      [ABS, Central door lock, Central door lock wit...
# 2      [ABS, Central door lock, Daytime running light...
# 3      [ABS, Alarm system, Central door lock with rem...
# 4      [ABS, Central door lock, Driver-side airbag, E...
# ...                                                  ...
# 15914  [ABS, Central door lock, Central door lock wit...
# 15915  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918  [ABS, Blind spot monitor, Daytime running ligh...
#
#                                              description   emission_label  \
# 0      [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1      [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2      [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3      [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4      [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
# ...                                                  ...              ...
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          gears country_version electricity_consumption last_service_date  \
# 0          NaN             NaN                     NaN               NaN
# 1      [\n7\n]             NaN                     NaN               NaN
# 2          NaN             NaN                     NaN               NaN
# 3      [\n6\n]             NaN                     NaN               NaN
# 4          NaN   [\nGermany\n]                     NaN               NaN
# ...        ...             ...                     ...               ...
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       other_fuel_types                   availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       last_timing_belt_service_date available_from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %%
df.applymap(lambda x: str(x) if type(x)==list else x).type.str.extract(r"\[(.+)\]")
# Out:
#                                                        0
# 0          '', 'Used', '', 'Diesel (Particulate Filter)'
# 1                             '', 'Used', '', 'Gasoline'
# 2          '', 'Used', '', 'Diesel (Particulate Filter)'
# 3          '', 'Used', '', 'Diesel (Particulate Filter)'
# 4          '', 'Used', '', 'Diesel (Particulate Filter)'
# ...                                                  ...
# 15914       '', 'New', '', 'Diesel (Particulate Filter)'
# 15915  '', 'Used', '', 'Super 95 / Super Plus 98 (Par...
# 15916                 '', 'Pre-registered', '', 'Diesel'
# 15917                 '', 'Pre-registered', '', 'Diesel'
# 15918                '', 'Demonstration', '', 'Super 95'
#
# [15919 rows x 1 columns]

# %%
df.consumption.str.extract(r"(\[.+\]),(\[.+\])")
# Out:
#          0    1
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# 4      NaN  NaN
# ...    ...  ...
# 15914  NaN  NaN
# 15915  NaN  NaN
# 15916  NaN  NaN
# 15917  NaN  NaN
# 15918  NaN  NaN
#
# [15919 rows x 2 columns]

# %%
df.consumption.head(10)
# Out:
# 0    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1    [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2    [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4    [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# 5    [[3.5 l/100 km (comb)], [4.3 l/100 km (city)],...
# 6    [[3.7 l/100 km (comb)], [4.3 l/100 km (city)],...
# 7    [[3.7 l/100 km (comb)], [4.2 l/100 km (city)],...
# 8    [[3.7 l/100 km (comb)], [4.3 l/100 km (city)],...
# 9                                                  NaN
# Name: consumption, dtype: object

# %%
df.consumption.str.join(",")
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 15914                                                  NaN
# 15915    \n,7.4 l/100 km (comb),\n,9.2 l/100 km (city),...
# 15916                                                  NaN
# 15917                                                  NaN
# 15918                                                  NaN
# Name: consumption, Length: 15919, dtype: object

# %%
# Bu kod yeni notbook'a alınacak

df = df.applymap(lambda x: ','.join(map(str, x)) if isinstance(x, list) else x)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  k_w  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners  NaN
# 1      Price negotiable  80,000 km      03/2017               None  NaN
# 2        VAT deductible  83,450 km      02/2016   1 previous owner  NaN
# 3                  None  73,000 km      08/2016   1 previous owner  NaN
# 4                  None  16,200 km      05/2016   1 previous owner  NaN
# ...                 ...        ...          ...                ...  ...
# 15914    VAT deductible       - km          -/-               None  NaN
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner  NaN
# 15916    VAT deductible      15 km      03/2019   1 previous owner  NaN
# 15917    VAT deductible      10 km      06/2019               None  NaN
# 15918    VAT deductible       - km      01/2019   1 previous owner  NaN
#
#            hp                                               type  \
# 0       66 kW                 ,Used,,Diesel (Particulate Filter)
# 1      141 kW                                    ,Used,,Gasoline
# 2       85 kW                 ,Used,,Diesel (Particulate Filter)
# 3       66 kW                 ,Used,,Diesel (Particulate Filter)
# 4       66 kW                 ,Used,,Diesel (Particulate Filter)
# ...       ...                                                ...
# 15914  147 kW                  ,New,,Diesel (Particulate Filter)
# 15915  165 kW  ,Used,,Super 95 / Super Plus 98 (Particulate F...
# 15916  146 kW                            ,Pre-registered,,Diesel
# 15917  147 kW                            ,Pre-registered,,Diesel
# 15918  165 kW                           ,Demonstration,,Super 95
#
#                                          previous_owners  \
# 0                                                  \n2\n
# 1                                                    NaN
# 2                                                  \n1\n
# 3                                                  \n1\n
# 4                                                  \n1\n
# ...                                                  ...
# 15914                                                NaN
# 15915  \n1\n,\n,7.4 l/100 km (comb),\n,9.2 l/100 km (...
# 15916                      \n1\n,\n139 g CO2/km (comb)\n
# 15917                                                NaN
# 15918                                              \n1\n
#
#                            next_inspection                   inspection_new  \
# 0       \n06/2021\n,\n99 g CO2/km (comb)\n               \nYes\n,\nEuro 6\n
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN  \nYes\n,\n109 g CO2/km (comb)\n
# ...                                    ...                              ...
# 15914                                  NaN                              NaN
# 15915  \n01/2022\n,\n168 g CO2/km (comb)\n                              NaN
# 15916                                  NaN         \nYes\n,\nEuro 6d-TEMP\n
# 15917                                  NaN                              NaN
# 15918                                  NaN  \nYes\n,\n153 g CO2/km (comb)\n
#
#                            warranty                  full_service  \
# 0               \n,\n,\n4 (Green)\n                         \n,\n
# 1                               NaN                           NaN
# 2      \n,\n,\n99 g CO2/km (comb)\n                           NaN
# 3                               NaN  \n,\n,\n99 g CO2/km (comb)\n
# 4                  \n,\n,\nEuro 6\n           \n,\n,\n4 (Green)\n
# ...                             ...                           ...
# 15914                 \n24 months\n                           NaN
# 15915              \n,\n,\nEuro 6\n                           NaN
# 15916           \n,\n,\n4 (Green)\n                         \n,\n
# 15917                            \n                           NaN
# 15918                           NaN                           NaN
#
#        non_smoking_vehicle null         make         model  \
# 0                    \n,\n          \nAudi\n      \n,A1,\n
# 1                      NaN          \nAudi\n      \n,A1,\n
# 2                      NaN          \nAudi\n      \n,A1,\n
# 3         \n,\n,\nEuro 6\n          \nAudi\n      \n,A1,\n
# 4                    \n,\n          \nAudi\n      \n,A1,\n
# ...                    ...  ...          ...           ...
# 15914                  NaN       \nRenault\n  \n,Espace,\n
# 15915  \n,\n,\n4 (Green)\n       \nRenault\n  \n,Espace,\n
# 15916                \n,\n       \nRenault\n  \n,Espace,\n
# 15917                  NaN       \nRenault\n  \n,Espace,\n
# 15918                  NaN       \nRenault\n  \n,Espace,\n
#
#              offer_number first_registration   body_color    paint_type  \
# 0           \nLR-062483\n         \n,2016,\n  \n,Black,\n  \nMetallic\n
# 1                     NaN         \n,2017,\n    \n,Red,\n           NaN
# 2            \nAM-95365\n         \n,2016,\n  \n,Black,\n  \nMetallic\n
# 3                     NaN         \n,2016,\n  \n,Brown,\n  \nMetallic\n
# 4               \nC1626\n         \n,2016,\n  \n,Black,\n  \nMetallic\n
# ...                   ...                ...          ...           ...
# 15914        \n10988301\n                NaN   \n,Grey,\n  \nMetallic\n
# 15915     \n507370_3223\n         \n,2019,\n   \n,Grey,\n  \nMetallic\n
# 15916        \nEspace16\n         \n,2019,\n  \n,White,\n           NaN
# 15917         \n2691331\n         \n,2019,\n   \n,Grey,\n           NaN
# 15918  \nRe_30000008029\n         \n,2019,\n   \n,Grey,\n  \nMetallic\n
#
#               body_color_original               upholstery          body  \
# 0               \nMythosschwarz\n         \nCloth, Black\n  \n,Sedans,\n
# 1                             NaN          \nCloth, Grey\n  \n,Sedans,\n
# 2      \nmythosschwarz metallic\n         \nCloth, Black\n  \n,Sedans,\n
# 3                             NaN                      NaN  \n,Sedans,\n
# 4      \nMythosschwarz Metallic\n         \nCloth, Black\n  \n,Sedans,\n
# ...                           ...                      ...           ...
# 15914            \nGrigio scuro\n                      NaN     \n,Van,\n
# 15915     \nStahl-Grau Metallic\n                \nCloth\n     \n,Van,\n
# 15916             \narktis-weiß\n  \nFull leather, Black\n     \n,Van,\n
# 15917                  \nGrigio\n         \nPart leather\n     \n,Van,\n
# 15918  \nTitanium-Grau Metallic\n  \nFull leather, Brown\n     \n,Van,\n
#
#       nr_of_doors nr_of_seats    model_code     gearing_type  displacement  \
# 0           \n5\n       \n5\n  \n0588/BDF\n  \n,Automatic,\n  \n1,422 cc\n
# 1           \n3\n       \n4\n  \n0588/BCY\n  \n,Automatic,\n  \n1,798 cc\n
# 2           \n4\n       \n4\n           NaN  \n,Automatic,\n  \n1,598 cc\n
# 3           \n3\n       \n4\n           NaN  \n,Automatic,\n  \n1,422 cc\n
# 4           \n5\n       \n5\n  \n0588/BDF\n  \n,Automatic,\n  \n1,422 cc\n
# ...           ...         ...           ...              ...           ...
# 15914       \n5\n       \n5\n           NaN  \n,Automatic,\n  \n1,997 cc\n
# 15915       \n5\n       \n5\n  \n0000/000\n  \n,Automatic,\n  \n1,798 cc\n
# 15916       \n5\n       \n7\n           NaN  \n,Automatic,\n  \n1,997 cc\n
# 15917       \n5\n       \n7\n           NaN  \n,Automatic,\n  \n1,997 cc\n
# 15918       \n5\n       \n5\n  \n3333/BHJ\n  \n,Automatic,\n  \n1,798 cc\n
#
#       cylinders        weight drive_chain  \
# 0         \n3\n  \n1,220 kg\n   \nfront\n
# 1         \n4\n  \n1,255 kg\n   \nfront\n
# 2           NaN           NaN   \nfront\n
# 3         \n3\n  \n1,195 kg\n         NaN
# 4         \n3\n           NaN   \nfront\n
# ...         ...           ...         ...
# 15914     \n4\n  \n1,758 kg\n   \nfront\n
# 15915     \n4\n  \n1,708 kg\n   \nfront\n
# 15916     \n4\n           NaN   \nfront\n
# 15917     \n4\n  \n1,758 kg\n   \nfront\n
# 15918     \n4\n  \n1,685 kg\n     \n4WD\n
#
#                                                     fuel  \
# 0                      \n,Diesel (Particulate Filter),\n
# 1                                         \n,Gasoline,\n
# 2                      \n,Diesel (Particulate Filter),\n
# 3                      \n,Diesel (Particulate Filter),\n
# 4                      \n,Diesel (Particulate Filter),\n
# ...                                                  ...
# 15914                  \n,Diesel (Particulate Filter),\n
# 15915  \n,Super 95 / Super Plus 98 (Particulate Filte...
# 15916                                       \n,Diesel,\n
# 15917                                       \n,Diesel,\n
# 15918                                     \n,Super 95,\n
#
#                                              consumption  \
# 0      ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...
# 1      ['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'...
# 2      ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'...
# 3      ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'...
# 4      ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'...
# ...                                                  ...
# 15914  ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'...
# 15915  \n,7.4 l/100 km (comb),\n,9.2 l/100 km (city),...
# 15916  ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'...
# 15917  ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'...
# 15918  ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'...
#
#                  co_2_emission    emission_class  \
# 0       \n99 g CO2/km (comb)\n        \nEuro 6\n
# 1      \n129 g CO2/km (comb)\n        \nEuro 6\n
# 2       \n99 g CO2/km (comb)\n        \nEuro 6\n
# 3       \n99 g CO2/km (comb)\n        \nEuro 6\n
# 4      \n109 g CO2/km (comb)\n        \nEuro 6\n
# ...                        ...               ...
# 15914  \n139 g CO2/km (comb)\n               NaN
# 15915  \n168 g CO2/km (comb)\n               NaN
# 15916  \n139 g CO2/km (comb)\n  \nEuro 6d-TEMP\n
# 15917  \n139 g CO2/km (comb)\n        \nEuro 6\n
# 15918  \n153 g CO2/km (comb)\n        \nEuro 6\n
#
#                                    comfort_&_convenience  \
# 0      Air conditioning,Armrest,Automatic climate con...
# 1      Air conditioning,Automatic climate control,Hil...
# 2      Air conditioning,Cruise control,Electrical sid...
# 3      Air suspension,Armrest,Auxiliary heating,Elect...
# 4      Air conditioning,Armrest,Automatic climate con...
# ...                                                  ...
# 15914  Air conditioning,Automatic climate control,Cru...
# 15915  Air conditioning,Automatic climate control,Cru...
# 15916  Air conditioning,Armrest,Automatic climate con...
# 15917  Air conditioning,Automatic climate control,Cru...
# 15918  Air conditioning,Automatic climate control,Cru...
#
#                                    entertainment_&_media  \
# 0      Bluetooth,Hands-free equipment,On-board comput...
# 1      Bluetooth,Hands-free equipment,On-board comput...
# 2                                  MP3,On-board computer
# 3      Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4      Bluetooth,CD player,Hands-free equipment,MP3,O...
# ...                                                  ...
# 15914  Bluetooth,Digital radio,Hands-free equipment,O...
# 15915  Bluetooth,Digital radio,Hands-free equipment,R...
# 15916  Bluetooth,Hands-free equipment,On-board comput...
# 15917                  Bluetooth,Digital radio,Radio,USB
# 15918                                                USB
#
#                                                   extras  \
# 0         Alloy wheels,Catalytic Converter,Voice Control
# 1      Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                             Alloy wheels,Voice Control
# 3                 Alloy wheels,Sport seats,Voice Control
# 4      Alloy wheels,Sport package,Sport suspension,Vo...
# ...                                                  ...
# 15914                          Alloy wheels,Touch screen
# 15915            Alloy wheels,Touch screen,Voice Control
# 15916                                       Alloy wheels
# 15917                          Alloy wheels,Touch screen
# 15918                          Alloy wheels,Touch screen
#
#                                        safety_&_security  \
# 0      ABS,Central door lock,Daytime running lights,D...
# 1      ABS,Central door lock,Central door lock with r...
# 2      ABS,Central door lock,Daytime running lights,D...
# 3      ABS,Alarm system,Central door lock with remote...
# 4      ABS,Central door lock,Driver-side airbag,Elect...
# ...                                                  ...
# 15914  ABS,Central door lock,Central door lock with r...
# 15915  ABS,Adaptive Cruise Control,Blind spot monitor...
# 15916  ABS,Adaptive Cruise Control,Blind spot monitor...
# 15917  ABS,Blind spot monitor,Driver-side airbag,Elec...
# 15918  ABS,Blind spot monitor,Daytime running lights,...
#
#                                              description emission_label  \
# 0      \n,Sicherheit:, ,Deaktivierung für Beifahrer-A...            NaN
# 1      \nLangstreckenfahrzeug daher die hohe Kilomete...  \n4 (Green)\n
# 2      \n,Fahrzeug-Nummer: AM-95365, ,Ehem. UPE 24.64...  \n4 (Green)\n
# 3      \nAudi A1: ,- 1e eigenaar ,- Perfecte staat: s...            NaN
# 4      \n,Technik & Sicherheit:,Xenon plus,Klimaautom...            NaN
# ...                                                  ...            ...
# 15914  \nVettura visionabile nella sede in Via Roma 1...            NaN
# 15915  \nDach: Panorama-Glas-Schiebedach, Lackierung:...            NaN
# 15916  \n,Getriebe:, Automatik,Technik:, Bordcomputer...            NaN
# 15917  \nDEK:[2691331],Renault Espace Blue dCi 200CV ...            NaN
# 15918  \n,Sicherheit Airbags:, ,Seitenairbag, ,Fahrer...  \n4 (Green)\n
#
#        gears country_version electricity_consumption last_service_date  \
# 0        NaN             NaN                     NaN               NaN
# 1      \n7\n             NaN                     NaN               NaN
# 2        NaN             NaN                     NaN               NaN
# 3      \n6\n             NaN                     NaN               NaN
# 4        NaN     \nGermany\n                     NaN               NaN
# ...      ...             ...                     ...               ...
# 15914  \n6\n             NaN                     NaN               NaN
# 15915  \n7\n     \nGermany\n                     NaN               NaN
# 15916  \n6\n     \nAustria\n                     NaN               NaN
# 15917  \n6\n             NaN                     NaN               NaN
# 15918    NaN     \nGermany\n                     NaN               NaN
#
#       other_fuel_types                   availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915         [],[],[]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       last_timing_belt_service_date available_from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %%
df[["consumption_comb","consumption_city","consumption_country"]]= df.consumption.str.extract(r"(\d\.\d).+(\d\.\d).+(\d\.\d)")

# %%
for i in df.consumption.values:
    print(i)
# Out:
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['5.6 l/100 km (comb)'],['7.1 l/100 km (city)'],['4.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.5 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.3 l/100 km (comb)'],['3.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3 l/100 km (comb)'],['3 l/100 km (city)'],['3 l/100 km (country)']
# ['3.6 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# nan
# ['3.6 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3 l/100 km (comb)'],['4 l/100 km (city)'],['3 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.2 l/100 km (city),
# ,3.9 l/100 km (country),
#
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# nan
# nan
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# nan
# ['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.3 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.5 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.8 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
#
# ,5 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.3 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# nan
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# nan
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.6 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
#
# ,4.9 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.2 l/100 km (country),
#
#
# ,4.9 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.2 l/100 km (country),
#
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
#
# ,4.9 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.2 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# nan
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.8 l/100 km (comb)'],[],[]
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# nan
# ['5.8 l/100 km (comb)'],['7.4 l/100 km (city)'],['4.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.4 l/100 km (city),
# ,3.8 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.5 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# nan
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['5 l/100 km (comb)'],['6.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
#
# ,4.6 l/100 km (comb),
# ,5.6 l/100 km (city),
# ,4 l/100 km (country),
#
# ['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# nan
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.3 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']
#
# ,4.9 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.2 l/100 km (country),
#
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.4 l/100 km (country)']
#
# ,5.2 l/100 km (comb),
# ,6.7 l/100 km (city),
# ,4.4 l/100 km (country),
#
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# nan
#
# ,4.4 l/100 km (comb),
# ,5.2 l/100 km (city),
# ,3.9 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.3 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
#
# ,4.9 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.2 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
#
# ,4.7 l/100 km (comb),
# ,5.8 l/100 km (city),
# ,4.1 l/100 km (country),
#
# nan
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.4 l/100 km (comb)'],[],[]
# ['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.4 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.5 l/100 km (comb)'],['5.5 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
#
# ,4.9 l/100 km (comb),
# ,6.2 l/100 km (city),
# ,4.2 l/100 km (country),
#
# nan
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['5 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.3 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.6 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# nan
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['3.6 l/100 km (comb)'],['4 l/100 km (city)'],['3.3 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.4 l/100 km (city),
# ,3.8 l/100 km (country),
#
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# nan
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.6 l/100 km (comb)'],[],[]
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.4 l/100 km (city),
# ,3.8 l/100 km (country),
#
#
# ,4.4 l/100 km (comb),
# ,5.4 l/100 km (city),
# ,3.8 l/100 km (country),
#
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5.6 l/100 km (city)'],['4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.9 l/100 km (comb)'],[],['4.2 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.4 l/100 km (city),
# ,3.8 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.3 l/100 km (comb)'],['3.7 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.2 l/100 km (city),
# ,3.9 l/100 km (country),
#
# nan
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.8 l/100 km (city)'],['4.1 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.3 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3 l/100 km (comb)'],['4 l/100 km (city)'],['3 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
#
# ,4.6 l/100 km (comb),
# ,5.6 l/100 km (city),
# ,4 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.4 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.2 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.2 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['5.2 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.2 l/100 km (comb)'],[],[]
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.2 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.3 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.6 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.3 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],[],[]
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.3 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['43 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# nan
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# nan
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# nan
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.5 l/100 km (comb)'],[],[]
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['13.8 l/100 km (comb)'],['19.9 l/100 km (city)'],['10.3 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],[],['3.4 l/100 km (country)']
# nan
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.2 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.3 l/100 km (comb)'],['5.1 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
#
# ,4.4 l/100 km (comb),
# ,5.2 l/100 km (city),
# ,3.9 l/100 km (country),
#
# nan
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.4 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.4 l/100 km (comb)'],[],[]
# ['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4 l/100 km (comb)'],['4.8 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.1 l/100 km (country)']
# ['4.9 l/100 km (comb)'],['6.4 l/100 km (city)'],['4.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['5.2 l/100 km (comb)'],['6.7 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['4.2 l/100 km (comb)'],[],[]
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# nan
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['4.1 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.8 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.6 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.3 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.7 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.6 l/100 km (comb)'],['4.1 l/100 km (city)'],['3.3 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['3.8 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.5 l/100 km (country)']
# ['3.8 l/100 km (comb)'],['4.6 l/100 km (city)'],['3.3 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# nan
# nan
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# [],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.2 l/100 km (comb)'],[],[]
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['3.7 l/100 km (comb)'],['4.2 l/100 km (city)'],['3.4 l/100 km (country)']
# ['3.5 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.1 l/100 km (country)']
# ['3.4 l/100 km (comb)'],['3.9 l/100 km (city)'],['3.1 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['3.9 l/100 km (comb)'],['4.3 l/100 km (city)'],['3.6 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# ['4.3 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# nan
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['3.8 l/100 km (comb)'],['4.4 l/100 km (city)'],['3.5 l/100 km (country)']
# ['4 l/100 km (comb)'],['5 l/100 km (city)'],['3 l/100 km (country)']
#
# ,4.2 l/100 km (comb),
# ,5 l/100 km (city),
# ,3.7 l/100 km (country),
#
# ['3.7 l/100 km (comb)'],['4.5 l/100 km (city)'],['3.2 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['6.6 l/100 km (city)'],['4.2 l/100 km (country)']
# ['4.4 l/100 km (comb)'],['5.2 l/100 km (city)'],['3.9 l/100 km (country)']
# nan
# nan
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# ['4.2 l/100 km (comb)'],['5 l/100 km (city)'],['3.7 l/100 km (country)']
# nan
# ...
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.6 l/100 km (city)'],['6.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# nan
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],[],[]
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
#
# ,7.4 l/100 km (comb),
# ,9.2 l/100 km (city),
# ,6.3 l/100 km (country),
#
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['7.4 l/100 km (comb)'],[],[]
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# nan
# nan
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# nan
# nan
# nan
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.1 l/100 km (comb)'],[],[]
# nan
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# nan
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# nan
# nan
# nan
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# nan
# nan
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['4.6 l/100 km (comb)'],['5 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.6 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['5.6 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# nan
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['4.6 l/100 km (comb)'],[],[]
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# nan
# ['7.4 l/100 km (comb)'],['9.1 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.7 l/100 km (city)'],['6.3 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.6 l/100 km (comb)'],[],[]
# nan
# nan
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.4 l/100 km (comb)'],['6.3 l/100 km (city)'],['4.9 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['6.5 l/100 km (comb)'],[],[]
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# nan
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# ['7.6 l/100 km (comb)'],['9.9 l/100 km (city)'],['6.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],[],[]
# ['5.3 l/100 km (comb)'],[],[]
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.4 l/100 km (comb)'],[],[]
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5 l/100 km (comb)'],['5 l/100 km (city)'],['4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.8 l/100 km (country)']
# nan
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['5.4 l/100 km (comb)'],['6.1 l/100 km (city)'],['5 l/100 km (country)']
# ['6 l/100 km (comb)'],['8 l/100 km (city)'],['5 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['7.4 l/100 km (comb)'],[],[]
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.6 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# nan
# ['7.4 l/100 km (comb)'],['9.2 l/100 km (city)'],['6.3 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
#
# ,7.4 l/100 km (comb),
# ,9.2 l/100 km (city),
# ,6.3 l/100 km (country),
#
# ['5.7 l/100 km (comb)'],['6.1 l/100 km (city)'],['5.3 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],['9.6 l/100 km (city)'],['6 l/100 km (country)']
# ['5.1 l/100 km (comb)'],['5.7 l/100 km (city)'],['4.8 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# nan
# ['5.3 l/100 km (comb)'],['6 l/100 km (city)'],['5 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['7.4 l/100 km (comb)'],[],[]
#
# ,7.4 l/100 km (comb),
# ,9.6 l/100 km (city),
# ,6 l/100 km (country),
#
# nan
# nan
# ['6 l/100 km (comb)'],['8 l/100 km (city)'],['5 l/100 km (country)']
# ['4.7 l/100 km (comb)'],['5.1 l/100 km (city)'],['4.4 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
#
# ,7.4 l/100 km (comb),
# ,9.2 l/100 km (city),
# ,6.3 l/100 km (country),
#
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['5.3 l/100 km (comb)'],['6.2 l/100 km (city)'],['4.7 l/100 km (country)']
# ['6.8 l/100 km (comb)'],['8.7 l/100 km (city)'],['5.7 l/100 km (country)']

# %%
df.consumption.isnull().sum()

# %%
df.consumption.str.replace("\n", "").str.extract(r"(\d\.\d).+(\d\.\d).+(\d\.\d)").isnull().sum()

# %%
df.consumption.str.replace("\n", "").str.extract(r"(\d\.\d)(\d[\.\d]?).+(\d[\.\d]?).+(\d[\.\d]?)") # doğru çalışmıyor

# %%
df.consumption.str.replace("\n", "").str.extract(r"(\d[\.\d]?).+(\d[\.\d]?).+(\d[\.\d]?)").isnull().sum() # doğru çalışmıyor

# %%
print(df.consumption.head(50))

# %%
df.consumption.str.replace(r"[\n\[\],']?", "").str.extract(r"(.+) l/100 km \(comb\)(.+) l/100 km \(city\)(\[\.\d]?) l/100 km \(country\)").isnull().sum()

# %%
df.consumption.str.replace(r"[\n\[\],']?", "").str.extract(r"(.+) l/100 km \(comb\)").isnull().sum()

# %%
(df.consumption.str.contains("comb")).sum()

# %%
df.consumption.str.replace(r"[\n\[\],']?", "").str.extract(r".+ \(comb\)(.+) l/100 km \(city\)").isnull().sum()

# %%
(df.consumption.str.contains(r"city")).sum()

# %%
(df.consumption.str.contains("country")).sum()

# %%
# Öznur Hoca
df["consumption"].apply(lambda x: str(x).replace('[','').replace(']',''))

# %%
df.consumption.str.extract(r"(\d\.\d).+[comb](\d\.\d)[city](\d\.\d)[country]")

# %%
#Serdar Hoca

# df["consumption"]=df["consumption"].str.replace("\n,","").str.replace("[\[\]']?","")
df["comb"]=df["consumption"].str.findall(".+comb").transform(lambda x : np.nan if x == [] else x)
df["city"]=df["consumption"].str.findall(".+(\d.+city\))").transform(lambda x : np.nan if x == [] else x)
df["country"]=df["consumption"].str.findall(".+(\d.+country\))").transform(lambda x : np.nan if x == [] else x)
df[["comb","city","country"]].isnull().sum()

# %%
df["comb"]=df["consumption"].str.findall(".+comb\)").transform(lambda x : np.nan if x == [] else x)
df["city"]=df["consumption"].str.findall("[.+]?,(\d.+city\))").transform(lambda x : np.nan if x == [] else x)
df["country"]=df["consumption"].str.findall("[.+]?,(\d.+country\))").transform(lambda x : np.nan if x == [] else x)
df[["comb","city","country"]].isnull().sum()

# %%
df["comb"]=df["consumption"].str.findall(".+comb\)").transform(lambda x : np.nan if x == [] else x)
df["city"]=df["consumption"].str.findall("[.+]?,(\d.+city\))").transform(lambda x : np.nan if x == [] else x)
df["country"]=df["consumption"].str.findall("[.+]?,(\d.+country\))").transform(lambda x : np.nan if x == [] else x)
df[["comb","city","country"]].isnull().sum()

# %%
df.consumption.str.contains("l/100 km \(comb\)").sum()

# %%
df.consumption.str.contains("comb").sum()

# %%
15919 - (13886 + 2033)

# %%
df_0= df.consumption.str.extract(r"(.+) l/100 km \(comb\)")
df_0

# %%
df_1= df.consumption.str.extract(r"(.+) .+\(comb\)")
df_1[0].str.contains("kg").sum()

# %%
# Consumption kolonunun temizlenmesi ve yakıt tüketim değerlerinin ayrı sütunlar halinde çekilmesi

df["consumption"]=df["consumption"].str.replace("\n,","").str.replace("[\[\]']?","")
df["consumption_comb"] = df.consumption.str.extract(r"(\d*\.\d+|\d+).+\(comb\)")
df["consumption_city"] = df.consumption.str.extract(r"[.+]?,(\d*\.\d+|\d+).+\(city\)")
df["consumption_country"] = df.consumption.str.extract(r".+,(\d*\.\d+|\d+).+\(country\)")

# %%
df[["consumption_comb","consumption_city","consumption_country"]]
# Out:
#       consumption_comb consumption_city consumption_country
# 0                  3.8              4.3                 3.5
# 1                  5.6              7.1                 4.7
# 2                  3.8              4.4                 3.4
# 3                  3.8              4.3                 3.5
# 4                  4.1              4.6                 3.8
# ...                ...              ...                 ...
# 15914              5.3              6.2                 4.7
# 15915              7.4              9.2                 6.3
# 15916              5.3              6.2                 4.7
# 15917              5.3              6.2                 4.7
# 15918              6.8              8.7                 5.7
#
# [15919 rows x 3 columns]

# %%
df[["consumption_comb","consumption_city","consumption_country"]].isnull().sum()
# Out:
# consumption_comb       2033
# consumption_city       2436
# consumption_country    2376
# dtype: int64

# %%
df[["consumption_comb"]][(df["consumption_city"].isnull()==True) & (df["consumption_comb"].isnull()==False)]
# Out:
#       consumption_comb
# 170                3.8
# 252                4.4
# 361                3.6
# 382                4.9
# 461                4.2
# ...                ...
# 15847              5.3
# 15848              5.3
# 15850              5.4
# 15872              7.4
# 15906              7.4
#
# [511 rows x 1 columns]

# %%
df[["consumption_comb", "consumption_country"]][(df["consumption_city"].isnull()==True) & (df["consumption_country"].isnull()==False)]
# Out:
#       consumption_comb consumption_country
# 382                4.9                 4.2
# 551                3.7                 3.4
# 1428               3.7                 3.4
# 2829               3.9                 3.6
# 3483               3.6                 4.7
# 3811                 5                 4.3
# 3817                 5                 4.3
# 4026               3.6                 4.4
# 4134               4.8                 4.2
# 4135               4.8                 4.2
# 4181               4.8                 4.2
# 4182               4.8                 4.2
# 4187               4.8                 4.2
# 4390               4.8                 4.2
# 4936               3.6                 4.7
# 5009                 4                 3.8
# 5105               5.3                 4.9
# 6241                 3                   4
# 6319                 3                   4
# 6403                 3                   4
# 6781               4.4                 3.9
# 7538               3.3                 3.1
# 7544                 3                   4
# 8644               NaN                 5.6
# 8646               NaN                 5.7
# 9046               5.4                 4.6
# 9119               5.4                 4.6
# 9120               5.4                 4.6
# 9147               NaN                 5.7
# 9220               NaN                 5.8
# 9474               3.7                 3.3
# 9581               NaN                 5.7
# 9582               NaN                 5.7
# 9583               NaN                 5.7
# 9585               NaN                 5.7
# 9587               NaN                 5.7
# 9597               NaN                 5.7
# 9611               NaN                 5.7
# 9719               NaN                 5.7
# 9728               5.4                 4.6
# 10184              NaN                 5.7
# 10191              NaN                 5.7
# 10192              NaN                 5.7
# 10755              4.7                 8.6
# 10764              4.2                 7.8
# 11503              3.6                 4.1
# 11553              4.4                 6.9
# 13008              4.2                 5.8
# 13443              NaN                 5.1
# 13679              3.1                 3.5
# 14216              NaN                 5.1
# 14557              NaN                 5.1
# 14655              NaN                 5.1
# 14894               10                  10
# 14897               10                  10
# 14898               10                  10
# 14901               10                  10
# 14903               10                  10
# 14904               10                  10
# 14907               10                  10
# 14911               10                  10
# 14913               10                  10
# 14914               10                  10
# 14916               10                  10
# 14918               10                  10
# 14922               10                  10
# 14923               10                  10
# 14926               10                  10
# 14927               10                  10
# 15190              4.6                 4.4
# 15291              4.4                   4

# %%
df.consumption[14926]
# Out:
# '10 l/100 km (comb),,10 l/100 km (country)'

# %%
df[["consumption_comb","consumption_city","consumption_country"]].iloc[15872]
# Out:
# consumption_comb       7.4
# consumption_city       NaN
# consumption_country    NaN
# Name: 15872, dtype: object

# %%
# l/100 km yerine kg/100 km olarak verilmiş olanlar var. Bunlar yanlış girilmiş olabilir mi? Yoksa gerçek değerleri mi böyle?
# Kontrol edilip tekrar ona göre düzenlenecek.

# %%
# Serdar Hoca'dan

# df["consumption"]=df["consumption"].str.replace("\n,","")
# df[["comb","city","country"]]=df["consumption"].str.split(",",expand=True).loc[:,:2].applymap(lambda x : np.nan if x == "[]" or  x == "\n" else x)

# %%
# df[["comb","city","country"]]

# %%
# df[["comb","city","country"]].isnull().sum()

# %%
# df[["consumption","consumption_comb","consumption_city","consumption_country","comb","city","country"]].head(20)

# %%
df["nr_of_doors"].str.replace("\n",  "")
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: nr_of_doors, Length: 15919, dtype: object

# %%
df.head(5)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  k_w      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners  NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None  NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner  NaN   85 kW
# 3              None  73,000 km      08/2016   1 previous owner  NaN   66 kW
# 4              None  16,200 km      05/2016   1 previous owner  NaN   66 kW
#
#                                  type previous_owners  \
# 0  ,Used,,Diesel (Particulate Filter)           \n2\n
# 1                     ,Used,,Gasoline             NaN
# 2  ,Used,,Diesel (Particulate Filter)           \n1\n
# 3  ,Used,,Diesel (Particulate Filter)           \n1\n
# 4  ,Used,,Diesel (Particulate Filter)           \n1\n
#
#                       next_inspection                   inspection_new  \
# 0  \n06/2021\n,\n99 g CO2/km (comb)\n               \nYes\n,\nEuro 6\n
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN  \nYes\n,\n109 g CO2/km (comb)\n
#
#                        warranty                  full_service  \
# 0           \n,\n,\n4 (Green)\n                         \n,\n
# 1                           NaN                           NaN
# 2  \n,\n,\n99 g CO2/km (comb)\n                           NaN
# 3                           NaN  \n,\n,\n99 g CO2/km (comb)\n
# 4              \n,\n,\nEuro 6\n           \n,\n,\n4 (Green)\n
#
#   non_smoking_vehicle null      make     model   offer_number  \
# 0               \n,\n       \nAudi\n  \n,A1,\n  \nLR-062483\n
# 1                 NaN       \nAudi\n  \n,A1,\n            NaN
# 2                 NaN       \nAudi\n  \n,A1,\n   \nAM-95365\n
# 3    \n,\n,\nEuro 6\n       \nAudi\n  \n,A1,\n            NaN
# 4               \n,\n       \nAudi\n  \n,A1,\n      \nC1626\n
#
#   first_registration   body_color    paint_type         body_color_original  \
# 0         \n,2016,\n  \n,Black,\n  \nMetallic\n           \nMythosschwarz\n
# 1         \n,2017,\n    \n,Red,\n           NaN                         NaN
# 2         \n,2016,\n  \n,Black,\n  \nMetallic\n  \nmythosschwarz metallic\n
# 3         \n,2016,\n  \n,Brown,\n  \nMetallic\n                         NaN
# 4         \n,2016,\n  \n,Black,\n  \nMetallic\n  \nMythosschwarz Metallic\n
#
#          upholstery          body nr_of_doors nr_of_seats    model_code  \
# 0  \nCloth, Black\n  \n,Sedans,\n       \n5\n       \n5\n  \n0588/BDF\n
# 1   \nCloth, Grey\n  \n,Sedans,\n       \n3\n       \n4\n  \n0588/BCY\n
# 2  \nCloth, Black\n  \n,Sedans,\n       \n4\n       \n4\n           NaN
# 3               NaN  \n,Sedans,\n       \n3\n       \n4\n           NaN
# 4  \nCloth, Black\n  \n,Sedans,\n       \n5\n       \n5\n  \n0588/BDF\n
#
#       gearing_type  displacement cylinders        weight drive_chain  \
# 0  \n,Automatic,\n  \n1,422 cc\n     \n3\n  \n1,220 kg\n   \nfront\n
# 1  \n,Automatic,\n  \n1,798 cc\n     \n4\n  \n1,255 kg\n   \nfront\n
# 2  \n,Automatic,\n  \n1,598 cc\n       NaN           NaN   \nfront\n
# 3  \n,Automatic,\n  \n1,422 cc\n     \n3\n  \n1,195 kg\n         NaN
# 4  \n,Automatic,\n  \n1,422 cc\n     \n3\n           NaN   \nfront\n
#
#                                 fuel  \
# 0  \n,Diesel (Particulate Filter),\n
# 1                     \n,Gasoline,\n
# 2  \n,Diesel (Particulate Filter),\n
# 3  \n,Diesel (Particulate Filter),\n
# 4  \n,Diesel (Particulate Filter),\n
#
#                                          consumption            co_2_emission  \
# 0  3.8 l/100 km (comb),4.3 l/100 km (city),3.5 l/...   \n99 g CO2/km (comb)\n
# 1  5.6 l/100 km (comb),7.1 l/100 km (city),4.7 l/...  \n129 g CO2/km (comb)\n
# 2  3.8 l/100 km (comb),4.4 l/100 km (city),3.4 l/...   \n99 g CO2/km (comb)\n
# 3  3.8 l/100 km (comb),4.3 l/100 km (city),3.5 l/...   \n99 g CO2/km (comb)\n
# 4  4.1 l/100 km (comb),4.6 l/100 km (city),3.8 l/...  \n109 g CO2/km (comb)\n
#
#   emission_class                              comfort_&_convenience  \
# 0     \nEuro 6\n  Air conditioning,Armrest,Automatic climate con...
# 1     \nEuro 6\n  Air conditioning,Automatic climate control,Hil...
# 2     \nEuro 6\n  Air conditioning,Cruise control,Electrical sid...
# 3     \nEuro 6\n  Air suspension,Armrest,Auxiliary heating,Elect...
# 4     \nEuro 6\n  Air conditioning,Armrest,Automatic climate con...
#
#                                entertainment_&_media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                    safety_&_security  \
# 0  ABS,Central door lock,Daytime running lights,D...
# 1  ABS,Central door lock,Central door lock with r...
# 2  ABS,Central door lock,Daytime running lights,D...
# 3  ABS,Alarm system,Central door lock with remote...
# 4  ABS,Central door lock,Driver-side airbag,Elect...
#
#                                          description emission_label  gears  \
# 0  \n,Sicherheit:, ,Deaktivierung für Beifahrer-A...            NaN    NaN
# 1  \nLangstreckenfahrzeug daher die hohe Kilomete...  \n4 (Green)\n  \n7\n
# 2  \n,Fahrzeug-Nummer: AM-95365, ,Ehem. UPE 24.64...  \n4 (Green)\n    NaN
# 3  \nAudi A1: ,- 1e eigenaar ,- Perfecte staat: s...            NaN  \n6\n
# 4  \n,Technik & Sicherheit:,Xenon plus,Klimaautom...            NaN    NaN
#
#   country_version electricity_consumption last_service_date other_fuel_types  \
# 0             NaN                     NaN               NaN              NaN
# 1             NaN                     NaN               NaN              NaN
# 2             NaN                     NaN               NaN              NaN
# 3             NaN                     NaN               NaN              NaN
# 4     \nGermany\n                     NaN               NaN              NaN
#
#   availability last_timing_belt_service_date available_from consumption_comb  \
# 0          NaN                           NaN            NaN              3.8
# 1          NaN                           NaN            NaN              5.6
# 2          NaN                           NaN            NaN              3.8
# 3          NaN                           NaN            NaN              3.8
# 4          NaN                           NaN            NaN              4.1
#
#   consumption_city consumption_country                     comb  \
# 0              4.3                 3.5  ['3.8 l/100 km (comb)']
# 1              7.1                 4.7  ['5.6 l/100 km (comb)']
# 2              4.4                 3.4  ['3.8 l/100 km (comb)']
# 3              4.3                 3.5  ['3.8 l/100 km (comb)']
# 4              4.6                 3.8  ['4.1 l/100 km (comb)']
#
#                       city                     country
# 0  ['4.3 l/100 km (city)']  ['3.5 l/100 km (country)']
# 1  ['7.1 l/100 km (city)']  ['4.7 l/100 km (country)']
# 2  ['4.4 l/100 km (city)']  ['3.4 l/100 km (country)']
# 3  ['4.3 l/100 km (city)']  ['3.5 l/100 km (country)']
# 4  ['4.6 l/100 km (city)']  ['3.8 l/100 km (country)']

# %%
df=df.apply(lambda x: x.str.replace(",?\n,?",  "") if x.dtype == "O" else x)

# %%
#fazla gelen nulların kontrolu
df_0.join(df_1, lsuffix="_0", rsuffix="_1").sample(50)
# Out:
#          0_0          0_1
# 6660   ['5.5  ['5.5 l/100
# 2061   ['4.9  ['4.9 l/100
# 9978      ,6     ,6 l/100
# 6470   ['4.3  ['4.3 l/100
# 1020   ['4.4  ['4.4 l/100
# 8094   ['5.5  ['5.5 l/100
# 4645     NaN          NaN
# 10535    ['5    ['5 l/100
# 9196   ['3.8  ['3.8 l/100
# 2152     NaN          NaN
# 9457   ['5.4  ['5.4 l/100
# 13953    ['5    ['5 l/100
# 6431   ['6.3  ['6.3 l/100
# 3730   ['4.7  ['4.7 l/100
# 9291   ['5.3  ['5.3 l/100
# 3629   ['4.4  ['4.4 l/100
# 13759  ['3.3  ['3.3 l/100
# 3478   ['3.8  ['3.8 l/100
# 1827   ['4.4  ['4.4 l/100
# 9171   ['5.2  ['5.2 l/100
# 7687    ,5.6   ,5.6 l/100
# 12488  ['5.6  ['5.6 l/100
# 1761   ['4.2  ['4.2 l/100
# 2209   ['4.8  ['4.8 l/100
# 9572   ['5.2  ['5.2 l/100
# 10594  ['5.5  ['5.5 l/100
# 5377     NaN          NaN
# 10358  ['5.7  ['5.7 l/100
# 4612   ['4.3  ['4.3 l/100
# 3176   ['3.8  ['3.8 l/100
# 8422   ['4.7  ['4.7 l/100
# 8714   ['5.3  ['5.3 l/100
# 3695     ['4    ['4 l/100
# 9574   ['5.3  ['5.3 l/100
# 5751   ['4.1  ['4.1 l/100
# 14420  ['5.9  ['5.9 l/100
# 12006    NaN          NaN
# 8806     NaN          NaN
# 14136    NaN          NaN
# 7291   ['5.5  ['5.5 l/100
# 14272  ['5.6  ['5.6 l/100
# 10731    ['5    ['5 l/100
# 5539   ['5.1  ['5.1 l/100
# 9050     NaN          NaN
# 11038  ['4.3  ['4.3 l/100
# 2681   ['3.9  ['3.9 l/100
# 13096  ['3.5  ['3.5 l/100
# 6471     NaN          NaN
# 9543   ['5.9  ['5.9 l/100
# 6121   ['3.5  ['3.5 l/100

# %%
df.describe(include='O').T
# Out:
#                                count unique  \
# url                            15919  15919
# make_model                     15919      9
# short_description              15873  10001
# body_type                      15859      9
# vat                            11406      2
# km                             15919   6690
# registration                   15919     48
# prev_owner                      9091      4
# hp                             15919     81
# type                           15917    169
# previous_owners                 9279    101
# next_inspection                 3535   1384
# inspection_new                  3932    201
# warranty                       10499    506
# full_service                    8215    121
# non_smoking_vehicle             7177     93
# null                           15919      1
# make                           15919      3
# model                          15919      9
# offer_number                   12744  11440
# first_registration             14322      4
# body_color                     15322     14
# paint_type                     10147      3
# body_color_original            12160   1927
# upholstery                     12199     46
# body                           15859      9
# nr_of_doors                    15707      6
# nr_of_seats                    14942      6
# model_code                      4978    232
# gearing_type                   15919      3
# displacement                   15423     77
# cylinders                      10239      7
# weight                          8945    434
# drive_chain                     9061      3
# fuel                           15919     77
# consumption                    14013    739
# co_2_emission                  14111    123
# emission_class                 12898      7
# comfort_&_convenience          14999   6198
# entertainment_&_media          14545    346
# extras                         12957    659
# safety_&_security              14937   4443
# description                    15919  12864
# emission_label                  3985      6
# gears                          11207     10
# country_version                 7586     23
# electricity_consumption          137      1
# last_service_date                566    255
# other_fuel_types                 880      1
# availability                     635     15
# last_timing_belt_service_date     16     15
# available_from                   272     46
# consumption_comb               13886     72
# consumption_city               13483     86
# consumption_country            13543     57
#
#                                                                              top  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A3
# short_description                              SPB 1.6 TDI 116 CV S tronic Sport
# body_type                                                                 Sedans
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                      1 previous owner
# hp                                                                         85 kW
# type                                          ,Used,,Diesel (Particulate Filter)
# previous_owners                                                                1
# next_inspection                                                          04/2022
# inspection_new                                                         YesEuro 6
# warranty                                                                  Euro 6
# full_service                                                           4 (Green)
# non_smoking_vehicle
# null
# make                                                                        Opel
# model                                                                         A3
# offer_number                                                             LT67679
# first_registration                                                          2018
# body_color                                                                 Black
# paint_type                                                              Metallic
# body_color_original                                                 Onyx Schwarz
# upholstery                                                          Cloth, Black
# body                                                                      Sedans
# nr_of_doors                                                                    5
# nr_of_seats                                                                    5
# model_code                                                              0035/BCB
# gearing_type                                                              Manual
# displacement                                                            1,598 cc
# cylinders                                                                      4
# weight                                                                  1,163 kg
# drive_chain                                                                front
# fuel                                                 Diesel (Particulate Filter)
# consumption                    3.9 l/100 km (comb),4.1 l/100 km (city),3.7 l/...
# co_2_emission                                                120 g CO2/km (comb)
# emission_class                                                            Euro 6
# comfort_&_convenience          Air conditioning,Electrical side mirrors,Hill ...
# entertainment_&_media          Bluetooth,Hands-free equipment,On-board comput...
# extras                                                              Alloy wheels
# safety_&_security              ABS,Central door lock,Daytime running lights,D...
# description
# emission_label                                                         4 (Green)
# gears                                                                          6
# country_version                                                          Germany
# electricity_consumption                                      0 kWh/100 km (comb)
# last_service_date                                                  02/2019Euro 6
# other_fuel_types                                                        [],[],[]
# availability                                            in 90 days from ordering
# last_timing_belt_service_date                                            04/2016
# available_from                                                          31/08/19
# consumption_comb                                                             5.4
# consumption_city                                                               5
# consumption_country                                                          4.2
#
#                                 freq
# url                                1
# make_model                      3097
# short_description                 64
# body_type                       7903
# vat                            10980
# km                              1045
# registration                    1597
# prev_owner                      8294
# hp                              2542
# type                            3475
# previous_owners                 8103
# next_inspection                   62
# inspection_new                   523
# warranty                        1868
# full_service                    2235
# non_smoking_vehicle             3717
# null                           15919
# make                            7343
# model                           3097
# offer_number                      27
# first_registration              4522
# body_color                      3745
# paint_type                      9794
# body_color_original              338
# upholstery                      5821
# body                            7903
# nr_of_doors                    11575
# nr_of_seats                    13336
# model_code                       268
# gearing_type                    8153
# displacement                    4761
# cylinders                       8105
# weight                           574
# drive_chain                     8886
# fuel                            4315
# consumption                      304
# co_2_emission                    740
# emission_class                 10139
# comfort_&_convenience            216
# entertainment_&_media           1282
# extras                          3245
# safety_&_security                538
# description                      667
# emission_label                  3553
# gears                           5822
# country_version                 4502
# electricity_consumption          137
# last_service_date                 23
# other_fuel_types                 880
# availability                     196
# last_timing_belt_service_date      2
# available_from                    98
# consumption_comb                 770
# consumption_city                 669
# consumption_country             1178

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print('Num_of_Uniques : ', df[col].nunique())
#     print('Duplicates     : ', df.duplicated(subset = None, keep = 'first').sum(), end='\n\n')
    print("Value_counts :\n",df[col].value_counts(dropna = False))
    print()
    print("Value_counts with sort index :\n",df[col].value_counts(dropna = False).sort_index())
    print("##"*20)
    print()

# %%
for col in df.columns :
    first_look(col)
# Out:
# column name :  url
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  15919
# Value_counts :
#  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
#                                                                                                                                                           ..
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-black-cf50f7b1-4d7b-466f-93a2-4e11ec0b4107                        1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-grey-3f47eb34-15c4-4763-860d-78fcbbd2c9ff                         1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-f7a4bc95-b2ef-4bac-9497-6bcbcd05db0b                       1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-1c94c7a2-67b5-49ca-ae42-42a6800fb3f5                       1
# https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-gasoline-grey-0bd690d9-7e93-4cab-bc5a-9d5b63402481          1
# Name: url, Length: 15919, dtype: int64
#
# Value_counts with sort index :
#  https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-2019-sh-pdc-gasoline-white-1037d13f-0851-44dd-b559-c6f6def8e6d2                     1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-gasoline-white-16e81c6c-58ce-4b86-9926-9f09302d0ef4                                 1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-gasoline-white-a48492d9-f2e5-436d-9ad4-dfb31ff19aed                                 1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-basis-2019-navi-virtual-gasoline-white-6d94186e-c19d-4aa1-a223-bc0256d51845                  1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-basis-2019-pdc-sh-gasoline-white-047a0fe6-743e-4ae6-892e-e97bc13b1468                        1
#                                                                                                                                                               ..
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-5eb03fe7-5c36-40b6-a596-ee0de57372e1                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-996ac32a-6070-40af-b6ab-74f57232e256                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-a6700fd3-efb5-44a8-a85b-90c491c9d378                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-b9b30dfb-beb9-4157-b8b4-dbe86ba6573d                         1
# https://www.autoscout24.com//offers/renault-espace-zu-spaet-geht-an-haendler-da-wird-er-dann-23-000-ko-gasoline-silver-93caa088-19e3-905e-e053-e250040a8d8d    1
# Name: url, Length: 15919, dtype: int64
# ########################################
#
# column name :  make_model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
# Value_counts :
#  Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
#
# Value_counts with sort index :
#  Audi A1           2614
# Audi A2              1
# Audi A3           3097
# Opel Astra        2526
# Opel Corsa        2219
# Opel Insignia     2598
# Renault Clio      1839
# Renault Duster      34
# Renault Espace     991
# Name: make_model, dtype: int64
# ########################################
#
# column name :  short_description
# --------------------------------
# Per_of_Nulls   :  % 0.29
# Num_of_Nulls   :  46
# Num_of_Uniques :  10001
# Value_counts :
#  SPB 1.6 TDI 116 CV S tronic Sport                 64
# NaN                                               46
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 10002, dtype: int64
#
# Value_counts with sort index :
#   1,6 CDTI**NAVI*Klimaaut*Tempomat*EURO6*TÜV NEU     1
#  1.4 75 cv5 porte b-color                           1
#  1.4 TFSI Attraction (125 CV)                       6
#  1.4 Turbo S&S Excellence (125 CV)                  2
#  1.6 CDTi Dynamic (110 CV)                          4
#                                                    ..
# van 1.5 dci 75cv S S E6                             1
# van 1.5 dci 75cv S&S E6                            24
# zoé life                                            1
# Österr. Edition 16.CDTI                             1
# NaN                                                46
# Name: short_description, Length: 10002, dtype: int64
# ########################################
#
# column name :  body_type
# --------------------------------
# Per_of_Nulls   :  % 0.38
# Num_of_Nulls   :  60
# Num_of_Uniques :  9
# Value_counts :
#  Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
#
# Value_counts with sort index :
#  Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body_type, dtype: int64
# ########################################
#
# column name :  price
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2956
# Value_counts :
#  14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64
#
# Value_counts with sort index :
#  13       1
# 120      1
# 255      1
# 331      1
# 4950     1
#         ..
# 64332    1
# 64900    1
# 67600    1
# 68320    1
# 74600    1
# Name: price, Length: 2956, dtype: int64
# ########################################
#
# column name :  vat
# --------------------------------
# Per_of_Nulls   :  % 28.35
# Num_of_Nulls   :  4513
# Num_of_Uniques :  2
# Value_counts :
#  VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
#
# Value_counts with sort index :
#  Price negotiable      426
# VAT deductible      10980
# NaN                  4513
# Name: vat, dtype: int64
# ########################################
#
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  6690
# Value_counts :
#  10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
#
# Value_counts with sort index :
#  - km         1024
# 0 km           19
# 1 km          367
# 1,000 km       46
# 1,001 km        4
#              ...
# 99,999 km       1
# 990 km          2
# 991 km          1
# 995 km          1
# 999 km          3
# Name: km, Length: 6690, dtype: int64
# ########################################
#
# column name :  registration
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  48
# Value_counts :
#  -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64
#
# Value_counts with sort index :
#  -/-        1597
# 01/2016     376
# 01/2017     306
# 01/2018     511
# 01/2019     541
# 02/2016     472
# 02/2017     368
# 02/2018     539
# 02/2019     585
# 03/2016     536
# 03/2017     471
# 03/2018     695
# 03/2019     543
# 04/2016     532
# 04/2017     380
# 04/2018     541
# 04/2019     506
# 05/2016     459
# 05/2017     404
# 05/2018     572
# 05/2019     440
# 06/2016     452
# 06/2017     409
# 06/2018     532
# 06/2019     224
# 07/2016     176
# 07/2017     215
# 07/2018     396
# 07/2019       6
# 08/2016      94
# 08/2017     114
# 08/2018     285
# 08/2019       1
# 09/2016     141
# 09/2017     149
# 09/2018     141
# 09/2019       5
# 10/2016     160
# 10/2017     154
# 10/2018      97
# 11/2016     142
# 11/2017     180
# 11/2018     110
# 11/2019       1
# 12/2016     134
# 12/2017     123
# 12/2018     103
# 12/2019       1
# Name: registration, dtype: int64
# ########################################
#
# column name :  prev_owner
# --------------------------------
# Per_of_Nulls   :  % 42.89
# Num_of_Nulls   :  6828
# Num_of_Uniques :  4
# Value_counts :
#  1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
#
# Value_counts with sort index :
#  1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6828
# Name: prev_owner, dtype: int64
# ########################################
#
# column name :  k_w
# --------------------------------
# Per_of_Nulls   :  % 100.0
# Num_of_Nulls   :  15919
# Num_of_Uniques :  0
# Value_counts :
#  NaN    15919
# Name: k_w, dtype: int64
#
# Value_counts with sort index :
#  NaN    15919
# Name: k_w, dtype: int64
# ########################################
#
# column name :  hp
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  81
# Value_counts :
#  85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 78 kW       20
# 1 kW        20
# 294 kW      18
# 146 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# 76 kW        4
# 65 kW        4
# 149 kW       3
# 80 kW        3
# 168 kW       3
# 98 kW        3
# 93 kW        3
# 228 kW       2
# 270 kW       2
# 53 kW        2
# 140 kW       2
# 86 kW        2
# 167 kW       2
# 127 kW       2
# 89 kW        2
# 143 kW       2
# 63 kW        2
# 40 kW        2
# 150 kW       2
# 163 kW       1
# 115 kW       1
# 132 kW       1
# 75 kW        1
# 4 kW         1
# 137 kW       1
# 123 kW       1
# 133 kW       1
# 84 kW        1
# 195 kW       1
# 44 kW        1
# 239 kW       1
# 9 kW         1
# Name: hp, dtype: int64
#
# Value_counts with sort index :
#  - kW        88
# 1 kW        20
# 100 kW    1308
# 101 kW      47
# 103 kW     253
# 104 kW       8
# 110 kW    1112
# 112 kW       7
# 115 kW       1
# 117 kW       6
# 118 kW     516
# 119 kW      30
# 120 kW       8
# 121 kW     392
# 122 kW      35
# 123 kW       1
# 125 kW     707
# 127 kW       2
# 132 kW       1
# 133 kW       1
# 135 kW      24
# 137 kW       1
# 140 kW       2
# 141 kW      16
# 143 kW       2
# 146 kW      18
# 147 kW     380
# 149 kW       3
# 150 kW       2
# 154 kW      39
# 155 kW       6
# 162 kW      98
# 163 kW       1
# 164 kW      27
# 165 kW     194
# 167 kW       2
# 168 kW       3
# 184 kW       5
# 191 kW       7
# 195 kW       1
# 228 kW       2
# 239 kW       1
# 270 kW       2
# 294 kW      18
# 4 kW         1
# 40 kW        2
# 44 kW        1
# 51 kW      695
# 52 kW       22
# 53 kW        2
# 54 kW      276
# 55 kW      569
# 56 kW      286
# 57 kW       10
# 60 kW      160
# 63 kW        2
# 65 kW        4
# 66 kW     2122
# 67 kW       40
# 70 kW      888
# 71 kW       59
# 74 kW       81
# 75 kW        1
# 76 kW        4
# 77 kW      345
# 78 kW       20
# 80 kW        3
# 81 kW     1402
# 82 kW       22
# 84 kW        1
# 85 kW     2542
# 86 kW        2
# 87 kW      232
# 88 kW      177
# 89 kW        2
# 9 kW         1
# 90 kW        4
# 92 kW      466
# 93 kW        3
# 96 kW       72
# 98 kW        3
# Name: hp, dtype: int64
# ########################################
#
# column name :  type
# --------------------------------
# Per_of_Nulls   :  % 0.01
# Num_of_Nulls   :  2
# Num_of_Uniques :  169
# Value_counts :
#  ,Used,,Diesel (Particulate Filter)                                                                                 3475
# ,Used,,Diesel                                                                                                      2516
# ,Used,,Gasoline                                                                                                    2367
# ,Used,,Super 95                                                                                                    1818
# ,Pre-registered,,Super 95                                                                                           500
#                                                                                                                    ...
# ,New,,Regular/Benzine 91 / Super 95 / Super Plus 98 / Regular/Benzine E10 91 / Super Plus E10 98 / Super E10 95       1
# ,Used,,Super 95 / Super Plus 98 / Super E10 95 / Super Plus E10 98 (Particulate Filter)                               1
# ,Demonstration,,Super Plus 98                                                                                         1
# ,New,,Super Plus E10 98                                                                                               1
# ,Demonstration,,Regular/Benzine E10 91                                                                                1
# Name: type, Length: 170, dtype: int64
#
# Value_counts with sort index :
#  ,Demonstration,,Diesel                                                 45
# ,Demonstration,,Diesel (Particulate Filter)                           129
# ,Demonstration,,Gasoline                                              158
# ,Demonstration,,Gasoline (Particulate Filter)                           1
# ,Demonstration,,Regular/Benzine 91                                     36
#                                                                      ...
# ,Used,,Super E10 95 / Super 95 / Super Plus 98 / Super Plus E10 98      8
# ,Used,,Super E10 95 / Super Plus E10 98                                 4
# ,Used,,Super Plus 98                                                    2
# ,Used,,Super Plus E10 98 / Super 95 / Super Plus 98 / Super E10 95      1
# NaN                                                                     2
# Name: type, Length: 170, dtype: int64
# ########################################
#
# column name :  previous_owners
# --------------------------------
# Per_of_Nulls   :  % 41.71
# Num_of_Nulls   :  6640
# Num_of_Uniques :  101
# Value_counts :
#  1                                                                8103
# NaN                                                              6640
# 2                                                                 766
# 0                                                                 163
# 3                                                                  17
#                                                                  ...
# 1111 g CO2/km (comb)                                                1
# 1Euro 6                                                             1
# 2119 g CO2/km (comb)                                                1
# 16.6 l/100 km (comb)8.1 l/100 km (city)5.7 l/100 km (country)       1
# 1142 g CO2/km (comb)                                                1
# Name: previous_owners, Length: 102, dtype: int64
#
# Value_counts with sort index :
#  0                                                                 163
# 00 kWh/100 km (comb)                                                2
# 0104 g CO2/km (comb)                                                1
# 0105 g CO2/km (comb)                                                1
# 0106 g CO2/km (comb)                                                1
#                                                                  ...
# 2137 g CO2/km (comb)                                                1
# 25.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       2
# 3                                                                  17
# 4                                                                   2
# NaN                                                              6640
# Name: previous_owners, Length: 102, dtype: int64
# ########################################
#
# column name :  next_inspection
# --------------------------------
# Per_of_Nulls   :  % 77.79
# Num_of_Nulls   :  12384
# Num_of_Uniques :  1384
# Value_counts :
#  NaN                           12384
# 04/2022                          62
# 06/2021                          47
# 03/2021                          39
# 03/2022                          36
#                               ...
# 06/2021121 g CO2/km (comb)        1
# 02/2020139 g CO2/km (comb)        1
# 10/2021136 g CO2/km (comb)        1
# 06/2019139 g CO2/km (comb)        1
# 01/2022168 g CO2/km (comb)        1
# Name: next_inspection, Length: 1385, dtype: int64
#
# Value_counts with sort index :
#  01/1921120 g CO2/km (comb)                                               1
# 01/1955                                                                  1
# 01/1999                                                                  1
# 01/2001120 g CO2/km (comb)                                               1
# 01/2001122 g CO2/km (comb)                                               2
#                                                                      ...
# 12/2021167 g CO2/km (comb)                                               1
# 12/20215 l/100 km (comb)6.3 l/100 km (city)4.2 l/100 km (country)        1
# 12/2021Euro 6                                                            1
# 12/2022                                                                  1
# NaN                                                                  12384
# Name: next_inspection, Length: 1385, dtype: int64
# ########################################
#
# column name :  inspection_new
# --------------------------------
# Per_of_Nulls   :  % 75.3
# Num_of_Nulls   :  11987
# Num_of_Uniques :  201
# Value_counts :
#  NaN                                                                11987
# YesEuro 6                                                            523
# Yes                                                                  442
# Yes102 g CO2/km (comb)                                               174
# Yes4 (Green)                                                         166
#                                                                    ...
# Yes5.2 l/100 km (comb)6.7 l/100 km (city)4.2 l/100 km (country)        1
# Yes100 g CO2/km (comb)                                                 1
# Yes4.9 l/100 km (comb)5.9 l/100 km (city)4.3 l/100 km (country)        1
# Yes5.1 l/100 km (comb)6.4 l/100 km (city)4.3 l/100 km (country)        1
# Yes172 g CO2/km (comb)                                                 1
# Name: inspection_new, Length: 202, dtype: int64
#
# Value_counts with sort index :
#  Yes                         442
# Yes0 kWh/100 km (comb)       86
# Yes1 (No sticker)             1
# Yes100 g CO2/km (comb)        1
# Yes101 g CO2/km (comb)       25
#                           ...
# YesEuro 6                   523
# YesEuro 6c                    5
# YesEuro 6d                   24
# YesEuro 6d-TEMP             134
# NaN                       11987
# Name: inspection_new, Length: 202, dtype: int64
# ########################################
#
# column name :  warranty
# --------------------------------
# Per_of_Nulls   :  % 34.05
# Num_of_Nulls   :  5420
# Num_of_Uniques :  506
# Value_counts :
#  NaN                                                                    5420
# Euro 6                                                                 1868
#                                                                        1343
# 12 months                                                              1305
# 24 months                                                               585
#                                                                        ...
# 2 months                                                                  1
# 72 months125 g CO2/km (comb)                                              1
# 60 months14 g CO2/km (comb)                                               1
# 24 months121 g CO2/km (comb)                                              1
# 36 months7.4 l/100 km (comb)9.6 l/100 km (city)6 l/100 km (country)       1
# Name: warranty, Length: 507, dtype: int64
#
# Value_counts with sort index :
#                    1343
# ,,,Diesel            1
# 1 (No sticker)      17
# 1 months             1
# 1 monthsEuro 6       2
#                   ...
# Euro 6            1868
# Euro 6c             21
# Euro 6d             11
# Euro 6d-TEMP       362
# NaN               5420
# Name: warranty, Length: 507, dtype: int64
# ########################################
#
# column name :  full_service
# --------------------------------
# Per_of_Nulls   :  % 48.39
# Num_of_Nulls   :  7704
# Num_of_Uniques :  121
# Value_counts :
#  NaN                                                             7704
# 4 (Green)                                                       2235
# Euro 6                                                          2097
#                                                                 1985
# Euro 6d-TEMP                                                     399
#                                                                 ...
# 6 l/100 km (comb)8 l/100 km (city)4.9 l/100 km (country)           1
# 84 g CO2/km (comb)                                                 1
# 87 g CO2/km (comb)                                                 1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.9 l/100 km (country)       1
# Euro 4                                                             1
# Name: full_service, Length: 122, dtype: int64
#
# Value_counts with sort index :
#                         1985
# 0 kWh/100 km (comb)       2
# 1 (No sticker)           29
# 101 g CO2/km (comb)      10
# 102 g CO2/km (comb)      29
#                        ...
# Euro 6                 2097
# Euro 6c                  28
# Euro 6d                  11
# Euro 6d-TEMP            399
# NaN                    7704
# Name: full_service, Length: 122, dtype: int64
# ########################################
#
# column name :  non_smoking_vehicle
# --------------------------------
# Per_of_Nulls   :  % 54.92
# Num_of_Nulls   :  8742
# Num_of_Uniques :  93
# Value_counts :
#  NaN                                                             8742
#                                                                 3717
# 4 (Green)                                                       1240
# Euro 6                                                          1127
# Euro 6d-TEMP                                                     345
# 120 g CO2/km (comb)                                               63
# 85 g CO2/km (comb)                                                46
# 104 g CO2/km (comb)                                               36
# 107 g CO2/km (comb)                                               36
# 153 g CO2/km (comb)                                               31
# 124 g CO2/km (comb)                                               29
# 1 (No sticker)                                                    24
# 99 g CO2/km (comb)                                                23
# 106 g CO2/km (comb)                                               20
# 97 g CO2/km (comb)                                                20
# 108 g CO2/km (comb)                                               19
# 100 g CO2/km (comb)                                               18
# 109 g CO2/km (comb)                                               18
# 113 g CO2/km (comb)                                               18
# 105 g CO2/km (comb)                                               18
# Euro 6c                                                           17
# 98 g CO2/km (comb)                                                15
# 129 g CO2/km (comb)                                               14
# 131 g CO2/km (comb)                                               13
# 133 g CO2/km (comb)                                               12
# 103 g CO2/km (comb)                                               12
# 114 g CO2/km (comb)                                               12
# 135 g CO2/km (comb)                                               11
# 116 g CO2/km (comb)                                               11
# 102 g CO2/km (comb)                                               11
# 143 g CO2/km (comb)                                               10
# 127 g CO2/km (comb)                                               10
# Euro 6d                                                            9
# 92 g CO2/km (comb)                                                 9
# 112 g CO2/km (comb)                                                9
# 5 (Blue)                                                           8
# 118 g CO2/km (comb)                                                8
# 147 g CO2/km (comb)                                                7
# 128 g CO2/km (comb)                                                7
# 139 g CO2/km (comb)                                                7
# 140 g CO2/km (comb)                                                6
# 137 g CO2/km (comb)                                                6
# 117 g CO2/km (comb)                                                6
# 126 g CO2/km (comb)                                                6
# 130 g CO2/km (comb)                                                5
# 115 g CO2/km (comb)                                                5
# 5.2 l/100 km (comb)5.8 l/100 km (city)4.8 l/100 km (country)       4
# 123 g CO2/km (comb)                                                4
# Euro 5                                                             4
# 151 g CO2/km (comb)                                                4
# 136 g CO2/km (comb)                                                3
# 110 g CO2/km (comb)                                                3
# 148 g CO2/km (comb)                                                3
# 157 g CO2/km (comb)                                                3
# 95 g CO2/km (comb)                                                 3
# 119 g CO2/km (comb)                                                3
# 149 g CO2/km (comb)                                                3
# 166 g CO2/km (comb)                                                2
# 138 g CO2/km (comb)                                                2
# 121 g CO2/km (comb)                                                2
# 111 g CO2/km (comb)                                                2
# 90 g CO2/km (comb)                                                 2
# 142 g CO2/km (comb)                                                2
# 125 g CO2/km (comb)                                                2
# 134 g CO2/km (comb)                                                2
# 5.2 l/100 km (comb)6.4 l/100 km (city)4.4 l/100 km (country)       2
# 6.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)       1
# 146 g CO2/km (comb)                                                1
# 189 g CO2/km (comb)                                                1
# 6.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)       1
# 6.3 l/100 km (comb)8 l/100 km (city)5.3 l/100 km (country)         1
# 154 g CO2/km (comb)                                                1
# 6.5 l/100 km (comb)7.9 l/100 km (city)5.6 l/100 km (country)       1
# 6.4 l/100 km (comb)8.1 l/100 km (city)5.4 l/100 km (country)       1
# 122 g CO2/km (comb)                                                1
# 82 g CO2/km (comb)                                                 1
# 1.6 l/100 km (comb)                                                1
# 172 g CO2/km (comb)                                                1
# 161 g CO2/km (comb)                                                1
# 156 g CO2/km (comb)                                                1
# 169 g CO2/km (comb)                                                1
# 6.1 l/100 km (comb)7.8 l/100 km (city)5.1 l/100 km (country)       1
# 152 g CO2/km (comb)                                                1
# 144 g CO2/km (comb)                                                1
# 132 g CO2/km (comb)                                                1
# 159 g CO2/km (comb)                                                1
# 5.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       1
# 158 g CO2/km (comb)                                                1
# 150 g CO2/km (comb)                                                1
# 6.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)       1
# 91 g CO2/km (comb)                                                 1
# 101 g CO2/km (comb)                                                1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       1
# 175 g CO2/km (comb)                                                1
# Name: non_smoking_vehicle, dtype: int64
#
# Value_counts with sort index :
#                                                                  3717
# 1 (No sticker)                                                    24
# 1.6 l/100 km (comb)                                                1
# 100 g CO2/km (comb)                                               18
# 101 g CO2/km (comb)                                                1
# 102 g CO2/km (comb)                                               11
# 103 g CO2/km (comb)                                               12
# 104 g CO2/km (comb)                                               36
# 105 g CO2/km (comb)                                               18
# 106 g CO2/km (comb)                                               20
# 107 g CO2/km (comb)                                               36
# 108 g CO2/km (comb)                                               19
# 109 g CO2/km (comb)                                               18
# 110 g CO2/km (comb)                                                3
# 111 g CO2/km (comb)                                                2
# 112 g CO2/km (comb)                                                9
# 113 g CO2/km (comb)                                               18
# 114 g CO2/km (comb)                                               12
# 115 g CO2/km (comb)                                                5
# 116 g CO2/km (comb)                                               11
# 117 g CO2/km (comb)                                                6
# 118 g CO2/km (comb)                                                8
# 119 g CO2/km (comb)                                                3
# 120 g CO2/km (comb)                                               63
# 121 g CO2/km (comb)                                                2
# 122 g CO2/km (comb)                                                1
# 123 g CO2/km (comb)                                                4
# 124 g CO2/km (comb)                                               29
# 125 g CO2/km (comb)                                                2
# 126 g CO2/km (comb)                                                6
# 127 g CO2/km (comb)                                               10
# 128 g CO2/km (comb)                                                7
# 129 g CO2/km (comb)                                               14
# 130 g CO2/km (comb)                                                5
# 131 g CO2/km (comb)                                               13
# 132 g CO2/km (comb)                                                1
# 133 g CO2/km (comb)                                               12
# 134 g CO2/km (comb)                                                2
# 135 g CO2/km (comb)                                               11
# 136 g CO2/km (comb)                                                3
# 137 g CO2/km (comb)                                                6
# 138 g CO2/km (comb)                                                2
# 139 g CO2/km (comb)                                                7
# 140 g CO2/km (comb)                                                6
# 142 g CO2/km (comb)                                                2
# 143 g CO2/km (comb)                                               10
# 144 g CO2/km (comb)                                                1
# 146 g CO2/km (comb)                                                1
# 147 g CO2/km (comb)                                                7
# 148 g CO2/km (comb)                                                3
# 149 g CO2/km (comb)                                                3
# 150 g CO2/km (comb)                                                1
# 151 g CO2/km (comb)                                                4
# 152 g CO2/km (comb)                                                1
# 153 g CO2/km (comb)                                               31
# 154 g CO2/km (comb)                                                1
# 156 g CO2/km (comb)                                                1
# 157 g CO2/km (comb)                                                3
# 158 g CO2/km (comb)                                                1
# 159 g CO2/km (comb)                                                1
# 161 g CO2/km (comb)                                                1
# 166 g CO2/km (comb)                                                2
# 169 g CO2/km (comb)                                                1
# 172 g CO2/km (comb)                                                1
# 175 g CO2/km (comb)                                                1
# 189 g CO2/km (comb)                                                1
# 4 (Green)                                                       1240
# 5 (Blue)                                                           8
# 5.2 l/100 km (comb)5.8 l/100 km (city)4.8 l/100 km (country)       4
# 5.2 l/100 km (comb)6.4 l/100 km (city)4.4 l/100 km (country)       2
# 5.6 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       1
# 5.7 l/100 km (comb)7.3 l/100 km (city)4.7 l/100 km (country)       1
# 6.1 l/100 km (comb)7.7 l/100 km (city)5.2 l/100 km (country)       1
# 6.1 l/100 km (comb)7.8 l/100 km (city)5.1 l/100 km (country)       1
# 6.2 l/100 km (comb)7.9 l/100 km (city)5.3 l/100 km (country)       1
# 6.3 l/100 km (comb)8 l/100 km (city)5.3 l/100 km (country)         1
# 6.4 l/100 km (comb)8.1 l/100 km (city)5.4 l/100 km (country)       1
# 6.5 l/100 km (comb)7.9 l/100 km (city)5.6 l/100 km (country)       1
# 6.5 l/100 km (comb)8.5 l/100 km (city)5.4 l/100 km (country)       1
# 82 g CO2/km (comb)                                                 1
# 85 g CO2/km (comb)                                                46
# 90 g CO2/km (comb)                                                 2
# 91 g CO2/km (comb)                                                 1
# 92 g CO2/km (comb)                                                 9
# 95 g CO2/km (comb)                                                 3
# 97 g CO2/km (comb)                                                20
# 98 g CO2/km (comb)                                                15
# 99 g CO2/km (comb)                                                23
# Euro 5                                                             4
# Euro 6                                                          1127
# Euro 6c                                                           17
# Euro 6d                                                            9
# Euro 6d-TEMP                                                     345
# NaN                                                             8742
# Name: non_smoking_vehicle, dtype: int64
# ########################################
#
# column name :  null
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  1
# Value_counts :
#      15919
# Name: null, dtype: int64
#
# Value_counts with sort index :
#      15919
# Name: null, dtype: int64
# ########################################
#
# column name :  make
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  3
# Value_counts :
#  Opel       7343
# Audi       5712
# Renault    2864
# Name: make, dtype: int64
#
# Value_counts with sort index :
#  Audi       5712
# Opel       7343
# Renault    2864
# Name: make, dtype: int64
# ########################################
#
# column name :  model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
# Value_counts :
#  A3          3097
# A1          2614
# Insignia    2598
# Astra       2526
# Corsa       2219
# Clio        1839
# Espace       991
# Duster        34
# A2             1
# Name: model, dtype: int64
#
# Value_counts with sort index :
#  A1          2614
# A2             1
# A3          3097
# Astra       2526
# Clio        1839
# Corsa       2219
# Duster        34
# Espace       991
# Insignia    2598
# Name: model, dtype: int64
# ########################################
#
# column name :  offer_number
# --------------------------------
# Per_of_Nulls   :  % 19.94
# Num_of_Nulls   :  3175
# Num_of_Uniques :  11440
# Value_counts :
#  NaN                                         3175
# LT67679                                       27
# UN89904                                       27
# XJ38068                                       27
# JV03654                                       27
#                                             ...
# 160_dcbb6c3e-a6da-43a3-8754-ccd994cec93b       1
# 6701576                                        1
# 6701569                                        1
# 158121                                         1
# Re_30000008029                                 1
# Name: offer_number, Length: 11441, dtype: int64
#
# Value_counts with sort index :
#  # 250678          1
# # 8H6050830       1
# # G1024529        1
# # G6050580        1
# #8023778          2
#                ...
# x_45689v          2
# y8fx64x           1
# zr11914           1
# zr11916           1
# NaN            3175
# Name: offer_number, Length: 11441, dtype: int64
# ########################################
#
# column name :  first_registration
# --------------------------------
# Per_of_Nulls   :  % 10.03
# Num_of_Nulls   :  1597
# Num_of_Uniques :  4
# Value_counts :
#  2018    4522
# 2016    3674
# 2017    3273
# 2019    2853
# NaN     1597
# Name: first_registration, dtype: int64
#
# Value_counts with sort index :
#  2016    3674
# 2017    3273
# 2018    4522
# 2019    2853
# NaN     1597
# Name: first_registration, dtype: int64
# ########################################
#
# column name :  body_color
# --------------------------------
# Per_of_Nulls   :  % 3.75
# Num_of_Nulls   :  597
# Num_of_Uniques :  14
# Value_counts :
#  Black     3745
# Grey      3505
# White     3406
# Silver    1647
# Blue      1431
# Red        957
# NaN        597
# Brown      289
# Green      154
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Gold         2
# Name: body_color, dtype: int64
#
# Value_counts with sort index :
#  Beige      108
# Black     3745
# Blue      1431
# Bronze       6
# Brown      289
# Gold         2
# Green      154
# Grey      3505
# Orange       3
# Red        957
# Silver    1647
# Violet      18
# White     3406
# Yellow      51
# NaN        597
# Name: body_color, dtype: int64
# ########################################
#
# column name :  paint_type
# --------------------------------
# Per_of_Nulls   :  % 36.26
# Num_of_Nulls   :  5772
# Num_of_Uniques :  3
# Value_counts :
#  Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: paint_type, dtype: int64
#
# Value_counts with sort index :
#  Metallic       9794
# Perl effect       6
# Uni/basic       347
# NaN            5772
# Name: paint_type, dtype: int64
# ########################################
#
# column name :  body_color_original
# --------------------------------
# Per_of_Nulls   :  % 23.61
# Num_of_Nulls   :  3759
# Num_of_Uniques :  1927
# Value_counts :
#  NaN                              3759
# Onyx Schwarz                      338
# Bianco                            282
# Mythosschwarz Metallic            238
# Brillantschwarz                   216
#                                  ...
# Rouge-Braun (G0Y)                   1
# VARI COLRI DISPONIBILI              1
# Kokosnussbraun Metallic             1
# Farbe frei wählbar                  1
# Perlmutt-Weiß Metallic (Weiß)       1
# Name: body_color_original, Length: 1928, dtype: int64
#
# Value_counts with sort index :
#  "PLATIN"                          1
# "satinsilber "                    1
# (0C0C) Monsungrau Metallic        1
# (B4B4) Cortinaweiss               1
# (NNP)                             1
#                                ...
# wählbar - ggf. mit Aufpreis     118
# wählbar -ggfl. mit Aufpreis       1
# wählbar, ggf gegen Aufpreis       2
# zwart                             2
# NaN                            3759
# Name: body_color_original, Length: 1928, dtype: int64
# ########################################
#
# column name :  upholstery
# --------------------------------
# Per_of_Nulls   :  % 23.37
# Num_of_Nulls   :  3720
# Num_of_Uniques :  46
# Value_counts :
#  Cloth, Black           5821
# NaN                    3720
# Part leather, Black    1121
# Cloth                  1005
# Cloth, Grey             891
# Cloth, Other            639
# Full leather, Black     575
# Black                   491
# Grey                    273
# Other, Other            182
# Part leather            140
# Full leather            139
# Full leather, Brown     116
# Part leather, Grey      116
# Other, Black            110
# Full leather, Other      72
# Full leather, Grey       67
# Part leather, Other      65
# Other                    56
# Part leather, Brown      50
# alcantara, Black         47
# Velour, Black            36
# Full leather, Beige      36
# Cloth, Brown             28
# Velour                   16
# Other, Grey              15
# Cloth, Beige             13
# Brown                    12
# Cloth, Blue              12
# Velour, Grey              8
# Cloth, White              8
# alcantara, Grey           6
# Cloth, Red                5
# Other, Yellow             4
# Part leather, Red         3
# Beige                     3
# Part leather, White       2
# Full leather, Blue        2
# alcantara, Other          2
# alcantara                 2
# White                     2
# Part leather, Beige       2
# Blue                      2
# Cloth, Orange             1
# Full leather, Red         1
# Other, Brown              1
# Full leather, White       1
# Name: upholstery, dtype: int64
#
# Value_counts with sort index :
#  Beige                     3
# Black                   491
# Blue                      2
# Brown                    12
# Cloth                  1005
# Cloth, Beige             13
# Cloth, Black           5821
# Cloth, Blue              12
# Cloth, Brown             28
# Cloth, Grey             891
# Cloth, Orange             1
# Cloth, Other            639
# Cloth, Red                5
# Cloth, White              8
# Full leather            139
# Full leather, Beige      36
# Full leather, Black     575
# Full leather, Blue        2
# Full leather, Brown     116
# Full leather, Grey       67
# Full leather, Other      72
# Full leather, Red         1
# Full leather, White       1
# Grey                    273
# Other                    56
# Other, Black            110
# Other, Brown              1
# Other, Grey              15
# Other, Other            182
# Other, Yellow             4
# Part leather            140
# Part leather, Beige       2
# Part leather, Black    1121
# Part leather, Brown      50
# Part leather, Grey      116
# Part leather, Other      65
# Part leather, Red         3
# Part leather, White       2
# Velour                   16
# Velour, Black            36
# Velour, Grey              8
# White                     2
# alcantara                 2
# alcantara, Black         47
# alcantara, Grey           6
# alcantara, Other          2
# NaN                    3720
# Name: upholstery, dtype: int64
# ########################################
#
# column name :  body
# --------------------------------
# Per_of_Nulls   :  % 0.38
# Num_of_Nulls   :  60
# Num_of_Uniques :  9
# Value_counts :
#  Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body, dtype: int64
#
# Value_counts with sort index :
#  Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body, dtype: int64
# ########################################
#
# column name :  nr_of_doors
# --------------------------------
# Per_of_Nulls   :  % 1.33
# Num_of_Nulls   :  212
# Num_of_Uniques :  6
# Value_counts :
#  5      11575
# 4       3079
# 3        832
# 2        219
# NaN      212
# 1          1
# 7          1
# Name: nr_of_doors, dtype: int64
#
# Value_counts with sort index :
#  1          1
# 2        219
# 3        832
# 4       3079
# 5      11575
# 7          1
# NaN      212
# Name: nr_of_doors, dtype: int64
# ########################################
#
# column name :  nr_of_seats
# --------------------------------
# Per_of_Nulls   :  % 6.14
# Num_of_Nulls   :  977
# Num_of_Uniques :  6
# Value_counts :
#  5      13336
# 4       1125
# NaN      977
# 7        362
# 2        116
# 6          2
# 3          1
# Name: nr_of_seats, dtype: int64
#
# Value_counts with sort index :
#  2        116
# 3          1
# 4       1125
# 5      13336
# 6          2
# 7        362
# NaN      977
# Name: nr_of_seats, dtype: int64
# ########################################
#
# column name :  model_code
# --------------------------------
# Per_of_Nulls   :  % 68.73
# Num_of_Nulls   :  10941
# Num_of_Uniques :  232
# Value_counts :
#  NaN         10941
# 0035/BCB      268
# 0588/BNO      245
# 0588/BDB      206
# 0588/BHX      188
#             ...
# 0035/AVN        1
# 0035/BEM        1
# 0035/BAG        1
# 0035/BAA        1
# 3333/BKG        1
# Name: model_code, Length: 233, dtype: int64
#
# Value_counts with sort index :
#  0000/000       21
# 0000/035        1
# 0000/ACP        1
# 0035/AAA        1
# 0035/AAD        1
#             ...
# 3333/BJR       79
# 3333/BKG        1
# 3333/BKQ       18
# 3333/BKR        8
# NaN         10941
# Name: model_code, Length: 233, dtype: int64
# ########################################
#
# column name :  gearing_type
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  3
# Value_counts :
#  Manual            8153
# Automatic         7297
# Semi-automatic     469
# Name: gearing_type, dtype: int64
#
# Value_counts with sort index :
#  Automatic         7297
# Manual            8153
# Semi-automatic     469
# Name: gearing_type, dtype: int64
# ########################################
#
# column name :  displacement
# --------------------------------
# Per_of_Nulls   :  % 3.12
# Num_of_Nulls   :  496
# Num_of_Uniques :  77
# Value_counts :
#  1,598 cc     4761
# 999 cc       2438
# 1,398 cc     1314
# 1,399 cc      749
# 1,229 cc      677
# ...
# Name: description, Length: 12864, dtype: int64
# ########################################
#
# column name :  emission_label
# --------------------------------
# Per_of_Nulls   :  % 74.97
# Num_of_Nulls   :  11934
# Num_of_Uniques :  6
# Value_counts :
#  NaN               11934
# 4 (Green)          3553
# 1 (No sticker)      381
# [],[],[]             40
# 5 (Blue)              8
# 3 (Yellow)            2
# 2 (Red)               1
# Name: emission_label, dtype: int64
#
# Value_counts with sort index :
#  1 (No sticker)      381
# 2 (Red)               1
# 3 (Yellow)            2
# 4 (Green)          3553
# 5 (Blue)              8
# [],[],[]             40
# NaN               11934
# Name: emission_label, dtype: int64
# ########################################
#
# column name :  gears
# --------------------------------
# Per_of_Nulls   :  % 29.6
# Num_of_Nulls   :  4712
# Num_of_Uniques :  10
# Value_counts :
#  6      5822
# NaN    4712
# 5      3239
# 7      1908
# 8       224
# 9         6
# 1         2
# 3         2
# 4         2
# 2         1
# 50        1
# Name: gears, dtype: int64
#
# Value_counts with sort index :
#  1         2
# 2         1
# 3         2
# 4         2
# 5      3239
# 50        1
# 6      5822
# 7      1908
# 8       224
# 9         6
# NaN    4712
# Name: gears, dtype: int64
# ########################################
#
# column name :  country_version
# --------------------------------
# Per_of_Nulls   :  % 52.35
# Num_of_Nulls   :  8333
# Num_of_Uniques :  23
# Value_counts :
#  NaN               8333
# Germany           4502
# Italy             1038
# European Union     507
# Netherlands        464
# Spain              325
# Belgium            314
# Austria            208
# Czech Republic      52
# Poland              49
# France              38
# Denmark             33
# Hungary             28
# Japan                8
# Slovakia             4
# Croatia              4
# Sweden               3
# Romania              2
# Bulgaria             2
# Luxembourg           1
# Switzerland          1
# Slovenia             1
# Egypt                1
# Serbia               1
# Name: country_version, dtype: int64
#
# Value_counts with sort index :
#  Austria            208
# Belgium            314
# Bulgaria             2
# Croatia              4
# Czech Republic      52
# Denmark             33
# Egypt                1
# European Union     507
# France              38
# Germany           4502
# Hungary             28
# Italy             1038
# Japan                8
# Luxembourg           1
# Netherlands        464
# Poland              49
# Romania              2
# Serbia               1
# Slovakia             4
# Slovenia             1
# Spain              325
# Sweden               3
# Switzerland          1
# NaN               8333
# Name: country_version, dtype: int64
# ########################################
#
# column name :  electricity_consumption
# --------------------------------
# Per_of_Nulls   :  % 99.14
# Num_of_Nulls   :  15782
# Num_of_Uniques :  1
# Value_counts :
#  NaN                    15782
# 0 kWh/100 km (comb)      137
# Name: electricity_consumption, dtype: int64
#
# Value_counts with sort index :
#  0 kWh/100 km (comb)      137
# NaN                    15782
# Name: electricity_consumption, dtype: int64
# ########################################
#
# column name :  last_service_date
# --------------------------------
# Per_of_Nulls   :  % 96.44
# Num_of_Nulls   :  15353
# Num_of_Uniques :  255
# Value_counts :
#  NaN                           15353
# 02/2019Euro 6                    23
# 05/2019Euro 6                    16
# 01/2018118 g CO2/km (comb)       15
# 03/2019Euro 6                    15
#                               ...
# 01/201795 g CO2/km (comb)         1
# 06/201987 g CO2/km (comb)         1
# 10/2018100 g CO2/km (comb)        1
# 02/201897 g CO2/km (comb)         1
# 03/2019120 g CO2/km (comb)        1
# Name: last_service_date, Length: 256, dtype: int64
#
# Value_counts with sort index :
#  01/2017102 g CO2/km (comb)        1
# 01/2017107 g CO2/km (comb)        1
# 01/201795 g CO2/km (comb)         1
# 01/2018                           1
# 01/2018114 g CO2/km (comb)        1
#                               ...
# 12/20185 (Blue)                   1
# 12/201897 g CO2/km (comb)         1
# 12/201899 g CO2/km (comb)         2
# 12/2018Euro 6                    11
# NaN                           15353
# Name: last_service_date, Length: 256, dtype: int64
# ########################################
#
# column name :  other_fuel_types
# --------------------------------
# Per_of_Nulls   :  % 94.47
# Num_of_Nulls   :  15039
# Num_of_Uniques :  1
# Value_counts :
#  NaN         15039
# [],[],[]      880
# Name: other_fuel_types, dtype: int64
#
# Value_counts with sort index :
#  [],[],[]      880
# NaN         15039
# Name: other_fuel_types, dtype: int64
# ########################################
#
# column name :  availability
# --------------------------------
# Per_of_Nulls   :  % 96.01
# Num_of_Nulls   :  15284
# Num_of_Uniques :  15
# Value_counts :
#  NaN                          15284
# in 90 days from ordering       196
# in 120 days from ordering      182
# in 1 day from ordering          51
# in 5 days from ordering         35
# in 3 days from ordering         35
# in 180 days from ordering       24
# in 14 days from ordering        24
# in 7 days from ordering         20
# in 150 days from ordering       18
# in 2 days from ordering         16
# in 60 days from ordering        13
# in 42 days from ordering        10
# in 21 days from ordering         8
# in 4 days from ordering          2
# in 6 days from ordering          1
# Name: availability, dtype: int64
#
# Value_counts with sort index :
#  in 1 day from ordering          51
# in 120 days from ordering      182
# in 14 days from ordering        24
# in 150 days from ordering       18
# in 180 days from ordering       24
# in 2 days from ordering         16
# in 21 days from ordering         8
# in 3 days from ordering         35
# in 4 days from ordering          2
# in 42 days from ordering        10
# in 5 days from ordering         35
# in 6 days from ordering          1
# in 60 days from ordering        13
# in 7 days from ordering         20
# in 90 days from ordering       196
# NaN                          15284
# Name: availability, dtype: int64
# ########################################
#
# column name :  last_timing_belt_service_date
# --------------------------------
# Per_of_Nulls   :  % 99.9
# Num_of_Nulls   :  15903
# Num_of_Uniques :  15
# Value_counts :
#  NaN              15903
# 04/2016              2
# 12/1900              1
# 07/2018              1
# 01/1900              1
# 05/2019              1
# 09/2018              1
# 05/2018Euro 6        1
# 06/2017              1
# 01/2019              1
# 02/2019              1
# 02/2018              1
# 06/2019              1
# 01/2018              1
# 04/2019              1
# 01/1970              1
# Name: last_timing_belt_service_date, dtype: int64
#
# Value_counts with sort index :
#  01/1900              1
# 01/1970              1
# 01/2018              1
# 01/2019              1
# 02/2018              1
# 02/2019              1
# 04/2016              2
# 04/2019              1
# 05/2018Euro 6        1
# 05/2019              1
# 06/2017              1
# 06/2019              1
# 07/2018              1
# 09/2018              1
# 12/1900              1
# NaN              15903
# Name: last_timing_belt_service_date, dtype: int64
# ########################################
#
# column name :  available_from
# --------------------------------
# Per_of_Nulls   :  % 98.29
# Num_of_Nulls   :  15647
# Num_of_Uniques :  46
# Value_counts :
#  NaN         15647
# 31/08/19       98
# 30/07/19       25
# 15/08/19       24
# 16/09/19       14
# 29/06/19       12
# 01/07/19       11
# 28/06/19       10
# 19/08/19        7
# 10/09/19        6
# 26/06/19        5
# 27/06/19        5
# 10/11/19        5
# 08/07/19        4
# 15/07/19        3
# 25/10/19        3
# 01/08/19        3
# 04/07/19        2
# 05/08/19        2
# 24/08/19        2
# 16/07/19        2
# 20/07/19        2
# 05/07/19        2
# 30/06/19        2
# 30/09/19        1
# 31/10/19        1
# 27/07/19        1
# 02/07/19        1
# 10/07/19        1
# 19/07/19        1
# 24/07/19        1
# 29/07/19        1
# 29/09/19        1
# 18/08/19        1
# 14/09/19        1
# 18/07/19        1
# 16/08/19        1
# 24/09/19        1
# 17/08/19        1
# 10/10/19        1
# 06/12/19        1
# 03/12/19        1
# 05/12/19        1
# 11/08/19        1
# 10/12/19        1
# 01/09/19        1
# 03/08/19        1
# Name: available_from, dtype: int64
#
# Value_counts with sort index :
#  01/07/19       11
# 01/08/19        3
# 01/09/19        1
# 02/07/19        1
# 03/08/19        1
# 03/12/19        1
# 04/07/19        2
# 05/07/19        2
# 05/08/19        2
# 05/12/19        1
# 06/12/19        1
# 08/07/19        4
# 10/07/19        1
# 10/09/19        6
# 10/10/19        1
# 10/11/19        5
# 10/12/19        1
# 11/08/19        1
# 14/09/19        1
# 15/07/19        3
# 15/08/19       24
# 16/07/19        2
# 16/08/19        1
# 16/09/19       14
# 17/08/19        1
# 18/07/19        1
# 18/08/19        1
# 19/07/19        1
# 19/08/19        7
# 20/07/19        2
# 24/07/19        1
# 24/08/19        2
# 24/09/19        1
# 25/10/19        3
# 26/06/19        5
# 27/06/19        5
# 27/07/19        1
# 28/06/19       10
# 29/06/19       12
# 29/07/19        1
# 29/09/19        1
# 30/06/19        2
# 30/07/19       25
# 30/09/19        1
# 31/08/19       98
# 31/10/19        1
# NaN         15647
# Name: available_from, dtype: int64
# ########################################
#
# column name :  consumption_comb
# --------------------------------
# Per_of_Nulls   :  % 12.77
# Num_of_Nulls   :  2033
# Num_of_Uniques :  72
# Value_counts :
#  NaN     2033
# 5.4      770
# 3.9      733
# 4        713
# 5.1      657
# 4.4      623
# 5.6      618
# 4.7      602
# 3.8      585
# 4.8      546
# 5        545
# 4.5      523
# 5.2      454
# 4.2      435
# 4.6      426
# 4.9      393
# 5.5      380
# 5.3      380
# 3.7      369
# 5.9      369
# 4.1      342
# 5.7      342
# 6        331
# 4.3      307
# 3.3      307
# 3.5      288
# 6.2      216
# 3.6      194
# 6.3      181
# 6.1      175
# 5.8      164
# 6.6      148
# 6.8      136
# 3.4      106
# 6.4       75
# 3         69
# 7.4       66
# 6.5       43
# 6.7       43
# 7.1       38
# 10        34
# 6.9       27
# 3.2       25
# 8.3       20
# 7.6       14
# 7         10
# 3.1        7
# 7.2        6
# 7.8        6
# 8          5
# 51         4
# 8.6        4
# 7.9        3
# 8.7        3
# 1.6        3
# 7.3        2
# 8.1        2
# 40         2
# 38         2
# 0          2
# 9.1        1
# 43         1
# 7.5        1
# 13.8       1
# 55         1
# 54         1
# 1.2        1
# 32         1
# 33         1
# 50         1
# 1          1
# 46         1
# 11         1
# Name: consumption_comb, dtype: int64
#
# Value_counts with sort index :
#  0          2
# 1          1
# 1.2        1
# 1.6        3
# 10        34
# 11         1
# 13.8       1
# 3         69
# 3.1        7
# 3.2       25
# 3.3      307
# 3.4      106
# 3.5      288
# 3.6      194
# 3.7      369
# 3.8      585
# 3.9      733
# 32         1
# 33         1
# 38         2
# 4        713
# 4.1      342
# 4.2      435
# 4.3      307
# 4.4      623
# 4.5      523
# 4.6      426
# 4.7      602
# 4.8      546
# 4.9      393
# 40         2
# 43         1
# 46         1
# 5        545
# 5.1      657
# 5.2      454
# 5.3      380
# 5.4      770
# 5.5      380
# 5.6      618
# 5.7      342
# 5.8      164
# 5.9      369
# 50         1
# 51         4
# 54         1
# 55         1
# 6        331
# 6.1      175
# 6.2      216
# 6.3      181
# 6.4       75
# 6.5       43
# 6.6      148
# 6.7       43
# 6.8      136
# 6.9       27
# 7         10
# 7.1       38
# 7.2        6
# 7.3        2
# 7.4       66
# 7.5        1
# 7.6       14
# 7.8        6
# 7.9        3
# 8          5
# 8.1        2
# 8.3       20
# 8.6        4
# 8.7        3
# 9.1        1
# NaN     2033
# Name: consumption_comb, dtype: int64
# ########################################
#
# column name :  consumption_city
# --------------------------------
# Per_of_Nulls   :  % 15.3
# Num_of_Nulls   :  2436
# Num_of_Uniques :  86
# Value_counts :
#  NaN     2436
# 5        669
# 5.8      633
# 4.5      580
# 4.3      533
# 5.1      479
# 6.8      454
# 7.2      445
# 7.3      435
# 4.6      417
# 7.8      413
# 5.9      389
# 5.7      376
# 4.2      353
# 6.6      352
# 6.7      346
# 5.2      345
# 6.3      338
# 5.4      321
# 4.1      320
# 4        300
# 4.7      289
# 7.5      267
# 7.1      258
# 6        251
# 7.6      248
# 3.9      245
# 3.5      230
# 6.9      223
# 5.5      216
# 6.2      211
# 7.7      204
# 7        194
# 7.4      179
# 6.5      162
# 8.7      161
# 6.1      152
# 8.2      140
# 4.4      136
# 6.4      121
# 8        110
# 5.6      104
# 5.3      101
# 7.9      101
# 4.8       72
# 4.9       58
# 3.7       53
# 3.4       50
# 8.6       42
# 9.6       42
# 8.3       41
# 8.5       39
# 9.2       34
# 3.3       30
# 3.8       26
# 8.1       25
# 10.2      21
# 11.3      19
# 10        16
# 9.9       15
# 9.4       14
# 9.1       12
# 3          9
# 8.4        7
# 0          6
# 9.8        5
# 11.5       4
# 11         4
# 11.2       4
# 62         4
# 8.9        4
# 10.8       3
# 9.5        3
# 10.1       2
# 43         2
# 45         2
# 1          2
# 8.8        2
# 3.6        2
# 19.9       1
# 64         1
# 66         1
# 9          1
# 10.5       1
# 16.1       1
# 10.4       1
# 9.7        1
# Name: consumption_city, dtype: int64
#
# Value_counts with sort index :
#  0          6
# 1          2
# 10        16
# 10.1       2
# 10.2      21
# 10.4       1
# 10.5       1
# 10.8       3
# 11         4
# 11.2       4
# 11.3      19
# 11.5       4
# 16.1       1
# 19.9       1
# 3          9
# 3.3       30
# 3.4       50
# 3.5      230
# 3.6        2
# 3.7       53
# 3.8       26
# 3.9      245
# 4        300
# 4.1      320
# 4.2      353
# 4.3      533
# 4.4      136
# 4.5      580
# 4.6      417
# 4.7      289
# 4.8       72
# 4.9       58
# 43         2
# 45         2
# 5        669
# 5.1      479
# 5.2      345
# 5.3      101
# 5.4      321
# 5.5      216
# 5.6      104
# 5.7      376
# 5.8      633
# 5.9      389
# 6        251
# 6.1      152
# 6.2      211
# 6.3      338
# 6.4      121
# 6.5      162
# 6.6      352
# 6.7      346
# 6.8      454
# 6.9      223
# 62         4
# 64         1
# 66         1
# 7        194
# 7.1      258
# 7.2      445
# 7.3      435
# 7.4      179
# 7.5      267
# 7.6      248
# 7.7      204
# 7.8      413
# 7.9      101
# 8        110
# 8.1       25
# 8.2      140
# 8.3       41
# 8.4        7
# 8.5       39
# 8.6       42
# 8.7      161
# 8.8        2
# 8.9        4
# 9          1
# 9.1       12
# 9.2       34
# 9.4       14
# 9.5        3
# 9.6       42
# 9.7        1
# 9.8        5
# 9.9       15
# NaN     2436
# Name: consumption_city, dtype: int64
# ########################################
#
# column name :  consumption_country
# --------------------------------
# Per_of_Nulls   :  % 14.93
# Num_of_Nulls   :  2376
# Num_of_Uniques :  57
# Value_counts :
#  NaN     2376
# 4.2     1178
# 3.7     1089
# 4.4      898
# 4.5      848
# 3.8      802
# 3.9      777
# 4.7      615
# 4.1      592
# 4        589
# 3.5      525
# 4.3      520
# 4.6      516
# 3.6      486
# 4.9      481
# 3.1      481
# 3.3      457
# 3.4      353
# 4.8      341
# 5.3      278
# 5.4      239
# 5.1      232
# 5.7      204
# 3.2      180
# 5.6      154
# 3        142
# 5        130
# 5.2      117
# 6.3       52
# 6         42
# 5.5       36
# 10        32
# 5.8       30
# 7.7       20
# 6.6       19
# 2.9       16
# 6.4       15
# 2.8        9
# 0          9
# 7.3        4
# 44         4
# 6.5        4
# 7          3
# 7.1        3
# 6.9        2
# 35         2
# 37         2
# 6.1        2
# 5.9        2
# 6.7        2
# 7.8        2
# 7.6        1
# 42         1
# 8          1
# 8.6        1
# 10.3       1
# 2          1
# 1          1
# Name: consumption_country, dtype: int64
#
# Value_counts with sort index :
#  0          9
# 1          1
# 10        32
# 10.3       1
# 2          1
# 2.8        9
# 2.9       16
# 3        142
# 3.1      481
# 3.2      180
# 3.3      457
# 3.4      353
# 3.5      525
# 3.6      486
# 3.7     1089
# 3.8      802
# 3.9      777
# 35         2
# 37         2
# 4        589
# 4.1      592
# 4.2     1178
# 4.3      520
# 4.4      898
# 4.5      848
# 4.6      516
# 4.7      615
# 4.8      341
# 4.9      481
# 42         1
# 44         4
# 5        130
# 5.1      232
# 5.2      117
# 5.3      278
# 5.4      239
# 5.5       36
# 5.6      154
# 5.7      204
# 5.8       30
# 5.9        2
# 6         42
# 6.1        2
# 6.3       52
# 6.4       15
# 6.5        4
# 6.6       19
# 6.7        2
# 6.9        2
# 7          3
# 7.1        3
# 7.3        4
# 7.6        1
# 7.7       20
# 7.8        2
# 8          1
# 8.6        1
# NaN     2376
# Name: consumption_country, dtype: int64
# ########################################

# %%
# null kolonu içi boş. düşülecek
# kW kolonu içi boş. düşülecek.
# "url" tüm analiz sonrası silinecek veya analiz başında silinecek df_orjinal den bakılacak
# Audi A2 ile ilgili tek satır veri var
# km sütunu temizlenecek ve integer yapılacak
# registration sutununda "-/-" şeklinde veri var
# prev_owner sutunu temizlecek ve integer yapılacak
# hp sutunu temizlenecek integer yapılacak ve "- kW,1 kW" bu gibi küçük değerlere bakılacak
# previous_owners kolonunun içeriği ve adı kıyaslanacak. temizlenecek integer yapılacak
            #ve prev_owner sutunu ile kıyaslanıp tek sutun yapılacak
# next_inspection null veriler doldurulabilir.temizlenecek. datatype date yapılacak
# inspection_new kolonu "yes" "no" şeklinde düzenlenebilir.
# warranty kolonunda null ve boş veriler var. ay formatına çevirilecek ve integer yapılacak
# full_service kolonunda null ve boş veriler var.
# non_smoking_vehicle kolonunda null ve boş veriler var.
# make_model kolonu ile "make" ve "model" kolonları karşılaştırılıp hangisinin düşürüleceğine karar verilecek
# offer number kolonu ML de işe yaramayabilir. düşülebilir.
# first_registration kolonundaki null değerler için registration kolonuna bakılabilir..
# paint_type kolonu metallic, non-metallic ve other olarak kategorize edilebilir
# upholstery kolonu kategorize edilecek
# body ve body type sutunu aynı birisi düşürülecek
# "nr_of_doors" kolonunda "1,7 veya null" veriler incelenecek
# "nr_of_seats" kolonunda "3,6 veya null" veriler incelenecek
# model_code kolonu düşürülebilir
# displacement kolonu numeric yapılacak
# cylinders kolonundaki null verilerkontrol edilecek
# weight kolonu numeric yapılacak
# drive chain kolonu null değerleri nasıl doldurulacak. Diğer modellere bakılarak doldurulabilir.
# fuel kolonu kategorize edilecek.(Benzin, Dizel, Gaz, Diğer olabilir)
# consumption kolonu 3 sütuna bölübdü. Null değerler doldurulabilir mi, incelenecek.
# co_2_emission ve emission_class sütunları birlikte incelenip, null değerler doldurulabilir mi bakılacak.
# ...Birbiri ile ilişkili ise biri düşülebilir. co_2_emission kategorize edilebilir mi, bakılacak.
# comfort_&_convenience sütunundaki null değerler incelenecek? Belki genel özellikler ayrı sütunlar yapılabilir(python, sql, ... required skills gibi)
# entertainment_&_media null değerler incelenecek? Belki genel özellikler ayrı sütunlar yapılabilir(python, sql, ... required skills gibi)
# extras null değerler incelenecek? Belki genel özellikler ayrı sütunlar yapılabilir(python, sql, ... required skills gibi)
# safety_&_security null değerler incelenecek? Belki genel özellikler ayrı sütunlar yapılabilir(python, sql, ... required skills gibi)
# ...description kolonuna bakılarak paket mi/ değil mi incelenip, sınıflandırılabilir belki.
# description ilan açıklaması gibi. düşülebilir.
# emission_label diğer emisyon sütunları(2 sütun:emission class ve Co2 emissin) ile karşılaştırılarak ne yapılacağına karar verilecek.
# gears sütunundaki null değerler ve 1,2, 50 gibi strange değerler kontrol edilerek ne yapılacağına karar verilecek.
# country_version ilanın verildiği ülke gibi görünüyor. Null değer çok fazla. Düşülebilir(önce grafiğine bakılabilir).
# electricity_consumption % 99 null. düşülebilir.
# last_service_date null değer % 95 üzerinde null değer var. House price'daki gibi %95 üzerinde null değer içieren kolonlar tek bri kod ile düşülebilir.
# other_fuel_types çoğu null. kalanı da boş liste. listeler önce null'a çevirilecek. Sonra düşülecek.
# availability çoğu null. düşülebilir.
# last_timing_belt_service_date çoğu null. düşülebilir.
# available_from çoğu null. düşülebilir.
# bizim oluşturduğumuz kolonlar(consumption_comb, consumption_city, consumption_country) daki null değerler nasıl doldurulacak. Kontrol edilip, karar verilecek.

# ÖNEMLİ: df'te yer alan tüm boş listeler ve boş olanlar null'a çevirilecek. Sonra value counts'lar tekrar kontrol edilecek.

# %%
df.description.values[0]
# Out:
# 'Sicherheit:, ,Deaktivierung für Beifahrer-Airbag, ,ESC mit elektronischer Quersperre, ,Tagfahrlicht, ,Reifendruck-Kontrollanzeige, ,Kopfairbag-System mit Seiten-Airbags vorn, ,Sicherheitslenksäule,Assistenzsysteme:, ,Berganfahrassistent,Komfort:, ,Scheinwerferreinigung, ,Xenon plus inklusive Scheinwerfer-Reinigungsanlage, ,Scheinwerfer-Reinigungsanlage, ,Einparkhilfe hinten, ,Licht-/Regensensor, ,Funkfernbedienung, ,Elektrische Luftzusatzheizung,Interieur:, ,Rücksitzanlage 2 + 1, ,Multifunktions-Sportlederlenkrad im 3-Speichen-Design, ,automatische Leuchtweitenregulierung, ,Fahrerinformationssystem, ,Staub- und Pollenfilter, ,Kopfstützen hinten (3 Stück), ,Stoff Zeitgeist, ,Fahrersitz manuell höheneinstellbar, ,Scheiben seitlich und hinten in Wärmeschutzverglasung, ,Kindersitzbefestigung ISOFIX und Top Tether für die äußeren Fondsitze, ,Dachhimmel in Stoff titangrau, ,Waschwasser-Standanzeige, ,Nichtraucherfahrzeug,Exterieur:, ,Elektrische Aussenspiegel, ,Außenspiegel elektrisch beheizbar inklusive beheizbarer Scheibenwaschdüsen, ,Scheibenwaschdüsen beheizbar vorn, ,Aluminium-Gussräder im 10-Speichen-Design Größe 7 J x 16 mit Reifen 215/45 R 16, ,LED-Heckleuchten, ,Dynamikfahrwerk, ,Reifenreparaturset, ,Heckscheibenwischer mit Wasch-Wisch-Automatik,Umwelt:, ,Start-Stop-System, ,Abgaskonzept EU6 plus,Multimedia:, ,Radio mit Dreifachtuner und Phasendiversity, ,Bluetooth-Schnittstelle, ,media-Paket, ,Sprachdialogsystem, ,MMI® Navigation plus,Getriebe:, ,7-Gang-Automatikgetriebe,Sonstiges:, ,Scheckheft gepflegt, ,Frontscheibe mit grauem Colorstreifen am oberen Rand, ,Verbau der Startbatterie hinten ohne zweite Batterie, ,GebrauchtwagenPlus, ,Eingabefehler Irrtümer und Zwischenverkauf vorbehalten. Die gemachten Angaben in Anzeigen Internet Preisschildern und Bildern sind unverbindliche Beschreibungen und dienen nicht als zugesicherte Eigenschaften. Der Verkäufer übernimmt keine Haftung für Tipp- und Datenübermittlungsfehlern. Aufgeführte Ausstattungen sind ggfs. gesondert zu prüfen. Alle Angaben in den Inseraten sind unverbindlich und ohne Gewähr. Wir freuen uns auf Ihren Besuch.'

# %%
type(df.description.values[0])
# Out:
# str

# %%
type(df.apply(lambda x: ",".join(x) if isinstance(x, list) else x).description.values[0])
# Out:
# str

# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
