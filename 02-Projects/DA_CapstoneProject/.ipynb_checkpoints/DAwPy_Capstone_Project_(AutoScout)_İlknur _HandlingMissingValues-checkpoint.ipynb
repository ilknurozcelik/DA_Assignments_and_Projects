# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# # PART- 1 Data Cleaning

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches
import seaborn as sns

import warnings

# Statistics functions
from scipy.stats import norm
from scipy import stats
from scipy.stats import chi2_contingency
from scipy.stats import chi2
# Out:
# C:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Settings

# %%
# Suppressing a warning 
warnings.filterwarnings("ignore") 

# It is a magic function that renders the figure in the notebook
# %matplotlib inline 

# Changing the figure size of a seaborn axes 
sns.set(rc={"figure.figsize": (10, 6)})

# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid")

# To display maximum columns
pd.set_option('display.max_columns', None)

# To display maximum rows
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Reading scout_car.json file as a dataframe named df

# %%
df = pd.read_csv("scout_car_cleaned.csv")

# %% [markdown]
# ### Creating a copy from df named df_copy

# %%
df_copy = df.copy()

# %% [markdown]
# ## Checking the dataframe with head, tail and sample

# %%
# Checking the head of df

df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type    price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770.0
# 1                                     1.8 TFSI sport    Sedans  14500.0
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640.0
# 3                            1.4 TDi Design S tronic    Sedans  14500.0
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790.0
#
#                 vat       km  prev_owner  type previous_owners  \
# 0    VAT deductible  56013.0         2.0  Used               2
# 1  Price negotiable  80000.0         NaN  Used             NaN
# 2    VAT deductible  83450.0         1.0  Used               1
# 3               NaN  73000.0         1.0  Used               1
# 4               NaN  16200.0         1.0  Used               1
#
#               next_inspection           inspection_new            warranty  \
# 0  06/2021,99 g CO2/km (comb)               Yes,Euro 6           4 (Green)
# 1                         NaN                      NaN                 NaN
# 2                         NaN                      NaN  99 g CO2/km (comb)
# 3                         NaN                      NaN                 NaN
# 4                         NaN  Yes,109 g CO2/km (comb)              Euro 6
#
#          full_service non_smoking_vehicle  first_registration body_color  \
# 0                 NaN                 NaN              2016.0      Black
# 1                 NaN                 NaN              2017.0        Red
# 2                 NaN                 NaN              2016.0      Black
# 3  99 g CO2/km (comb)              Euro 6              2016.0      Brown
# 4           4 (Green)                 NaN              2016.0      Black
#
#   paint_type  nr_of_doors  nr_of_seats gearing_type  displacement_cc  \
# 0   Metallic          5.0          5.0    Automatic           1422.0
# 1        NaN          3.0          4.0    Automatic           1798.0
# 2   Metallic          4.0          4.0    Automatic           1598.0
# 3   Metallic          3.0          4.0    Automatic           1422.0
# 4   Metallic          5.0          5.0    Automatic           1422.0
#
#    cylinders drive_chain     fuel  co_2_emission emission_class  \
# 0        3.0       front   Diesel           99.0         Euro 6
# 1        4.0       front  Benzine          129.0         Euro 6
# 2        NaN       front   Diesel           99.0         Euro 6
# 3        3.0         NaN   Diesel           99.0         Euro 6
# 4        3.0       front   Diesel          109.0         Euro 6
#
#                                  comfort_convenience  \
# 0  Air conditioning,Armrest,Automatic climate con...
# 1  Air conditioning,Automatic climate control,Hil...
# 2  Air conditioning,Cruise control,Electrical sid...
# 3  Air suspension,Armrest,Auxiliary heating,Elect...
# 4  Air conditioning,Armrest,Automatic climate con...
#
#                                  entertainment_media  \
# 0  Bluetooth,Hands-free equipment,On-board comput...
# 1  Bluetooth,Hands-free equipment,On-board comput...
# 2                              MP3,On-board computer
# 3  Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4  Bluetooth,CD player,Hands-free equipment,MP3,O...
#
#                                               extras  \
# 0     Alloy wheels,Catalytic Converter,Voice Control
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                         Alloy wheels,Voice Control
# 3             Alloy wheels,Sport seats,Voice Control
# 4  Alloy wheels,Sport package,Sport suspension,Vo...
#
#                                      safety_security emission_label  gears  \
# 0  ABS,Central door lock,Daytime running lights,D...            NaN    NaN
# 1  ABS,Central door lock,Central door lock with r...      4 (Green)    7.0
# 2  ABS,Central door lock,Daytime running lights,D...      4 (Green)    NaN
# 3  ABS,Alarm system,Central door lock with remote...            NaN    6.0
# 4  ABS,Central door lock,Driver-side airbag,Elect...            NaN    NaN
#
#    hp_kw next_insp_date insp_new  warranty_month upholstery_type  \
# 0   66.0        06/2021      Yes             NaN           Cloth
# 1  141.0            NaN      NaN             NaN           Cloth
# 2   85.0            NaN      NaN             NaN           Cloth
# 3   66.0            NaN      NaN             NaN             NaN
# 4   66.0            NaN      Yes             NaN           Cloth
#
#   upholstery_color  weight_kg  consumption_comb  consumption_city  \
# 0            Black     1220.0               3.8               4.3
# 1             Grey     1255.0               5.6               7.1
# 2            Black        NaN               3.8               4.4
# 3              NaN     1195.0               3.8               4.3
# 4            Black        NaN               4.1               4.6
#
#    consumption_country
# 0                  3.5
# 1                  4.7
# 2                  3.4
# 3                  3.5
# 4                  3.8

# %%
# Checking the tail of df

df.tail()
# Out:
#                                                      url      make_model  \
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type    price  \
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950.0
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885.0
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875.0
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700.0
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999.0
#
#                   vat      km  prev_owner            type  \
# 15914  VAT deductible     NaN         NaN             New
# 15915  VAT deductible  9900.0         1.0            Used
# 15916  VAT deductible    15.0         1.0  Pre-registered
# 15917  VAT deductible    10.0         NaN  Pre-registered
# 15918  VAT deductible     NaN         1.0   Demonstration
#
#                                          previous_owners  \
# 15914                                                NaN
# 15915  1,,7.4 l/100 km (comb),,9.2 l/100 km (city),,6...
# 15916                              1,139 g CO2/km (comb)
# 15917                                                NaN
# 15918                                                  1
#
#                    next_inspection           inspection_new   warranty  \
# 15914                          NaN                      NaN  24 months
# 15915  01/2022,168 g CO2/km (comb)                      NaN     Euro 6
# 15916                          NaN         Yes,Euro 6d-TEMP  4 (Green)
# 15917                          NaN                      NaN        NaN
# 15918                          NaN  Yes,153 g CO2/km (comb)        NaN
#
#       full_service non_smoking_vehicle  first_registration body_color  \
# 15914          NaN                 NaN                 NaN       Grey
# 15915          NaN           4 (Green)              2019.0       Grey
# 15916          NaN                 NaN              2019.0      White
# 15917          NaN                 NaN              2019.0       Grey
# 15918          NaN                 NaN              2019.0       Grey
#
#       paint_type  nr_of_doors  nr_of_seats gearing_type  displacement_cc  \
# 15914   Metallic          5.0          5.0    Automatic           1997.0
# 15915   Metallic          5.0          5.0    Automatic           1798.0
# 15916        NaN          5.0          7.0    Automatic           1997.0
# 15917        NaN          5.0          7.0    Automatic           1997.0
# 15918   Metallic          5.0          5.0    Automatic           1798.0
#
#        cylinders drive_chain     fuel  co_2_emission emission_class  \
# 15914        4.0       front   Diesel          139.0            NaN
# 15915        4.0       front  Benzine          168.0            NaN
# 15916        4.0       front   Diesel          139.0   Euro 6d-TEMP
# 15917        4.0       front   Diesel          139.0         Euro 6
# 15918        4.0         4WD  Benzine          153.0         Euro 6
#
#                                      comfort_convenience  \
# 15914  Air conditioning,Automatic climate control,Cru...
# 15915  Air conditioning,Automatic climate control,Cru...
# 15916  Air conditioning,Armrest,Automatic climate con...
# 15917  Air conditioning,Automatic climate control,Cru...
# 15918  Air conditioning,Automatic climate control,Cru...
#
#                                      entertainment_media  \
# 15914  Bluetooth,Digital radio,Hands-free equipment,O...
# 15915  Bluetooth,Digital radio,Hands-free equipment,R...
# 15916  Bluetooth,Hands-free equipment,On-board comput...
# 15917                  Bluetooth,Digital radio,Radio,USB
# 15918                                                USB
#
#                                         extras  \
# 15914                Alloy wheels,Touch screen
# 15915  Alloy wheels,Touch screen,Voice Control
# 15916                             Alloy wheels
# 15917                Alloy wheels,Touch screen
# 15918                Alloy wheels,Touch screen
#
#                                          safety_security emission_label  \
# 15914  ABS,Central door lock,Central door lock with r...            NaN
# 15915  ABS,Adaptive Cruise Control,Blind spot monitor...            NaN
# 15916  ABS,Adaptive Cruise Control,Blind spot monitor...            NaN
# 15917  ABS,Blind spot monitor,Driver-side airbag,Elec...            NaN
# 15918  ABS,Blind spot monitor,Daytime running lights,...      4 (Green)
#
#        gears  hp_kw next_insp_date insp_new  warranty_month upholstery_type  \
# 15914    6.0  147.0            NaN      NaN            24.0             NaN
# 15915    7.0  165.0        01/2022      NaN             NaN           Cloth
# 15916    6.0  146.0            NaN      Yes             NaN    Full leather
# 15917    6.0  147.0            NaN      NaN             NaN    Part leather
# 15918    NaN  165.0            NaN      Yes             NaN    Full leather
#
#       upholstery_color  weight_kg  consumption_comb  consumption_city  \
# 15914              NaN     1758.0               5.3               6.2
# 15915              NaN     1708.0               7.4               9.2
# 15916            Black        NaN               5.3               6.2
# 15917              NaN     1758.0               5.3               6.2
# 15918            Brown     1685.0               6.8               8.7
#
#        consumption_country
# 15914                  4.7
# 15915                  6.3
# 15916                  4.7
# 15917                  4.7
# 15918                  5.7

# %%
# Checking the df by taking samples

df.sample(10)
# Out:
#                                                      url    make_model  \
# 1370   https://www.autoscout24.com//offers/audi-a1-1-...       Audi A1
# 3891   https://www.autoscout24.com//offers/audi-a3-1-...       Audi A3
# 9622   https://www.autoscout24.com//offers/opel-corsa...    Opel Corsa
# 13601  https://www.autoscout24.com//offers/renault-cl...  Renault Clio
# 192    https://www.autoscout24.com//offers/audi-a1-sp...       Audi A1
# 10291  https://www.autoscout24.com//offers/opel-corsa...    Opel Corsa
# 9592   https://www.autoscout24.com//offers/opel-corsa...    Opel Corsa
# 13473  https://www.autoscout24.com//offers/renault-cl...  Renault Clio
# 2752   https://www.autoscout24.com//offers/audi-a3-2-...       Audi A3
# 13742  https://www.autoscout24.com//offers/renault-cl...  Renault Clio
#
#                                   short_description      body_type    price  \
# 1370                1.0 TFSI Navi, GRA, Media-Paket        Compact  15440.0
# 3891         1.6 Tdi SPBK SPORT restyling AZIENDALI         Sedans  20900.0
# 9622                      1.4 66kW (90CV) Selective          Other   9600.0
# 13601             Clio Estate 1.5 DCI 90cv Business  Station wagon   7900.0
# 192                        Sportback 1.0 TFSI sport        Compact  17900.0
# 10291   E 1.2 Selection *Cool & Sound*Onyx Schwarz*        Compact  10680.0
# 9592                         5P B-COLOR 1.4 75CV MT         Sedans   9500.0
# 13473         1.2 LIMITED *Navi*Temp*R&Go*Garantie*  Station wagon   8490.0
# 2752   2.0 TDI S tronic S line Sportback Xenon Navi         Sedans  17900.0
# 13742                  IV SOCIETE DCI 75 ENERGY AIR         Sedans   6900.0
#
#                   vat        km  prev_owner            type previous_owners  \
# 1370   VAT deductible    6240.0         1.0            Used               1
# 3891   VAT deductible   19500.0         NaN  Employee's car             NaN
# 9622              NaN   12066.0         1.0            Used               1
# 13601             NaN  126000.0         NaN            Used             NaN
# 192    VAT deductible   10170.0         1.0            Used               1
# 10291  VAT deductible       NaN         NaN             New             NaN
# 9592   VAT deductible   24666.0         NaN            Used             NaN
# 13473             NaN   49178.0         2.0            Used               2
# 2752              NaN   89325.0         2.0            Used               2
# 13742  VAT deductible   82494.0         NaN            Used             NaN
#
#                    next_inspection           inspection_new  \
# 1370   06/2021,104 g CO2/km (comb)                      NaN
# 3891                           NaN                      NaN
# 9622                           NaN                      NaN
# 13601                          NaN                      NaN
# 192                            NaN  Yes,102 g CO2/km (comb)
# 10291                          NaN                      NaN
# 9592                           NaN                      NaN
# 13473                          NaN                      NaN
# 2752   05/2018,121 g CO2/km (comb)                      NaN
# 13742                          NaN                      NaN
#
#                   warranty         full_service  \
# 1370                Euro 6            4 (Green)
# 3891             24 months                  NaN
# 9622   120 g CO2/km (comb)               Euro 6
# 13601                  NaN                  NaN
# 192                 Euro 6            4 (Green)
# 10291                  NaN                  NaN
# 9592                   NaN                  NaN
# 13473                  NaN  126 g CO2/km (comb)
# 2752                Euro 6            4 (Green)
# 13742             6 months                  NaN
#
#                                      non_smoking_vehicle  first_registration  \
# 1370                                                 NaN              2018.0
# 3891                                                 NaN              2017.0
# 9622                                                 NaN              2018.0
# 13601                                                NaN              2016.0
# 192                                                  NaN              2018.0
# 10291  5.6 l/100 km (comb),,7.3 l/100 km (city),,4.7 ...                 NaN
# 9592                                                 NaN              2018.0
# 13473                                             Euro 6              2016.0
# 2752                                                 NaN              2016.0
# 13742                                                NaN              2016.0
#
#       body_color paint_type  nr_of_doors  nr_of_seats gearing_type  \
# 1370       Black        NaN          2.0          4.0       Manual
# 3891       Black   Metallic          5.0          5.0    Automatic
# 9622        Grey   Metallic          5.0          5.0       Manual
# 13601       Grey        NaN          5.0          5.0       Manual
# 192         Grey   Metallic          5.0          4.0    Automatic
# 10291      Black   Metallic          3.0          5.0       Manual
# 9592       Black        NaN          5.0          5.0       Manual
# 13473      White        NaN          4.0          5.0       Manual
# 2752      Silver   Metallic          4.0          5.0    Automatic
# 13742        Red        NaN          5.0          NaN       Manual
#
#        displacement_cc  cylinders drive_chain     fuel  co_2_emission  \
# 1370             999.0        3.0       front  Benzine          104.0
# 3891               NaN        NaN       front   Diesel            NaN
# 9622            1398.0        4.0         NaN  Benzine          120.0
# 13601           1461.0        4.0         NaN   Diesel            NaN
# 192              999.0        3.0       front  Benzine          102.0
# 10291           1229.0        4.0       front  Benzine          129.0
# 9592            1398.0        4.0       front  Benzine          118.0
# 13473           1149.0        NaN         NaN  Benzine          126.0
# 2752            1968.0        NaN         NaN   Diesel          121.0
# 13742              NaN        NaN         NaN   Diesel            NaN
#
#       emission_class                                comfort_convenience  \
# 1370          Euro 6  Air conditioning,Armrest,Cruise control,Electr...
# 3891             NaN  Air conditioning,Armrest,Automatic climate con...
# 9622          Euro 6                                                NaN
# 13601         Euro 5  Air conditioning,Electrical side mirrors,Leath...
# 192           Euro 6  Air conditioning,Armrest,Automatic climate con...
# 10291   Euro 6d-TEMP         Air conditioning,Hill Holder,Power windows
# 9592          Euro 6  Air conditioning,Electrical side mirrors,Power...
# 13473         Euro 6  Air conditioning,Cruise control,Electrical sid...
# 2752          Euro 6  Air conditioning,Armrest,Automatic climate con...
# 13742            NaN                                                NaN
#
#                                      entertainment_media  \
# 1370   Bluetooth,CD player,Hands-free equipment,MP3,O...
# 3891   Bluetooth,CD player,Digital radio,Hands-free e...
# 9622                                                 NaN
# 13601                                                NaN
# 192    Bluetooth,CD player,Hands-free equipment,MP3,O...
# 10291                            On-board computer,Radio
# 9592                       Bluetooth,CD player,Radio,USB
# 13473  Bluetooth,CD player,Hands-free equipment,On-bo...
# 2752   Bluetooth,CD player,Hands-free equipment,On-bo...
# 13742                                                NaN
#
#                                                   extras  \
# 1370                                       Voice Control
# 3891              Alloy wheels,Sport seats,Voice Control
# 9622                                                 NaN
# 13601                                                NaN
# 192    Alloy wheels,Catalytic Converter,Sport seats,S...
# 10291                                                NaN
# 9592              Alloy wheels,Sport package,Sport seats
# 13473                Alloy wheels,Roof rack,Touch screen
# 2752   Alloy wheels,Roof rack,Sport package,Sport sea...
# 13742                                                NaN
#
#                                          safety_security emission_label  \
# 1370   ABS,Central door lock,Daytime running lights,D...            NaN
# 3891   ABS,Alarm system,Central door lock,Daytime run...            NaN
# 9622                                                 NaN            NaN
# 13601  ABS,Central door lock,Driver-side airbag,Elect...            NaN
# 192    ABS,Central door lock,Daytime running lights,D...            NaN
# 10291  ABS,Central door lock,Daytime running lights,D...      4 (Green)
# 9592   ABS,Central door lock,Driver-side airbag,Elect...            NaN
# 13473  ABS,Daytime running lights,Electronic stabilit...      4 (Green)
# 2752   ABS,Adaptive headlights,Alarm system,Central d...            NaN
# 13742                                                NaN            NaN
#
#        gears  hp_kw next_insp_date insp_new  warranty_month upholstery_type  \
# 1370     5.0   60.0        06/2021      NaN             NaN             NaN
# 3891     NaN   81.0            NaN      NaN            24.0             NaN
# 9622     5.0   66.0            NaN      NaN             NaN             NaN
# 13601    5.0   66.0            NaN      NaN             NaN             NaN
# 192      7.0   70.0            NaN      Yes             NaN           Cloth
# 10291    NaN   51.0            NaN      NaN             NaN           Cloth
# 9592     5.0   55.0            NaN      NaN             NaN             NaN
# 13473    NaN   54.0            NaN      NaN             NaN           Cloth
# 2752     NaN  110.0        05/2018      NaN             NaN    Full leather
# 13742    5.0    NaN            NaN      NaN             6.0             NaN
#
#       upholstery_color  weight_kg  consumption_comb  consumption_city  \
# 1370             Black     1110.0               4.4               5.2
# 3891               NaN        NaN               NaN               NaN
# 9622               NaN     1163.0               5.2               6.9
# 13601              NaN     1121.0               NaN               NaN
# 192              Black        NaN               4.6               5.6
# 10291            Black        NaN               5.6               7.3
# 9592               NaN     1088.0               5.1               6.7
# 13473             Grey        NaN               5.4               6.8
# 2752             Black        NaN               4.6               5.4
# 13742              NaN        NaN               NaN               NaN
#
#        consumption_country
# 1370                   3.9
# 3891                   NaN
# 9622                   4.2
# 13601                  NaN
# 192                    4.0
# 10291                  4.7
# 9592                   4.2
# 13473                  4.5
# 2752                   4.2
# 13742                  NaN

# %% [markdown]
# ## Checking the summary information of df

# %%
# Checking the summary information of df with df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   url                  15919 non-null  object
#  1   make_model           15919 non-null  object
#  2   short_description    15873 non-null  object
#  3   body_type            15859 non-null  object
#  4   price                15919 non-null  float64
#  5   vat                  11406 non-null  object
#  6   km                   14895 non-null  float64
#  7   prev_owner           9091 non-null   float64
#  8   type                 15917 non-null  object
#  9   previous_owners      9279 non-null   object
#  10  next_inspection      3535 non-null   object
#  11  inspection_new       3932 non-null   object
#  12  warranty             9156 non-null   object
#  13  full_service         6230 non-null   object
#  14  non_smoking_vehicle  3460 non-null   object
#  15  first_registration   14322 non-null  float64
#  16  body_color           15322 non-null  object
#  17  paint_type           10147 non-null  object
#  18  nr_of_doors          15707 non-null  float64
#  19  nr_of_seats          14942 non-null  float64
#  20  gearing_type         15919 non-null  object
#  21  displacement_cc      15423 non-null  float64
#  22  cylinders            10239 non-null  float64
#  23  drive_chain          9061 non-null   object
#  24  fuel                 15919 non-null  object
#  25  co_2_emission        13483 non-null  float64
#  26  emission_class       12291 non-null  object
#  27  comfort_convenience  14999 non-null  object
#  28  entertainment_media  14545 non-null  object
#  29  extras               12957 non-null  object
#  30  safety_security      14937 non-null  object
#  31  emission_label       3945 non-null   object
#  32  gears                11207 non-null  float64
#  33  hp_kw                15831 non-null  float64
#  34  next_insp_date       3535 non-null   object
#  35  insp_new             3932 non-null   object
#  36  warranty_month       4853 non-null   float64
#  37  upholstery_type      11048 non-null  object
#  38  upholstery_color     10897 non-null  object
#  39  weight_kg            8945 non-null   float64
#  40  consumption_comb     13886 non-null  float64
#  41  consumption_city     13483 non-null  float64
#  42  consumption_country  13543 non-null  float64
# dtypes: float64(16), object(27)
# memory usage: 5.2+ MB

# %% [markdown]
# ## Checking the null values of df

# %%
df.isnull().sum()
# Out:
# url                        0
# make_model                 0
# short_description         46
# body_type                 60
# price                      0
# vat                     4513
# km                      1024
# prev_owner              6828
# type                       2
# previous_owners         6640
# next_inspection        12384
# inspection_new         11987
# warranty                6763
# full_service            9689
# non_smoking_vehicle    12459
# first_registration      1597
# body_color               597
# paint_type              5772
# nr_of_doors              212
# nr_of_seats              977
# gearing_type               0
# displacement_cc          496
# cylinders               5680
# drive_chain             6858
# fuel                       0
# co_2_emission           2436
# emission_class          3628
# comfort_convenience      920
# entertainment_media     1374
# extras                  2962
# safety_security          982
# emission_label         11974
# gears                   4712
# hp_kw                     88
# next_insp_date         12384
# insp_new               11987
# warranty_month         11066
# upholstery_type         4871
# upholstery_color        5022
# weight_kg               6974
# consumption_comb        2033
# consumption_city        2436
# consumption_country     2376
# dtype: int64

# %% [markdown]
# ## Checking the duplicated values in df

# %%
df.duplicated

# As it is seen below, there is not any duplicated values.
# Out:
# <bound method DataFrame.duplicated of                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  kW  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners NaN
# 1      Price negotiable  80,000 km      03/2017               None NaN
# 2        VAT deductible  83,450 km      02/2016   1 previous owner NaN
# 3                  None  73,000 km      08/2016   1 previous owner NaN
# 4                  None  16,200 km      05/2016   1 previous owner NaN
# ...                 ...        ...          ...                ...  ..
# 15914    VAT deductible       - km          -/-               None NaN
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner NaN
# 15916    VAT deductible      15 km      03/2019   1 previous owner NaN
# 15917    VAT deductible      10 km      06/2019               None NaN
# 15918    VAT deductible       - km      01/2019   1 previous owner NaN
#
#            hp                                               Type  \
# 0       66 kW            [, Used, , Diesel (Particulate Filter)]
# 1      141 kW                               [, Used, , Gasoline]
# 2       85 kW            [, Used, , Diesel (Particulate Filter)]
# 3       66 kW            [, Used, , Diesel (Particulate Filter)]
# 4       66 kW            [, Used, , Diesel (Particulate Filter)]
# ...       ...                                                ...
# 15914  147 kW             [, New, , Diesel (Particulate Filter)]
# 15915  165 kW  [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916  146 kW                       [, Pre-registered, , Diesel]
# 15917  147 kW                       [, Pre-registered, , Diesel]
# 15918  165 kW                      [, Demonstration, , Super 95]
#
#                                          Previous Owners  \
# 0                                                  \n2\n
# 1                                                    NaN
# 2                                                  \n1\n
# 3                                                  \n1\n
# 4                                                  \n1\n
# ...                                                  ...
# 15914                                                NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                NaN
# 15918                                              \n1\n
#
#                               Next Inspection  \
# 0       [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15914                                     NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15916                                     NaN
# 15917                                     NaN
# 15918                                     NaN
#
#                            Inspection new                          Warranty  \
# 0                   [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
# 1                                     NaN                               NaN
# 2                                     NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 3                                     NaN                               NaN
# 4      [\nYes\n, \n109 g CO2/km (comb)\n]              [\n, \n, \nEuro 6\n]
# ...                                   ...                               ...
# 15914                                 NaN                     \n24 months\n
# 15915                                 NaN              [\n, \n, \nEuro 6\n]
# 15916         [\nYes\n, \nEuro 6d-TEMP\n]           [\n, \n, \n4 (Green)\n]
# 15917                                 NaN                                \n
# 15918  [\nYes\n, \n153 g CO2/km (comb)\n]                               NaN
#
#                            Full Service      Non-smoking Vehicle null  \
# 0                              [\n, \n]                 [\n, \n]   []
# 1                                   NaN                      NaN   []
# 2                                   NaN                      NaN   []
# 3      [\n, \n, \n99 g CO2/km (comb)\n]     [\n, \n, \nEuro 6\n]   []
# 4               [\n, \n, \n4 (Green)\n]                 [\n, \n]   []
# ...                                 ...                      ...  ...
# 15914                               NaN                      NaN   []
# 15915                               NaN  [\n, \n, \n4 (Green)\n]   []
# 15916                          [\n, \n]                 [\n, \n]   []
# 15917                               NaN                      NaN   []
# 15918                               NaN                      NaN   []
#
#               Make             Model          Offer Number First Registration  \
# 0         \nAudi\n      [\n, A1, \n]       [\nLR-062483\n]     [\n, 2016, \n]
# 1         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2017, \n]
# 2         \nAudi\n      [\n, A1, \n]        [\nAM-95365\n]     [\n, 2016, \n]
# 3         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2016, \n]
# 4         \nAudi\n      [\n, A1, \n]           [\nC1626\n]     [\n, 2016, \n]
# ...            ...               ...                   ...                ...
# 15914  \nRenault\n  [\n, Espace, \n]        [\n10988301\n]                NaN
# 15915  \nRenault\n  [\n, Espace, \n]     [\n507370_3223\n]     [\n, 2019, \n]
# 15916  \nRenault\n  [\n, Espace, \n]        [\nEspace16\n]     [\n, 2019, \n]
# 15917  \nRenault\n  [\n, Espace, \n]         [\n2691331\n]     [\n, 2019, \n]
# 15918  \nRenault\n  [\n, Espace, \n]  [\nRe_30000008029\n]     [\n, 2019, \n]
#
#             Body Color      Paint Type           Body Color Original  \
# 0      [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1        [\n, Red, \n]             NaN                           NaN
# 2      [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
# 3      [\n, Brown, \n]  [\nMetallic\n]                           NaN
# 4      [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz Metallic\n]
# ...                ...             ...                           ...
# 15914   [\n, Grey, \n]  [\nMetallic\n]            [\nGrigio scuro\n]
# 15915   [\n, Grey, \n]  [\nMetallic\n]     [\nStahl-Grau Metallic\n]
# 15916  [\n, White, \n]             NaN             [\narktis-weiß\n]
# 15917   [\n, Grey, \n]             NaN                  [\nGrigio\n]
# 15918   [\n, Grey, \n]  [\nMetallic\n]  [\nTitanium-Grau Metallic\n]
#
#                       Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1              [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
# 3                            NaN  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 4             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# ...                          ...               ...          ...          ...
# 15914                        NaN     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15915                [\nCloth\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15916  [\nFull leather, Black\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15917         [\nPart leather\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15918  [\nFull leather, Brown\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
#
#            Model Code         Gearing Type    Displacement Cylinders  \
# 0      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1      [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2                 NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
# 3                 NaN  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 4      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# ...               ...                  ...             ...       ...
# 15914             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15915  [\n0000/000\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 15916             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15917             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15918  [\n3333/BHJ\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
#
#                Weight  Drive chain  \
# 0      [\n1,220 kg\n]  [\nfront\n]
# 1      [\n1,255 kg\n]  [\nfront\n]
# 2                 NaN  [\nfront\n]
# 3      [\n1,195 kg\n]          NaN
# 4                 NaN  [\nfront\n]
# ...               ...          ...
# 15914  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,708 kg\n]  [\nfront\n]
# 15916             NaN  [\nfront\n]
# 15917  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                     Fuel  \
# 0                  [\n, Diesel (Particulate Filter), \n]
# 1                                     [\n, Gasoline, \n]
# 2                  [\n, Diesel (Particulate Filter), \n]
# 3                  [\n, Diesel (Particulate Filter), \n]
# 4                  [\n, Diesel (Particulate Filter), \n]
# ...                                                  ...
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                              Consumption  \
# 0      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1      [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2      [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4      [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# ...                                                  ...
# 15914  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918  [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
#
#                     CO2 Emission      Emission Class  \
# 0       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 1      [\n129 g CO2/km (comb)\n]        [\nEuro 6\n]
# 2       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 3       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 4      [\n109 g CO2/km (comb)\n]        [\nEuro 6\n]
# ...                          ...                 ...
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                \nComfort & Convenience\n  \
# 0      [Air conditioning, Armrest, Automatic climate ...
# 1      [Air conditioning, Automatic climate control, ...
# 2      [Air conditioning, Cruise control, Electrical ...
# 3      [Air suspension, Armrest, Auxiliary heating, E...
# 4      [Air conditioning, Armrest, Automatic climate ...
# ...                                                  ...
# 15914  [Air conditioning, Automatic climate control, ...
# 15915  [Air conditioning, Automatic climate control, ...
# 15916  [Air conditioning, Armrest, Automatic climate ...
# 15917  [Air conditioning, Automatic climate control, ...
# 15918  [Air conditioning, Automatic climate control, ...
#
#                                \nEntertainment & Media\n  \
# 0      [Bluetooth, Hands-free equipment, On-board com...
# 1      [Bluetooth, Hands-free equipment, On-board com...
# 2                               [MP3, On-board computer]
# 3      [Bluetooth, CD player, Hands-free equipment, M...
# 4      [Bluetooth, CD player, Hands-free equipment, M...
# ...                                                  ...
# 15914  [Bluetooth, Digital radio, Hands-free equipmen...
# 15915  [Bluetooth, Digital radio, Hands-free equipmen...
# 15916  [Bluetooth, Hands-free equipment, On-board com...
# 15917             [Bluetooth, Digital radio, Radio, USB]
# 15918                                              [USB]
#
#                                               \nExtras\n  \
# 0      [Alloy wheels, Catalytic Converter, Voice Cont...
# 1      [Alloy wheels, Sport seats, Sport suspension, ...
# 2                          [Alloy wheels, Voice Control]
# 3             [Alloy wheels, Sport seats, Voice Control]
# 4      [Alloy wheels, Sport package, Sport suspension...
# ...                                                  ...
# 15914                       [Alloy wheels, Touch screen]
# 15915        [Alloy wheels, Touch screen, Voice Control]
# 15916                                     [Alloy wheels]
# 15917                       [Alloy wheels, Touch screen]
# 15918                       [Alloy wheels, Touch screen]
#
#                                    \nSafety & Security\n  \
# 0      [ABS, Central door lock, Daytime running light...
# 1      [ABS, Central door lock, Central door lock wit...
# 2      [ABS, Central door lock, Daytime running light...
# 3      [ABS, Alarm system, Central door lock with rem...
# 4      [ABS, Central door lock, Driver-side airbag, E...
# ...                                                  ...
# 15914  [ABS, Central door lock, Central door lock wit...
# 15915  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918  [ABS, Blind spot monitor, Daytime running ligh...
#
#                                              description   Emission Label  \
# 0      [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1      [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2      [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3      [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4      [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
# ...                                                  ...              ...
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption Last Service Date  \
# 0          NaN             NaN                     NaN               NaN
# 1      [\n7\n]             NaN                     NaN               NaN
# 2          NaN             NaN                     NaN               NaN
# 3      [\n6\n]             NaN                     NaN               NaN
# 4          NaN   [\nGermany\n]                     NaN               NaN
# ...        ...             ...                     ...               ...
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]>

# %% [markdown]
# # PART- 2 `( Handling With Missing Values )`

# %% [markdown]
# ## url column

# %%
df[df.body_color.isnull()][["url", "body_color"]]
# Out:
#                                                      url body_color
# 70     https://www.autoscout24.com//offers/audi-a1-sp...        NaN
# 122    https://www.autoscout24.com//offers/audi-a1-sp...        NaN
# 150    https://www.autoscout24.com//offers/audi-a1-sp...        NaN
# 195    https://www.autoscout24.com//offers/audi-a1-sp...        NaN
# 198    https://www.autoscout24.com//offers/audi-a1-a1...        NaN
# ...                                                  ...        ...
# 15690  https://www.autoscout24.com//offers/renault-es...        NaN
# 15785  https://www.autoscout24.com//offers/renault-es...        NaN
# 15849  https://www.autoscout24.com//offers/renault-es...        NaN
# 15854  https://www.autoscout24.com//offers/renault-es...        NaN
# 15864  https://www.autoscout24.com//offers/renault-es...        NaN
#
# [597 rows x 2 columns]

# %%
df.url[198]
# Out:
# 'https://www.autoscout24.com//offers/audi-a1-a1-s1-1-6-tdi-116-cv-s-tronic-diesel-40d8d475-a023-493f-b313-d066e569e8d6'

# %%
color_list = list(df.body_color.dropna().unique())
color_list
# Out:
# ['Black',
#  'Red',
#  'Brown',
#  'White',
#  'Grey',
#  'Silver',
#  'Blue',
#  'Beige',
#  'Violet',
#  'Yellow',
#  'Green',
#  'Bronze',
#  'Orange',
#  'Gold']

# %%
def findcolor(x):
    if any(i in x for i in color_list):
        return True
    else:
        return False

# %%
df.url.apply(findcolor).sum()
# Out:
# 0

# %%
'https://www.autoscout24.com//offers/audi-a1-a1-s1-1-6-tdi-116-cv-s-tronic-diesel-40d8d475-a023-493f-b313-d066e569e8d6'

# %%
findcolor(df.url[0])
# Out:
# False

# %%
df.body_color.dropna().apply(findcolor)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15914    True
# 15915    True
# 15916    True
# 15917    True
# 15918    True
# Name: body_color, Length: 15322, dtype: bool

# %%
## Diğer kolonları dolduracak bilgi olmadığı tespit edildi. Düşülecek.

df.drop(columns="url", inplace=True)

# %%
df.shape
# Out:
# (15919, 42)

# %%
missing_value_col = []
[missing_value_col.append(i) for i in df.columns if any(df[i].isnull())]
missing_value_col
# Out:
# ['short_description',
#  'body_type',
#  'vat',
#  'km',
#  'prev_owner',
#  'type',
#  'previous_owners',
#  'next_inspection',
#  'inspection_new',
#  'warranty',
#  'full_service',
#  'non_smoking_vehicle',
#  'first_registration',
#  'body_color',
#  'paint_type',
#  'nr_of_doors',
#  'nr_of_seats',
#  'displacement_cc',
#  'cylinders',
#  'drive_chain',
#  'co_2_emission',
#  'emission_class',
#  'comfort_convenience',
#  'entertainment_media',
#  'extras',
#  'safety_security',
#  'emission_label',
#  'gears',
#  'hp_kw',
#  'next_insp_date',
#  'insp_new',
#  'warranty_month',
#  'upholstery_type',
#  'upholstery_color',
#  'weight_kg',
#  'consumption_comb',
#  'consumption_city',
#  'consumption_country']

# %% [markdown]
# ## body_type

# %%
df.body_type.value_counts(dropna=False)
# Out:
# Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.groupby("make_model")["body_type"].value_counts(dropna=False)
# Out:
# make_model      body_type
# Audi A1         Sedans           1538
#                 Compact          1039
#                 Station wagon      21
#                 Other              13
#                 Coupe               2
#                 Van                 1
# Audi A2         Off-Road            1
# Audi A3         Sedans           2598
#                 Station wagon     282
#                 Compact           182
#                 Other              16
#                 Convertible         8
#                 NaN                 7
#                 Coupe               4
# Opel Astra      Station wagon    1211
#                 Sedans           1053
#                 Compact           185
#                 Other              67
#                 NaN                 7
#                 Coupe               2
#                 Off-Road            1
# Opel Corsa      Compact          1230
#                 Sedans            875
#                 Other              87
#                 Coupe              13
#                 Transporter         7
#                 Off-Road            3
#                 NaN                 2
#                 Van                 2
# Opel Insignia   Station wagon    1611
#                 Sedans            900
#                 Other              48
#                 Compact            27
#                 Off-Road            7
#                 NaN                 3
#                 Coupe               1
#                 Van                 1
# Renault Clio    Sedans            918
#                 Compact           484
#                 Station wagon     337
#                 Other              51
#                 Transporter        29
#                 NaN                15
#                 Off-Road            2
#                 Van                 2
#                 Coupe               1
# Renault Duster  Off-Road           34
# Renault Espace  Van               777
#                 Station wagon      91
#                 Transporter        52
#                 NaN                26
#                 Sedans             21
#                 Off-Road            8
#                 Other               8
#                 Compact             6
#                 Coupe               2
# Name: body_type, dtype: int64

# %%
df.groupby("make_model")["body_type"].apply(list)
# Out:
# make_model
# Audi A1           [Sedans, Sedans, Sedans, Sedans, Sedans, Sedan...
# Audi A2                                                  [Off-Road]
# Audi A3           [Convertible, Sedans, Sedans, Sedans, Sedans, ...
# Opel Astra        [Station wagon, Station wagon, Station wagon, ...
# Opel Corsa        [Sedans, Sedans, Sedans, Compact, Compact, Com...
# Opel Insignia     [Station wagon, Sedans, Station wagon, Station...
# Renault Clio      [Compact, Station wagon, Sedans, Station wagon...
# Renault Duster    [Off-Road, Off-Road, Off-Road, Off-Road, Off-R...
# Renault Espace    [nan, Station wagon, Transporter, Van, Van, Tr...
# Name: body_type, dtype: object

# %%
df.body_type.mode()
# Out:
# 0    Sedans
# dtype: object

# %%
df.groupby("make_model")["body_type"].apply(lambda x: x.mode()[0])
# Out:
# make_model
# Audi A1                  Sedans
# Audi A2                Off-Road
# Audi A3                  Sedans
# Opel Astra        Station wagon
# Opel Corsa              Compact
# Opel Insignia     Station wagon
# Renault Clio             Sedans
# Renault Duster         Off-Road
# Renault Espace              Van
# Name: body_type, dtype: object

# %%
# fill null values with modeof each group by grouping data according to make_model

df[] = df.groupby("make_model")["body_type"].apply(lambda x: x.fillna(x.mode()[0]))
# Out:
# Sedans           7925
# Station wagon    3563
# Compact          3155
# Van               809
# Other             290
# Transporter        88
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64

# %%
df.groupby("make_model")["body_type"].describe()
# Out:
#                count unique            top  freq
# make_model
# Audi A1         2614      6         Sedans  1538
# Audi A2            1      1       Off-Road     1
# Audi A3         3090      6         Sedans  2598
# Opel Astra      2519      6  Station wagon  1211
# Opel Corsa      2217      7        Compact  1230
# Opel Insignia   2595      7  Station wagon  1611
# Renault Clio    1824      8         Sedans   918
# Renault Duster    34      1       Off-Road    34
# Renault Espace   965      8            Van   777

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
