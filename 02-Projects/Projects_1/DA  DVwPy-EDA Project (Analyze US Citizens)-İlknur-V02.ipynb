# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
us_citizens= pd.read_csv("adult_eda.csv")

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
# checking the head of dataframe

us_citizens.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# checking the shape of dataframe

us_citizens.shape
# Out:
# (32561, 15)

# %%
# checking the data-types of features

us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
# checking duplicate rows
# there are 24 duplicated rows

us_citizens.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
# droping duplicate rows

us_citizens.drop(us_citizens[us_citizens.duplicated()].index, inplace=True)

# %%
# checking the shape of dataframe after dropping
# the number of rows was decreased to 32537 after dropping

us_citizens.shape
# Out:
# (32537, 15)

# %%
# checking the statistical values of features

us_citizens.describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            32537.000     38.586     13.638    17.000     28.000
# fnlwgt         32537.000 189780.849 105556.471 12285.000 117827.000
# education-num  31735.000     10.084      2.575     1.000      9.000
# capital-gain   32537.000   1078.444   7387.957     0.000      0.000
# capital-loss   32537.000     87.368    403.102     0.000      0.000
# hours-per-week 32537.000     40.440     12.347     1.000     40.000
#
#                       50%        75%         max
# age                37.000     48.000      90.000
# fnlwgt         178356.000 236993.000 1484705.000
# education-num      10.000     12.000      16.000
# capital-gain        0.000      0.000   99999.000
# capital-loss        0.000      0.000    4356.000
# hours-per-week     40.000     45.000      99.000

# %%
us_citizens.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# renaming some columns for easy use

us_citizens.rename(columns={"education-num" : "education_num", "marital-status" : "marital_status",
                            "capital-gain" : "capital_gain", "capital-loss" : "capital_loss",
                           "hours-per-week" : "hours_per_week", "native-country" : "native_country"}, inplace=True)
us_citizens.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# checking missing values per column

us_citizens.isnull().sum()

# there are 802 null values in education_num column
# there are 5064 null values in relationship column
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
# checking the persentage of missing values per column

us_citizens.isnull().sum()/len(us_citizens)*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.465
# marital_status    0.000
# occupation        0.000
# relationship     15.564
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
us_citizens.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
# finding column names that have object datatype

us_citizens.columns[us_citizens.dtypes == "object"]
# Out:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
# finding value counts of columns that have object datatype

us_citizens.describe(include="object").T
# Out:
#                 count unique                 top   freq
# workclass       32537      9             Private  22673
# education       32537     16             HS-grad  10494
# marital_status  32537      7  Married-civ-spouse  14970
# occupation      32537     15      Prof-specialty   4136
# relationship    27473      5             Husband  13187
# race            32537      5               White  27795
# sex             32537      2                Male  21775
# native_country  32537     42       United-States  29153
# salary          32537      2               <=50K  24698

# %%
# detecting strange values apart from NaN values

col_object=us_citizens.columns[us_citizens.dtypes == "object"]

for col in col_object :
    print(col)
    print("--"*10)
    print(us_citizens[col].value_counts(dropna=False))
    print("##"*20)
# Out:
# workclass
# --------------------
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ########################################
# education
# --------------------
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64
# ########################################
# marital_status
# --------------------
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# ...

# %% [markdown]
# ### After checking the strange values in us_citizens dataframe, it has been observed that;
#
# there are 1836 strange values in workclass column
#
# there are 1843 strange values in occupation column
#
# there are 639 strange values in native_country column

# %%
# checking if the dataset has any question mark(?)

(us_citizens == "?").any(axis=0)
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %%
us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   31735 non-null  float64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 4.0+ MB

# %%
us_citizens.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# # Salary(Target Feature)

# %% [markdown]
# ### Check the count of person in each "salary" levels and visualize it with a countplot

# %%
# Checking the count of person in each "salary" levels

us_citizens.salary.value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
# visualising the count of people in each "salary" levels
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
plt.figure(figsize=(12,8))
ax = sns.countplot(x=us_citizens.salary)
ax.bar_label(ax.containers[0]);

# %%
# Checking the percentage of person in each "salary" levels

us_citizens.salary.value_counts(normalize=True)
# Out:
# <=50K   0.759
# >50K    0.241
# Name: salary, dtype: float64

# %%
# visualising the percentage of people in each "salary" levels
plt.figure(figsize=(12,8))
salary_values = us_citizens.salary.value_counts(normalize=True).values
salary_labels = us_citizens.salary.value_counts(normalize=True).index
myexplode = [0, 0.2]
plt.pie(salary_values, labels=salary_labels, explode=myexplode,
        colors=["#51c1ed", "#f0f03c"],
        shadow=True, labeldistance=1.1,
        autopct="%.1f%%",
       textprops = {"fontsize":15})
plt.legend(title="Salary", fontsize = 15);

# %% [markdown]
# ## Conclusion about salary:
#
#
# ### 24.1% of the people in the dataset have a salary of over 50K, while 75.9% of them have a salary of less than 50K.

# %% [markdown]
# # Analysis of numeric features according to salary(target) feature

# %% [markdown]
# ### age and salary

# %%
# boxplot for age feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
plt.figure(figsize=(12,8))
sns.boxplot(data=us_citizens, x="age");

# %%
# distribution of age feature (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
plt.figure(figsize=(12,8))
sns.histplot(data=us_citizens, x="age", kde=True, bins=20);

# %%
# statistical values of age feature

us_citizens.age.describe()
# Out:
# count   32537.000
# mean       38.586
# std        13.638
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %%
# boxplot for age feature by salary levels
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
plt.figure(figsize=(12,8))
sns.boxplot(data=us_citizens, x="salary", y="age");

# %%
# distribution of age feature by salary levels (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
plt.figure(figsize=(12,8))
sns.histplot(data=us_citizens, x="age", hue="salary",kde=True, bins=20);

# %%
# kdeplot: distribution of age feature by salary level 
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="age", hue="salary", shade=True);

# %%
# statistical values of age feature by salary

us_citizens.groupby("salary").age.describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24698.000 36.787 14.017 17.000 25.000 34.000 46.000 90.000
# >50K    7839.000 44.251 10.520 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# ## Conclusion about age feature by salary levels
#
# ### While the average age of the people in the data set is 38.5, the median values are 37.
#
# ### There are some extreme values in age fature.
#
# ### The mean and median values of  age feature for people having >50K salary are greater than the others.
#
# ### Distribution of age feature is right skewed.
#
# ### While the distibution of age for people having >50K salary is right skewed, the distribution of age for people having <=50K salary is normal and standart deviation is less.

# %% [markdown]
# ## fnlwgt and salary

# %%
# boxplot for fnlwgt feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="fnlwgt");

# %%
# distribution of fnlwgt feature (histplot and kde plot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="fnlwgt", kde=True, bins=30);

# %%
# distribution of fnlwgt feature (kde plot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="fnlwgt", shade=True);

# %%
# statistical values for fnlwgt feature

us_citizens.fnlwgt.describe()
# Out:
# count     32537.000
# mean     189780.849
# std      105556.471
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      236993.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %%
# boxplot for fnlwgt feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="salary", y="fnlwgt");

# %%
# distribution of fnlwgt feature by salary (histplot and kde plot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="fnlwgt", hue="salary", kde=True, bins=20);

# %%
# distribution of fnlwgt feature by salary (kde plot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="fnlwgt", hue="salary", shade=True);

# %%
# statistical values of fnlwgt feature by salary

us_citizens.groupby("salary").fnlwgt.describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24698.000 190345.927 106487.413 12285.000 117606.000 179465.000
# >50K    7839.000 188000.481 102554.464 14878.000 119100.000 176063.000
#
#               75%         max
# salary
# <=50K  238968.250 1484705.000
# >50K   230969.000 1226583.000

# %% [markdown]
# ## Conclusion about fnlwgt feature
#
# ### The mean and median values of fnlwgt by salary are almost the same and the distribution of fnlwgt by salary are the same and it is positively skewed.
#
# ### There are so many extreme values in fnlwgt feature for both salary<=50K and salary>50K.

# %% [markdown]
# #  education_num and salary

# %%
# boxplot for education_num feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="education_num");

# %%
# distribution of education_num feature (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="education_num", bins=16, kde=True);

# %%
# statistical values for education_num feature

us_citizens.education_num.describe()
# Out:
# count   31735.000
# mean       10.084
# std         2.575
# min         1.000
# 25%         9.000
# 50%        10.000
# 75%        12.000
# max        16.000
# Name: education_num, dtype: float64

# %%
# boxplot for education_num feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="salary", y="education_num");

# %%
# distribution of education_num by salary feature (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="education_num", hue= "salary", bins=16, kde=True);

# %%
# distribution of education_num by salary feature (kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="education_num", hue= "salary", shade=True);

# %%
# statistical values of education_num feature by salary

us_citizens.groupby("salary").education_num.describe()
# Out:
#            count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  24104.000  9.599 2.439 1.000  9.000  9.000 10.000 16.000
# >50K    7631.000 11.616 2.388 2.000 10.000 12.000 13.000 16.000

# %% [markdown]
# ## Conclusion bout education_num feature
#
# ### The mean and median values for salary<=50K of edu_num are less than that for salary>50K. It can be conclude that as the level of education increases, the average salary also increases.
#
# ### There are also some extreme values in education_num feature.

# %% [markdown]
# # capital gain and salary

# %%
# boxplot for capital_gain feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="capital_gain");

# %%
# kdeplot for capital_gain feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="capital_gain", shade=True);

# %%
# statistical values for capital_gain feature

us_citizens.capital_gain.describe()
# Out:
# count   32537.000
# mean     1078.444
# std      7387.957
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %%
# boxplot for capital_gain feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="salary", y="capital_gain");

# %%
# distribution of capital_gain feature (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="capital_gain", bins=10, kde=True);

# %%
# distribution of capital_gain feature by salary (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="capital_gain", hue="salary", bins=10, kde=True);

# %%
# distribution of capital_gain feature by salary (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="capital_gain", hue="salary", shade=True);

# %%
# statistical values of capital_gain feature by salary

us_citizens.groupby("salary").capital_gain.describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24698.000  148.885   963.558 0.000 0.000 0.000 0.000 41310.000
# >50K    7839.000 4007.165 14572.097 0.000 0.000 0.000 0.000 99999.000

# %% [markdown]
# ## Conclusion about capital_gain
#
# ### It is observed that the capital gain values are distributed between 0-10 thousand for both the salary >50K and <=50K.
# ### There are also so many extreme values.

# %% [markdown]
# ## Capital loss and salary

# %%
# boxplot for capital_loss feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="capital_loss");

# %%
# kdeboxplot for capital_loss feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="capital_loss", shade=True);

# %%
# statistical values for capital_loss feature

us_citizens.capital_loss.describe()
# Out:
# count   32537.000
# mean       87.368
# std       403.102
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %%
# boxplot for capital_loss feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, y="salary", x="capital_loss");

# %%
# distribution of capital_loss feature by salary (histplot and kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.histplot(data=us_citizens, x="capital_loss", hue="salary", bins=10, kde=True);

# %%
# distribution of capital_loss feature by salary (kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="capital_loss", hue="salary", shade=True);

# %%
# statistical values of capital_loss feature by salary

us_citizens.groupby("salary").capital_loss.describe()
# Out:
#            count    mean     std   min   25%   50%   75%      max
# salary
# <=50K  24698.000  53.190 310.890 0.000 0.000 0.000 0.000 4356.000
# >50K    7839.000 195.051 595.555 0.000 0.000 0.000 0.000 3683.000

# %% [markdown]
# ## Conclusion about capital_loss feature
#
# ### It is concluded that most of the capital_loss values are around zero for both salary >50K and <=50K.
#
# ### It seems that there are so many extreme values in capital_loss feature.

# %% [markdown]
# # hours_per_week and salary

# %%
# boxplot for hours_per_week feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="hours_per_week");

# %%
# kdeplot for hours_per_week feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="hours_per_week", shade=True);

# %%
# statistical values for hours_per_week

us_citizens.hours_per_week.describe()
# Out:
# count   32537.000
# mean       40.440
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %%
# value counts of hours_per_week as percentage

us_citizens.hours_per_week.value_counts(normalize=True) * 100
# Out:
# 40   46.728
# 50    8.658
# 45    5.603
# 60    4.533
# 35    3.983
#       ...
# 82    0.003
# 92    0.003
# 87    0.003
# 74    0.003
# 94    0.003
# Name: hours_per_week, Length: 94, dtype: float64

# %%
# boxplot for hours_per_week feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="salary", y="hours_per_week");

# %%
# distribution of hours_per_week feature by salary (kdeplot)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.kdeplot(data=us_citizens, x="hours_per_week", hue="salary", shade=True);

# %%
# statistical values of hours_per_week by salary

us_citizens.groupby("salary").hours_per_week.describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24698.000 38.843 12.318 1.000 35.000 40.000 40.000 99.000
# >50K    7839.000 45.473 11.014 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# ## Conclusion about hours_per_week feature
#
# ### From the analysis have been conducted above for hours_per_week, it can be concluded that most of the people work aproximately 40 hours per week. When we analyze the weekly working hours according to the salary, it can be seen similar distributions for both salary<=50K and salary>50K. While the median values for weekly working hours by salary are the same, it can be inferred that the average weekly working hours increased by salary.

# %%
# Checking the relationship between numerical features and salary(target feature)
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.pairplot(us_citizens, hue="salary",corner=True, palette="viridis");

# %% [markdown]
# ## Analysis of categoric features according to salary feature

# %% [markdown]
# **to do list for categoric features:**
#
# Find the features which contains similar values, examine the similarities and analyze them together
#
# Check the count/percentage of person in each categories and visualize it with a suitable plot
#
# If need, decrease the number of categories by combining similar categories
#
# Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
#
# Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
#
# Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
#
# Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
#
# Write down the conclusions you draw from your analysis

# %%
us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32537 non-null  int64
#  1   workclass       32537 non-null  object
#  2   fnlwgt          32537 non-null  int64
#  3   education       32537 non-null  object
#  4   education_num   31735 non-null  float64
#  5   marital_status  32537 non-null  object
#  6   occupation      32537 non-null  object
#  7   relationship    27473 non-null  object
#  8   race            32537 non-null  object
#  9   sex             32537 non-null  object
#  10  capital_gain    32537 non-null  int64
#  11  capital_loss    32537 non-null  int64
#  12  hours_per_week  32537 non-null  int64
#  13  native_country  32537 non-null  object
#  14  salary          32537 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 5.0+ MB

# %% [markdown]
# # education & education_num features
#
# ### checking unique values to detect similarities

# %%
# finding unique values in education feature

us_citizens.education.value_counts(dropna=False)  # education column is similar with education_num
# Out:
# HS-grad         10494
# Some-college     7282
# Bachelors        5353
# Masters          1722
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           332
# 1st-4th           166
# Preschool          50
# Name: education, dtype: int64

# %%
# finding unique values in education_num feature

us_citizens.education_num.value_counts(dropna=False)  # education_num column is similar with education
# Out:
# 9.000     10208
# 10.000     7089
# 13.000     5245
# 14.000     1686
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       630
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       329
# 2.000       159
# 1.000        49
# Name: education_num, dtype: int64

# %%
# finding the number of person in education feature by education_num feature to check the similarities

us_citizens.groupby(["education", "education_num"], dropna=False)["education_num"].count()
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                  0
# 11th          7.000             1146
#               NaN                  0
# 12th          8.000              424
#               NaN                  0
# 1st-4th       2.000              159
#               NaN                  0
# 5th-6th       3.000              329
#               NaN                  0
# 7th-8th       4.000              630
#               NaN                  0
# 9th           5.000              503
#               NaN                  0
# Assoc-acdm    12.000            1044
#               NaN                  0
# Assoc-voc     11.000            1343
#               NaN                  0
# Bachelors     13.000            5245
#               NaN                  0
# Doctorate     16.000             405
#               NaN                  0
# HS-grad       9.000            10208
#               NaN                  0
# ...

# %%
# count of people for education feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="education")
plt.xticks(rotation=90);

# %%
# count of people for education_num feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="education_num")
plt.xticks(rotation=90);

# %%
# finding the number of person in education feature by salary

us_citizens.groupby(["education","salary"])["salary"].count()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      160
#               >50K         6
# 5th-6th       <=50K      316
#               >50K        16
# 7th-8th       <=50K      605
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3132
#               >50K      2221
# Doctorate     <=50K      107
#               >50K       306
# HS-grad       <=50K     8820
#               >50K      1674
# Masters       <=50K      763
#               >50K       959
# Preschool     <=50K       50
# Prof-school   <=50K      153
#               >50K       423
# Some-college  <=50K     5896
#               >50K      1386
# ...

# %%
# count of people for education feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="education", hue="salary")
plt.xticks(rotation=90);

# %%
# finding the number of person in education feature by salary

us_citizens.groupby(["education_num","salary"])["salary"].count()
# Out:
# education_num  salary
# 1.000          <=50K       49
# 2.000          <=50K      153
#                >50K         6
# 3.000          <=50K      313
#                >50K        16
# 4.000          <=50K      592
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8579
#                >50K      1629
# 10.000         <=50K     5746
#                >50K      1343
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3078
#                >50K      2167
# 14.000         <=50K      751
#                >50K       935
# 15.000         <=50K      149
#                >50K       410
# 16.000         <=50K      103
# ...

# %%
# count of people for education_num feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="education_num", hue="salary")
plt.xticks(rotation=90);

# %%
# boxplot for education_num feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens, x="salary", y="education_num");

# %%
# creating new column according to education level by classifying education feature as low, medium and high level

def mapping_education(x):
    if x in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th"]:
        return "low_level_grade"
    elif x in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_grade"
    elif x in ["Bachelors", "Masters", "Prof-school", "Doctorate"]:
        return "high_level_grade"

# %%
us_citizens["education_summary"] = us_citizens.education.map(mapping_education)

# %%
us_citizens.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# finding the count of person in each education level
us_citizens.education_summary.value_counts()
# Out:
# medium_level_grade    20225
# high_level_grade       8064
# low_level_grade        4248
# Name: education_summary, dtype: int64

# %%
# count of people for education_summary feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="education_summary");

# %%
# finding the count of person in each education level by salary

us_citizens.groupby(["education_summary","salary"])["salary"].count()
# Out:
# education_summary   salary
# high_level_grade    <=50K      4155
#                     >50K       3909
# low_level_grade     <=50K      4004
#                     >50K        244
# medium_level_grade  <=50K     16539
#                     >50K       3686
# Name: salary, dtype: int64

# %%
# count of people for education_summary feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="education_summary", hue="salary");

# %%
# finding the number of person in each education level by salary
us_citizens.groupby("education_summary")["salary"].value_counts(normalize=True)
# Out:
# education_summary   salary
# high_level_grade    <=50K    0.515
#                     >50K     0.485
# low_level_grade     <=50K    0.943
#                     >50K     0.057
# medium_level_grade  <=50K    0.818
#                     >50K     0.182
# Name: salary, dtype: float64

# %%
# finding the percentage of person in each education level by salary as a dataframe

df_perc=pd.DataFrame(us_citizens.groupby("education_summary")["salary"].value_counts(normalize=True))
df_perc.columns = ["percentage"]
df_perc = df_perc.unstack(level=0)
df_perc
# Out:
#                         percentage
# education_summary high_level_grade low_level_grade medium_level_grade
# salary
# <=50K                        0.515           0.943              0.818
# >50K                         0.485           0.057              0.182

# %%
# pie plot for each education level by salary 

fig, ax=plt.subplots(figsize=(15,7), nrows=1, ncols=3)
color=["#ffa3b1","#77d2fc"]
ax[0].pie(x=df_perc.percentage.high_level_grade, labels=df_perc.index, autopct="%.2f%%", colors=color)
ax[0].set_title("high_level_grade")

ax[1].pie(x=df_perc.percentage.low_level_grade, labels=df_perc.index, autopct="%.2f%%", colors=color)
ax[1].set_title("low_level_grade")

ax[2].pie(x=df_perc.percentage.medium_level_grade, labels=df_perc.index, autopct="%.2f%%", colors=color)
ax[2].set_title("medium_level_grade");

# %%
# finding the count of person in salary feature by education level

us_citizens.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_grade    16539
#         high_level_grade       4155
#         low_level_grade        4004
# >50K    high_level_grade       3909
#         medium_level_grade     3686
#         low_level_grade         244
# Name: education_summary, dtype: int64

# %%
# count of people for salary feature by education level
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="education_summary");

# %%
# finding the percentage of person in salary feature by education level
df_perc2=pd.DataFrame(us_citizens.groupby("salary")["education_summary"].value_counts(normalize=True))
df_perc2.columns = ["percentage"]
df_perc2 = df_perc2.unstack(level=0).sort_values(("percentage","<=50K"), ascending=False)
df_perc2
# Out:
#                    percentage
# salary                  <=50K  >50K
# education_summary
# medium_level_grade      0.670 0.470
# high_level_grade        0.168 0.499
# low_level_grade         0.162 0.031

# %%
# pie plot for salary by education level 
fig, ax=plt.subplots(figsize=(14,7), nrows=1, ncols=2)
color=["#ffa3b1","#77d2fc", "#a7faa9"]
ax[0].pie(x=df_perc2["percentage"]["<=50K"], labels=df_perc2.index, autopct="%.2f%%", colors=color)
ax[0].set_title("<=50K")

ax[1].pie(x=df_perc2["percentage"][">50K"], labels=df_perc2.index, autopct="%.2f%%", colors=color)
ax[1].set_title(">50K");

# %%
df_perc3=pd.DataFrame(us_citizens.groupby("salary")["education_summary"].value_counts(normalize=True))
df_perc3.columns = ["percentage"]
df_perc3 = df_perc3.reset_index()
df_perc3
# Out:
#   salary   education_summary  percentage
# 0  <=50K  medium_level_grade       0.670
# 1  <=50K    high_level_grade       0.168
# 2  <=50K     low_level_grade       0.162
# 3   >50K    high_level_grade       0.499
# 4   >50K  medium_level_grade       0.470
# 5   >50K     low_level_grade       0.031

# %%
# pie plot for salary by education level 

fig, ax=plt.subplots(figsize=(14,7), nrows=1, ncols=2)
color=["#ffa3b1","#77d2fc", "#a7faa9"]
label= ["medium", "high", "low"]
ax[0].pie(x=df_perc2["percentage"]["<=50K"], labels=label, autopct="%.2f%%", colors=color)
ax[0].set_title("<=50K")
ax[0].set_ylabel("percentage")

ax[1].pie(x=df_perc2["percentage"][">50K"], labels=label, autopct="%.2f%%", colors=color)
ax[1].set_title(">50K")
ax[1].set_ylabel("percentage");

# %%
df_perc3.set_index("salary").astype(str).T
# Out:
# salary                          <=50K               <=50K  \
# education_summary  medium_level_grade    high_level_grade
# percentage         0.6696493643209976  0.1682322455259535
#
# salary                           <=50K                 >50K  \
# education_summary      low_level_grade     high_level_grade
# percentage         0.16211839015304882  0.49866054343666283
#
# salary                           >50K                 >50K
# education_summary  medium_level_grade      low_level_grade
# percentage         0.4702130373772165  0.03112641918612068

# %% [markdown]
# ## Conclusion about education level by salary
#
# ###  It can be evaluated that as the level of education increases, the salaries also increase, and the proportion of people with higher education level is even higher in salaries above 50K.

# %% [markdown]
# # marital_status & relationship features

# %%
# finding the count of person in each marital_status
us_citizens.marital_status.value_counts(dropna=False)
# Out:
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
# finding the count of person in each relationship

us_citizens.relationship.value_counts(dropna=False)
# Out:
# Husband           13187
# Not-in-family      8292
# NaN                5064
# Unmarried          3445
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
us_citizens.groupby("marital_status")["relationship"].value_counts(dropna=False)

# it is difficult to say that there is a similarity in between marital_status and relationship
# Out:
# marital_status         relationship
# Divorced               Not-in-family      2403
#                        Unmarried          1600
#                        NaN                 328
#                        Other-relative      110
# Married-AF-spouse      Wife                 12
#                        Husband               9
#                        NaN                   1
#                        Other-relative        1
# Married-civ-spouse     Husband           13178
#                        Wife               1556
#                        Other-relative      124
#                        NaN                  95
#                        Not-in-family        17
# Married-spouse-absent  Not-in-family       211
#                        Unmarried           130
#                        NaN                  45
#                        Other-relative       32
# Never-married          Not-in-family      4694
#                        NaN                4481
# ...

# %%
# Filling missing values in relationship feature with "Unknown"

us_citizens.fillna("Unknown", inplace=True)

# %%
us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                32537 non-null  int64
#  1   workclass          32537 non-null  object
#  2   fnlwgt             32537 non-null  int64
#  3   education          32537 non-null  object
#  4   education_num      32537 non-null  object
#  5   marital_status     32537 non-null  object
#  6   occupation         32537 non-null  object
#  7   relationship       32537 non-null  object
#  8   race               32537 non-null  object
#  9   sex                32537 non-null  object
#  10  capital_gain       32537 non-null  int64
#  11  capital_loss       32537 non-null  int64
#  12  hours_per_week     32537 non-null  int64
#  13  native_country     32537 non-null  object
#  14  salary             32537 non-null  object
#  15  education_summary  32537 non-null  object
# ...

# %%
us_citizens.groupby("relationship", dropna=False)["marital_status"].value_counts()
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13178
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4694
#                 Divorced                  2403
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4481
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %%
# countplot for marital_status feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="marital_status")
plt.xticks(rotation=45);

# %%
# finding the count of person in each marital status by salary

us_citizens.groupby("marital_status")["salary"].value_counts(dropna=False)
# Out:
# marital_status         salary
# Divorced               <=50K      3978
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8280
#                        >50K       6690
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10176
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="marital_status", hue="salary")
plt.xticks(rotation=45);

# %% [markdown]
# ### Decreasing the number of catergories in marital_status feature as married an unmarried and creating a new feature with this new categorical data

# %%
# grouping marital_status as married and unmarried

def mapping_marital_status(x):
    if x in ["Never-married", "Divorced", "Separated", "Widowed"]:
        return "unmarried"
    elif x in ["Married-civ-spouse", "Married-AF-spouse", "Married-spouse-absent"]:
        return "married"

# %%
# finding the count of person in each new category (married, unmarried)

us_citizens.marital_status.map(mapping_marital_status).value_counts()
# Out:
# unmarried    17126
# married      15411
# Name: marital_status, dtype: int64

# %%
# creating new feature named marital_status_summary

us_citizens["marital_status_summary"] = us_citizens.marital_status.map(mapping_marital_status)

# %%
us_citizens.head()
# Out:
#    age         workclass  fnlwgt  education education_num      marital_status  \
# 0   39         State-gov   77516  Bachelors        13.000       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors        13.000  Married-civ-spouse
# 2   38           Private  215646    HS-grad         9.000            Divorced
# 3   53           Private  234721       11th         7.000  Married-civ-spouse
# 4   28           Private  338409  Bachelors        13.000  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital_gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital_loss  hours_per_week native_country salary   education_summary  \
# ...

# %%
# count plot for marital_status_summary feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="marital_status_summary");

# %%
# finding the count of person in each marital_status_summary levels by salary levels

us_citizens.groupby("marital_status_summary")["salary"].value_counts(dropna=False)
# Out:
# marital_status_summary  salary
# married                 <=50K      8677
#                         >50K       6734
# unmarried               <=50K     16021
#                         >50K       1105
# Name: salary, dtype: int64

# %%
# count plot for marital_status_summary feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="marital_status_summary", hue="salary");

# %%
# finding the percentage of person in each salary levels by marital_status_summary levels

us_citizens.groupby("marital_status_summary")["salary"].value_counts(normalize=True, dropna=False)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.935
#                         >50K     0.065
# Name: salary, dtype: float64

# %%
# finding the percentage of person in each marital_status_summary levels by salary as a dataframe

df_marr_perc=pd.DataFrame(us_citizens.groupby("marital_status_summary")["salary"].value_counts(normalize=True))
df_marr_perc.columns = ["percentage"]
df_marr_perc = df_marr_perc.unstack(level=0)
df_marr_perc
# Out:
#                        percentage
# marital_status_summary    married unmarried
# salary
# <=50K                       0.563     0.935
# >50K                        0.437     0.065

# %%
# pie plot for each marital_status_summary level by salary 

fig, ax=plt.subplots(figsize=(15,7), nrows=1, ncols=2)
color=["#ffa3b1","#77d2fc"]
ax[0].pie(x=df_marr_perc.percentage.married, labels=df_marr_perc.index, autopct="%.2f%%", colors=color)
ax[0].set_title("married")
ax[0].set_ylabel("salary")

ax[1].pie(x=df_marr_perc.percentage.unmarried, labels=df_marr_perc.index, autopct="%.2f%%", colors=color)
ax[1].set_title("unmarried")
ax[1].set_ylabel("salary");

# %%
# finding the count of person in each salary levels by marital_status_summary levels

us_citizens.groupby("salary")["marital_status_summary"].value_counts(dropna=False)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                 16021
#         married                    8677
# >50K    married                    6734
#         unmarried                  1105
# Name: marital_status_summary, dtype: int64

# %%
# count plot for salary feature by marital_status_summary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="marital_status_summary");

# %%
# finding the percentage of person in each salary levels by marital_status_summary levels

us_citizens.groupby("salary")["marital_status_summary"].value_counts(normalize=True, dropna=False)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
# finding the percentage of person in each salary levels by marital_status_summary as a dataframe

df_sal_perc=pd.DataFrame(us_citizens.groupby("salary")["marital_status_summary"].value_counts(normalize=True))
df_sal_perc.columns = ["percentage"]
df_sal_perc = df_sal_perc.unstack(level=0)
df_sal_perc
# Out:
#                        percentage
# salary                      <=50K  >50K
# marital_status_summary
# married                     0.351 0.859
# unmarried                   0.649 0.141

# %%
# pie plot for each salary level by marital_status_summary 

fig, ax=plt.subplots(figsize=(15,7), nrows=1, ncols=2)
color=["#ffa3b1","#77d2fc"]
ax[0].pie(x=df_sal_perc["percentage"]["<=50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
ax[0].set_title("<=50K")
ax[0].set_ylabel("percentage")

ax[1].pie(x=df_sal_perc["percentage"][">50K"], labels=df_sal_perc.index, autopct="%.2f%%", colors=color)
ax[1].set_title(">50K")
ax[1].set_ylabel("percentage");

# %% [markdown]
# ## Conclusion about marital_status and salary
#
# ### In the whole data set, the numbers of married and unmarried are close to each other. However, when we analyze it on the basis of salary, it is seen that the rate of married people is high among those whose salary is over 50K.

# %% [markdown]
# # workclass and salary features

# %%
# finding the count of person in each categories of workclass feature

us_citizens.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# count plot for workclass feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="workclass")
plt.xticks(rotation=90);

# %%
# Replacing "?" values with "Unknow"

us_citizens["workclass"] = us_citizens.workclass.str.replace("?","Unknow")

# %%
# checking the value counts for workclass
us_citizens.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknow               1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# finding the counts of person in workclass feature by salary

us_citizens.groupby("workclass")["salary"].value_counts(dropna=False)
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17712
#                   >50K       4961
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1816
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknow            <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %%
# count plot for workclass feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="workclass", hue="salary")
plt.xticks(rotation=90);

# %%
# finding the percentage of person in workclass feature by salary

us_citizens.groupby("workclass")["salary"].value_counts(normalize=True, dropna=False)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknow            <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
# finding the percentage of person in each workclass categories by salary as a dataframe

df_wrkclass = pd.DataFrame(us_citizens.groupby("workclass")["salary"].value_counts(normalize=True, dropna=False))
df_wrkclass.columns=["percentage"]
df_wrkclass = df_wrkclass.reset_index()
df_wrkclass
# Out:
#            workclass salary  percentage
# 0        Federal-gov  <=50K       0.614
# 1        Federal-gov   >50K       0.386
# 2          Local-gov  <=50K       0.705
# 3          Local-gov   >50K       0.295
# 4       Never-worked  <=50K       1.000
# 5            Private  <=50K       0.781
# 6            Private   >50K       0.219
# 7       Self-emp-inc   >50K       0.557
# 8       Self-emp-inc  <=50K       0.443
# 9   Self-emp-not-inc  <=50K       0.715
# 10  Self-emp-not-inc   >50K       0.285
# 11         State-gov  <=50K       0.728
# 12         State-gov   >50K       0.272
# 13            Unknow  <=50K       0.896
# 14            Unknow   >50K       0.104
# 15       Without-pay  <=50K       1.000

# %%
# bar plot for workclass feature by salary

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = sns.barplot(data=df_wrkclass, x="workclass", y="percentage", hue="salary")
plt.xticks(rotation=90)

for i in range(len(df_wrkclass.salary.value_counts())) :
    ax.bar_label(ax.containers[i], fmt="%.2f");

# %%
# finding the counts of person in salary feature by workclass

us_citizens.groupby("salary")["workclass"].value_counts(dropna=False)
# Out:
# salary  workclass
# <=50K   Private             17712
#         Self-emp-not-inc     1816
#         Unknow               1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4961
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknow                191
# Name: workclass, dtype: int64

# %%
# count plot for salary feature by workclass
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="workclass")
plt.legend(loc="upper right");

# %%
# finding the percentage of person in salary feature by workclass

us_citizens.groupby("salary")["workclass"].value_counts(normalize=True, dropna=False)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknow             0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknow             0.024
# Name: workclass, dtype: float64

# %%
# finding the percentage of person in each salary levels by workclass as a dataframe

df_wc_norm = pd.DataFrame(us_citizens.groupby("salary")["workclass"].value_counts(normalize=True, dropna=False))
df_wc_norm.columns=["percentage"]
df_wc_norm = df_wc_norm.reset_index()
df_wc_norm = df_wc_norm.sort_values(by=["salary","workclass"])

# %%
# bar plot for salary feature by workclass

plt.figure(figsize= (12,7))
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = sns.barplot(data=df_wc_norm, x="salary", y="percentage", hue="workclass")

for i in range(len(df_wrkclass.workclass.value_counts())) :
    ax.bar_label(ax.containers[i], fmt="%.2f", padding=1, fontsize=13);

# %% [markdown]
# ## Conclusion about workclass and salary features
#
# ### It can be said that most of the people work in the private sector and the same result is reached when the analysis is made according to the salary.

# %% [markdown]
# # Occupation and Salary Features

# %%
# finding the count of person in occupation feature

us_citizens.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# count plot for occupation feature

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="occupation")
plt.xticks(rotation=90);

# %%
# Replacing "?" values with "Unknow"

us_citizens["occupation"] = us_citizens.occupation.str.replace("?","Unknow")

# %%
# checking the count of people after repleacing step

us_citizens.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknow               1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# finding the count of person in occupation feature by salary

us_citizens.groupby("occupation")["salary"].value_counts(dropna=False)
# Out:
# occupation         salary
# Adm-clerical       <=50K     3261
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3165
#                    >50K       929
# Exec-managerial    <=50K     2097
#                    >50K      1968
# Farming-fishing    <=50K      877
#                    >50K       115
# Handlers-cleaners  <=50K     1283
#                    >50K        86
# Machine-op-inspct  <=50K     1751
#                    >50K       249
# Other-service      <=50K     3154
#                    >50K       137
# Priv-house-serv    <=50K      146
#                    >50K         1
# Prof-specialty     <=50K     2278
#                    >50K      1858
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      644
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
# count plot for occupation feature by salary

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="occupation", hue="salary")
plt.xticks(rotation=90);

# %%
# finding the percentage of person in occupation feature by salary as a dataframe

df_occp = pd.DataFrame(us_citizens.groupby("occupation")["salary"].value_counts(normalize=True, dropna=False))
df_occp.columns = ["percentage"]
df_occp= df_occp.reset_index()
df_occp
# Out:
#            occupation salary  percentage
# 0        Adm-clerical  <=50K       0.865
# 1        Adm-clerical   >50K       0.135
# 2        Armed-Forces  <=50K       0.889
# 3        Armed-Forces   >50K       0.111
# 4        Craft-repair  <=50K       0.773
# 5        Craft-repair   >50K       0.227
# 6     Exec-managerial  <=50K       0.516
# 7     Exec-managerial   >50K       0.484
# 8     Farming-fishing  <=50K       0.884
# 9     Farming-fishing   >50K       0.116
# 10  Handlers-cleaners  <=50K       0.937
# 11  Handlers-cleaners   >50K       0.063
# 12  Machine-op-inspct  <=50K       0.875
# 13  Machine-op-inspct   >50K       0.124
# 14      Other-service  <=50K       0.958
# 15      Other-service   >50K       0.042
# 16    Priv-house-serv  <=50K       0.993
# 17    Priv-house-serv   >50K       0.007
# 18     Prof-specialty  <=50K       0.551
# 19     Prof-specialty   >50K       0.449
# 20    Protective-serv  <=50K       0.675
# 21    Protective-serv   >50K       0.325
# ...

# %%
# bar plot for occupation feature by salary

plt.figure(figsize=(15,7))
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = sns.barplot(data=df_occp, x="occupation", y="percentage", hue="salary")
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.15,0.5))

for i in range(len(df_occp.salary.value_counts())) :
    ax.bar_label(ax.containers[i], fmt="%.2f", fontsize=13);

# %%
# finding the count of person in salary feature by occupation

us_citizens.groupby("salary")["occupation"].value_counts(dropna=False)
# Out:
# salary  occupation
# <=50K   Adm-clerical         3261
#         Craft-repair         3165
#         Other-service        3154
#         Sales                2667
#         Prof-specialty       2278
#         Exec-managerial      2097
#         Machine-op-inspct    1751
#         Unknow               1652
#         Handlers-cleaners    1283
#         Transport-moving     1277
#         Farming-fishing       877
#         Tech-support          644
#         Protective-serv       438
#         Priv-house-serv       146
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1858
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     249
#         Protective-serv       211
#         Unknow                191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
# count plot for salary feature by occupation

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="occupation")
plt.legend(bbox_to_anchor=(1.1,0.92));

# %%
# finding the percentage of person in salary feature by occupation

us_citizens.groupby("salary")["occupation"].value_counts(normalize=True, dropna=False)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknow              0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.119
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknow              0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
# finding the percentage of person in salary feature by occupation as a dataframe

df_occp_perc = pd.DataFrame(us_citizens.groupby("salary")["occupation"].value_counts(normalize=True, dropna=False))
df_occp_perc.columns = ["percentage"]
df_occp_perc = df_occp_perc.reset_index()
df_occp_perc = df_occp_perc.sort_values(by=["salary", "occupation"])

# %%
# bar plot for salary feature by workclass

plt.figure(figsize= (17,9))
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = sns.barplot(data=df_occp_perc, x="salary", y="percentage", hue="occupation")

for i in range(len(df_occp_perc.occupation.value_counts())) :
    ax.bar_label(ax.containers[i], fmt="%.2f", padding=1, fontsize=13);

# %% [markdown]
# ## Conclusion about occupation feature by salary
#
# ### Occupations of those with a salary of less than 50K vary widely. On the other hand, Exec-manegarial, Prof-speciality, Sales and Craft-repair professions come to the fore among those with 50K or more.

# %% [markdown]
# # race and salary features

# %%
# finding the count of person in race feature

us_citizens.race.value_counts(dropna=False)
# Out:
# White                 27795
# Black                  3122
# Asian-Pac-Islander     1038
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
# count plot for race feature
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="race")
plt.xticks(rotation=45);

# %%
# finding the count of person in race feature by salary

us_citizens.groupby("race")["salary"].value_counts(dropna=False)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       762
#                     >50K        276
# Black               <=50K      2735
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20680
#                     >50K       7115
# Name: salary, dtype: int64

# %%
# count plot for race feature by salary
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="race", hue="salary");

# %%
# finding the percentage of person in race feature by salary

us_citizens.groupby("race")["salary"].value_counts(normalize=True, dropna=False)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
# finding the percentage of person in race feature by salary as a dataframe

df_race = pd.DataFrame(us_citizens.groupby("race")["salary"].value_counts(normalize=True, dropna=False))
df_race.columns=["persentage"]
df_race = df_race.unstack(level=0)
df_race
# Out:
#                persentage
# race   Amer-Indian-Eskimo Asian-Pac-Islander Black Other White
# salary
# <=50K               0.884              0.734 0.876 0.908 0.744
# >50K                0.116              0.266 0.124 0.092 0.256

# %%
# pie plots for race feature by salary

df_race.plot(kind="pie",
             subplots=True,
             layout=(2,3),
             figsize=(18,12),
             autopct="%.2f%%",
             ylabel="salary",
             colors=color,
             legend=False,
            title=["Amer-Indian-Eskimo","Asian-Pac-Islander","Black","Other","White"]);

# %%
# finding the count of person in salary feature by race

us_citizens.groupby("salary")["race"].value_counts(dropna=False)
# Out:
# salary  race
# <=50K   White                 20680
#         Black                  2735
#         Asian-Pac-Islander      762
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7115
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
# count plot for salary feature by race
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="race");

# %%
# finding the percentage of person in salary feature by race

us_citizens.groupby("salary")["race"].value_counts(normalize=True, dropna=False)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
# finding the percentage of person in salary feature by race as a dataframe

df_race_perc = pd.DataFrame(us_citizens.groupby("salary")["race"].value_counts(normalize=True, dropna=False))
df_race_perc.columns=["percentage"]
df_race_perc = df_race_perc.reset_index()
df_race_perc = df_race_perc.sort_values(by=["salary","race"])
df_race_perc
# Out:
#   salary                race  percentage
# 3  <=50K  Amer-Indian-Eskimo       0.011
# 2  <=50K  Asian-Pac-Islander       0.031
# 1  <=50K               Black       0.111
# 4  <=50K               Other       0.010
# 0  <=50K               White       0.837
# 8   >50K  Amer-Indian-Eskimo       0.005
# 7   >50K  Asian-Pac-Islander       0.035
# 6   >50K               Black       0.049
# 9   >50K               Other       0.003
# 5   >50K               White       0.908

# %%
# bar plot for race feature by salary

plt.figure(figsize=(15,7))
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = sns.barplot(data=df_race_perc, x="salary", y="percentage", hue="race")
plt.xticks(rotation=90)
# plt.legend(bbox_to_anchor=(1.15,0.5))

for i in range(len(df_race_perc.race.value_counts())) :
    ax.bar_label(ax.containers[i], fmt="%.2f", fontsize=13);

# %% [markdown]
# ## Conclusion about race and salary feature
#
# ###  Most of the people in the race column are white. When we compared the salaries according to races, the ratio of those who earn more than 50K in the white and Asian-Pac-Islander races is higher than the others. When we compare the percentages of race on a salary basis, the percentage of white race is higher in both salary levels, while this rate is slightly higher for those with a salary above 50K.

# %% [markdown]
# # gender and salary features

# %%
# finding the count of person in gender feature

us_citizens.sex.value_counts(dropna=False)
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64

# %%
# count plot for gender fetaure

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="sex");

# %%
# finding the count of person in gender feature by salary

us_citizens.groupby("sex")["salary"].value_counts(dropna=False)
# Out:
# sex     salary
# Female  <=50K      9583
#         >50K       1179
# Male    <=50K     15115
#         >50K       6660
# Name: salary, dtype: int64

# %%
# count plot for gender fetaure by salary

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="sex", hue="salary");

# %%
# finding the percentage of person in gender feature by salary

us_citizens.groupby("sex")["salary"].value_counts(normalize=True, dropna=False)
# Out:
# sex     salary
# Female  <=50K    0.890
#         >50K     0.110
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
# finding the percentage of person in gender feature by salary as a dataframe

df_gender = pd.DataFrame(us_citizens.groupby("sex")["salary"].value_counts(normalize=True, dropna=False))
df_gender.columns = ["percentage"]
df_gender = df_gender.unstack(level=0)
df_gender
# Out:
#        percentage
# sex        Female  Male
# salary
# <=50K       0.890 0.694
# >50K        0.110 0.306

# %%
# pie plot for gender feature by salary

df_gender.plot(kind="pie",
             subplots=True,
             layout=(1,2),
             figsize=(16,8),
             autopct="%.2f%%",
             ylabel="salary",
             colors=color,
             legend=False,
            title=["Female","Male"]);

# %%
# finding the count of person in salary feature by gender

us_citizens.groupby("salary")["sex"].value_counts(dropna=False)
# Out:
# salary  sex
# <=50K   Male      15115
#         Female     9583
# >50K    Male       6660
#         Female     1179
# Name: sex, dtype: int64

# %%
# count plot for salary fetaure by gender

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="sex");

# %%
# finding the percentage of person in salary feature by gender

us_citizens.groupby("salary")["sex"].value_counts(normalize=True, dropna=False)
# Out:
# salary  sex
# <=50K   Male     0.612
#         Female   0.388
# >50K    Male     0.850
#         Female   0.150
# Name: sex, dtype: float64

# %%
# finding the percentage of person in salary feature by gender as a dataframe

df_gender_perc = pd.DataFrame(us_citizens.groupby("salary")["sex"].value_counts(normalize=True, dropna=False))
df_gender_perc.columns = ["percentage"]
df_gender_perc = df_gender_perc.unstack(level=0)
df_gender_perc
# Out:
#        percentage
# salary      <=50K  >50K
# sex
# Female      0.388 0.150
# Male        0.612 0.850

# %%
# pie plot for salary feature by gender

df_gender_perc.plot(kind="pie",
             subplots=True,
             layout=(1,2),
             figsize=(16,8),
             autopct="%.2f%%",
             ylabel="gender",
             colors=color,
             legend=False,
            title=["<=50K",">50K"]);

# %% [markdown]
# ## Conclusion about gender and salary feature
#
# ### 67% of the people in the gender feature are male and the rest are female. When we compare the gender feature by salary. The rate of men with a salary >50K is higher than that of women. The proportion of women with a salary >50K is less than those with a salary <=50K.

# %% [markdown]
# # native_country and salary features

# %%
# finding the count of person in each category of native_country feature

us_citizens.native_country.value_counts(dropna=False)
# Out:
# United-States                 29153
# Mexico                          639
# ?                               582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# count plot for native_country feature

plt.figure(figsize=(15,6))
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="native_country")
plt.xticks(rotation=90);

# %%
# replacing "?" with "Unknown" in native_country feature

us_citizens.native_country = us_citizens.native_country.str.replace("?", "Unknown")

# %%
# checking the native_country feature after replacing step

us_citizens.native_country.value_counts(dropna=False)
# Out:
# United-States                 29153
# Mexico                          639
# Unknown                         582
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Japan                            62
# Guatemala                        62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
# decreasing the number of categories in native_country feature as US and Others

def mapping_native_country(x):
    if x == "United-States":
        return "US"
    else:
        return "Others"

# %%
us_citizens["native_country_summary"] = us_citizens.native_country.map(mapping_native_country)
us_citizens["native_country_summary"]
# Out:
# 0            US
# 1            US
# 2            US
# 3            US
# 4        Others
#           ...
# 32556        US
# 32557        US
# 32558        US
# 32559        US
# 32560        US
# Name: native_country_summary, Length: 32537, dtype: object

# %%
us_citizens.native_country_summary.value_counts()
# Out:
# US        29153
# Others     3384
# Name: native_country_summary, dtype: int64

# %%
# count plot for native_country_summary feature

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="native_country_summary")
# Out:
# <AxesSubplot:xlabel='native_country_summary', ylabel='count'>

# %%
# finding the count or person in native_country_summary feature by salary

us_citizens.groupby("native_country_summary")["salary"].value_counts(dropna=False)
# Out:
# native_country_summary  salary
# Others                  <=50K      2714
#                         >50K        670
# US                      <=50K     21984
#                         >50K       7169
# Name: salary, dtype: int64

# %%
# count plot for native_country_summary feature by salary

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="native_country_summary", hue="salary");

# %%
# finding the percentage or person in native_country_summary feature by salary

us_citizens.groupby("native_country_summary")["salary"].value_counts(normalize=True, dropna=False)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
#creating a necessary dataframe in order to pie plot

df_nat_cntry = pd.DataFrame(us_citizens.groupby("native_country_summary")["salary"].value_counts(normalize=True, dropna=False))
df_nat_cntry.columns = ["percentage"]
df_nat_cntry = df_nat_cntry.unstack(level=0)
df_nat_cntry
# Out:
#                        percentage
# native_country_summary     Others    US
# salary
# <=50K                       0.802 0.754
# >50K                        0.198 0.246

# %%
# pie plot for native_country_summary feature by salary

df_nat_cntry.plot(kind="pie",
             subplots=True,
             layout=(1,2),
             figsize=(16,8),
             autopct="%.2f%%",
             ylabel="salary",
             colors=color,
             legend=False,
            title=["Others","US"]);

# %%
# finding the count or person in salary feature by native_country_summary

us_citizens.groupby("salary")["native_country_summary"].value_counts(dropna=False)
# Out:
# salary  native_country_summary
# <=50K   US                        21984
#         Others                     2714
# >50K    US                         7169
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
# count plot for salary feature by native_country_summary

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.countplot(data=us_citizens, x="salary", hue="native_country_summary");

# %%
# finding the percentage or person in native_country_summary feature by salary

us_citizens.groupby("salary")["native_country_summary"].value_counts(normalize=True, dropna=False)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
#creating a necessary dataframe in order to pie plot

df_nat_cntry_perc = pd.DataFrame(us_citizens.groupby("salary")["native_country_summary"].value_counts(normalize=True, dropna=False))
df_nat_cntry_perc.columns = ["percentage"]
df_nat_cntry_perc = df_nat_cntry_perc.unstack(level=0)
df_nat_cntry_perc
# Out:
#                        percentage
# salary                      <=50K  >50K
# native_country_summary
# Others                      0.110 0.085
# US                          0.890 0.915

# %%
# pie plot for native_country_summary feature by salary

df_nat_cntry_perc.plot(kind="pie",
             subplots=True,
             layout=(1,2),
             figsize=(16,8),
             autopct="%.2f%%",
             ylabel="native_country_summary",
             colors=color,
             legend=False,
            title=["<=50K",">50K"]);

# %% [markdown]
# ## Conclusion about native_country and salary
#
# ### Approximately 90% of the data in the native_country column is from the US. For US natives, the proportion of those with a salary >50K is higher than the others.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           32537 non-null  object
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
# finding the average age of males and females by income level

us_citizens.groupby(["salary", "sex"])["age"].mean()
# Out:
# salary  sex
# <=50K   Female   36.217
#         Male     37.149
# >50K    Female   42.126
#         Male     44.627
# Name: age, dtype: float64

# %%
# bar plot for age by gender and salary

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = pd.DataFrame(us_citizens.groupby(["salary", "sex"])["age"].mean()).plot(kind="bar",
                                                                                      legend=False,
                                                                                      xlabel="salary, gender")
ax.bar_label(ax.containers[0], fmt="%.2f");

# %%
# creating a dataframe containin average age by gender and salary

df_age_mean = pd.DataFrame(us_citizens.groupby(["salary", "sex"])["age"].mean())
df_age_mean = df_age_mean.reset_index()
df_age_mean.rename({"sex":"gender"}, axis=1, inplace=True)
df_age_mean
# Out:
#   salary  gender    age
# 0  <=50K  Female 36.217
# 1  <=50K    Male 37.149
# 2   >50K  Female 42.126
# 3   >50K    Male 44.627

# %%
# bar plot for age and salary by gender
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax = sns.barplot(data=df_age_mean, x="salary", y="age", hue="gender")

for i in range(len(df_age_mean.salary.value_counts().index)):
    ax.bar_label(ax.containers[i], fmt="%.2f")
plt.legend(fontsize=15);

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
# workclass percentages of Americans in high-level income group

us_citizens[(us_citizens.native_country == "United-States")&(us_citizens.salary == ">50K")]["workclass"].value_counts(normalize=True) * 100
# Out:
# Private            63.314
# Self-emp-not-inc    9.192
# Local-gov           8.021
# Self-emp-inc        7.784
# Federal-gov         4.687
# State-gov           4.547
# Unknow              2.455
# Name: workclass, dtype: float64

# %%
df_wcprcntg= pd.DataFrame(us_citizens[(us_citizens.native_country == "United-States")&(us_citizens.salary == ">50K")]["workclass"].value_counts(normalize=True) * 100)
df_wcprcntg= df_wcprcntg.reset_index()
df_wcprcntg.columns=["workclass", "percentage"]
df_wcprcntg
# Out:
#           workclass  percentage
# 0           Private      63.314
# 1  Self-emp-not-inc       9.192
# 2         Local-gov       8.021
# 3      Self-emp-inc       7.784
# 4       Federal-gov       4.687
# 5         State-gov       4.547
# 6            Unknow       2.455

# %%
# bar plot for percentage of Americans in high-level income group

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_wcprcntg, x="workclass", y="percentage")
plt.xticks(rotation=45)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
# occupation percentages of Americans who work as "Private" wrokclass in high-level income group

us_citizens[(us_citizens.native_country == "United-States")&(us_citizens.salary == ">50K")&(us_citizens.workclass == "Private")]["occupation"].value_counts(normalize=True) * 100
# Out:
# Exec-managerial     26.438
# Prof-specialty      19.476
# Craft-repair        14.695
# Sales               14.475
# Adm-clerical         6.389
# Transport-moving     5.442
# Tech-support         4.428
# Machine-op-inspct    4.428
# Other-service        1.674
# Handlers-cleaners    1.344
# Farming-fishing      0.595
# Protective-serv      0.595
# Priv-house-serv      0.022
# Name: occupation, dtype: float64

# %%
# bar plot for occupation percentages of Americans who work as "Private" wrokclass in high-level income group

df_occp_perc_high=pd.DataFrame(us_citizens[(us_citizens.native_country == "United-States")&(us_citizens.salary == ">50K")&(us_citizens.workclass == "Private")]["occupation"].value_counts(normalize=True) * 100)
df_occp_perc_high = df_occp_perc_high.reset_index()
df_occp_perc_high.columns = ["occupation","percentage"]
df_occp_perc_high
# Out:
#            occupation  percentage
# 0     Exec-managerial      26.438
# 1      Prof-specialty      19.476
# 2        Craft-repair      14.695
# 3               Sales      14.475
# 4        Adm-clerical       6.389
# 5    Transport-moving       5.442
# 6        Tech-support       4.428
# 7   Machine-op-inspct       4.428
# 8       Other-service       1.674
# 9   Handlers-cleaners       1.344
# 10    Farming-fishing       0.595
# 11    Protective-serv       0.595
# 12    Priv-house-serv       0.022

# %%
# bar plot for occupation percentages of Americans who work as "Private" wrokclass in high-level income group

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_occp_perc_high, x="occupation", y="percentage")
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
# education level percentages of Asian_Pac_Islander race group in igh_level income group

us_citizens[(us_citizens.race == "Asian-Pac-Islander")&(us_citizens.salary == ">50K")]["education"].value_counts(normalize=True) * 100
# Out:
# Bachelors      35.145
# Masters        15.580
# HS-grad        12.319
# Some-college   11.957
# Prof-school     9.783
# Doctorate       6.522
# Assoc-voc       3.261
# Assoc-acdm      2.899
# 5th-6th         1.087
# 9th             0.362
# 11th            0.362
# 10th            0.362
# 12th            0.362
# Name: education, dtype: float64

# %%
df_Asian = pd.DataFrame(us_citizens[(us_citizens.race == "Asian-Pac-Islander")&(us_citizens.salary == ">50K")]["education"].value_counts(normalize=True) * 100)
df_Asian = df_Asian.reset_index()
df_Asian.columns = ["education","percentage"]
df_Asian
# Out:
#        education  percentage
# 0      Bachelors      35.145
# 1        Masters      15.580
# 2        HS-grad      12.319
# 3   Some-college      11.957
# 4    Prof-school       9.783
# 5      Doctorate       6.522
# 6      Assoc-voc       3.261
# 7     Assoc-acdm       2.899
# 8        5th-6th       1.087
# 9            9th       0.362
# 10          11th       0.362
# 11          10th       0.362
# 12          12th       0.362

# %%
# bar plot for percentages of Asian_Pac_Islander race group in igh_level income group

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_Asian, x="education", y="percentage")
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
# occupation percentages of Asian_Pac_Islander race group who has a Bachelors degree in high-level

us_citizens[(us_citizens.race == "Asian-Pac-Islander")&(us_citizens.education == "Bachelors")&(us_citizens.salary == ">50K")]["occupation"].value_counts(normalize=True) * 100
# Out:
# Exec-managerial     27.835
# Prof-specialty      25.773
# Adm-clerical        12.371
# Sales                9.278
# Other-service        9.278
# Craft-repair         7.216
# Tech-support         3.093
# Protective-serv      2.062
# Transport-moving     1.031
# Machine-op-inspct    1.031
# Farming-fishing      1.031
# Name: occupation, dtype: float64

# %%
df_Asian_Bachelors = pd.DataFrame(us_citizens[(us_citizens.race == "Asian-Pac-Islander")&(us_citizens.education == "Bachelors")&(us_citizens.salary == ">50K")]["occupation"].value_counts(normalize=True) * 100)
df_Asian_Bachelors = df_Asian_Bachelors.reset_index()
df_Asian_Bachelors.columns = ["occupation","percentage"]
df_Asian_Bachelors
# Out:
#            occupation  percentage
# 0     Exec-managerial      27.835
# 1      Prof-specialty      25.773
# 2        Adm-clerical      12.371
# 3               Sales       9.278
# 4       Other-service       9.278
# 5        Craft-repair       7.216
# 6        Tech-support       3.093
# 7     Protective-serv       2.062
# 8    Transport-moving       1.031
# 9   Machine-op-inspct       1.031
# 10    Farming-fishing       1.031

# %%
# bar plot for occupation percentages of Asian_Pac_Islander race group who has a Bachelors degree in high-level

sns.set(font_scale=1.2)
sns.set_style("whitegrid")
ax= sns.barplot(data=df_Asian_Bachelors, x="occupation", y="percentage")
plt.xticks(rotation=90)
ax.bar_label(ax.containers[0], fmt="%.2f");

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
g = sns.catplot(kind="bar", data=us_citizens,
                x="education_summary",
                y="hours_per_week",
                row = "native_country_summary",
                col="marital_status_summary",
                hue="sex",
               height=4,
               aspect=1.8,
               palette="bwr_r",
              ci=None)


# iterate through axes
for ax in g.axes.ravel():
    
    # add annotations
    for c in ax.containers:
        labels = [f'{(v.get_height()):.2f}' for v in c]
        ax.bar_label(c, labels=labels, label_type='edge')
    ax.margins(y=0.2)

;
# Out:
# ''

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32537 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32537 non-null  int64
#  1   workclass               32537 non-null  object
#  2   fnlwgt                  32537 non-null  int64
#  3   education               32537 non-null  object
#  4   education_num           32537 non-null  object
#  5   marital_status          32537 non-null  object
#  6   occupation              32537 non-null  object
#  7   relationship            32537 non-null  object
#  8   race                    32537 non-null  object
#  9   sex                     32537 non-null  object
#  10  capital_gain            32537 non-null  int64
#  11  capital_loss            32537 non-null  int64
#  12  hours_per_week          32537 non-null  int64
#  13  native_country          32537 non-null  object
# ...

# %%
# dropping similar and unnecessary features

us_citizens.drop(labels=["education", "education_num", "marital_status", "relationship", "native_country"], axis=1, inplace=True)

# %%
us_citizens.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary   education_summary  \
# 0          2174             0              40  <=50K    high_level_grade
# 1             0             0              13  <=50K    high_level_grade
# 2             0             0              40  <=50K  medium_level_grade
# 3             0             0              40  <=50K     low_level_grade
# 4             0             0              40  <=50K    high_level_grade
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# chaecking missing values

us_citizens.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# ### 1. It seems that there is no missing value. But we know that "workclass", and "occupation" features have missing values as the "Unknown" string values. Examine these features in more detail.
#
# ### 2. Decide if drop these "Unknown" string values or not

# %%
# checking the counts of values in workclass feature

us_citizens.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknow               1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# checking the counts of values in occupation feature

us_citizens.occupation.value_counts()
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# Unknow               1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# finding the count of Unknow and Never-worked categories in workclass feature

us_citizens[(us_citizens.workclass == "Unknow") | (us_citizens.workclass == "Never-worked")].workclass.value_counts()
# Out:
# Unknow          1836
# Never-worked       7
# Name: workclass, dtype: int64

# %%
# finding the count of Unknow categories in occupation feature for Unknow and Never-worked categories in workclass feature

us_citizens[(us_citizens.workclass == "Unknow") | (us_citizens.workclass == "Never-worked")].occupation.value_counts()
# Out:
# Unknow    1843
# Name: occupation, dtype: int64

# %% [markdown]
# ### As it is seen from the results above the sum of Unknow and Never-worked categories in workclass feature is equal to the count of Unknow category in occupation feature.
#
# ###  As a result we can drop these missing/Unknow values.

# %% [markdown]
# ## Replacing Unknow values with NaN

# %%
us_citizens.workclass.value_counts()
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# Unknow               1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# replacing Unknow values which is in workclass feature with NaN

us_citizens.workclass.replace("Unknow", np.nan, inplace=True)

# %%
us_citizens.workclass.value_counts(dropna=False)
# Out:
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# NaN                  1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
# replacing Unknow values which is in occupation feature with NaN

us_citizens.occupation.replace("Unknow", np.nan, inplace=True)

# %%
us_citizens.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# NaN                  1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# Protective-serv       649
# Priv-house-serv       147
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# dropping these missing values

us_citizens.isnull().sum()
# Out:
# age                          0
# workclass                 1836
# fnlwgt                       0
# occupation                1843
# race                         0
# sex                          0
# capital_gain                 0
# capital_loss                 0
# hours_per_week               0
# salary                       0
# education_summary            0
# marital_status_summary       0
# native_country_summary       0
# dtype: int64

# %%
us_citizens.dropna(inplace=True)

# %%
us_citizens.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %%
us_citizens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30694 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30694 non-null  int64
#  1   workclass               30694 non-null  object
#  2   fnlwgt                  30694 non-null  int64
#  3   occupation              30694 non-null  object
#  4   race                    30694 non-null  object
#  5   sex                     30694 non-null  object
#  6   capital_gain            30694 non-null  int64
#  7   capital_loss            30694 non-null  int64
#  8   hours_per_week          30694 non-null  int64
#  9   salary                  30694 non-null  object
#  10  education_summary       30694 non-null  object
#  11  marital_status_summary  30694 non-null  object
#  12  native_country_summary  30694 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
# box plots for numeric features
plt.figure(figsize=(12,8))
sns.set(font_scale=1.2)
sns.set_style("whitegrid")
sns.boxplot(data=us_citizens);

# %%
plt.boxplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10712/3965067987.py in <module>
# ----> 1 plt.boxplot()
#
# TypeError: boxplot() missing 1 required positional argument: 'x'

# %%
us_citizens.columns[us_citizens.dtypes == "int64"]

# %%
us_citizens.loc[:,us_citizens.columns[us_citizens.dtypes == "int64"]]

# %%
fig, ax = plt.subplots(figsize=(21,10), nrows=2, ncols=3)

sns.boxplot(ax=ax[0,0], x=us_citizens.age)
sns.boxplot(ax=ax[0,1], x=us_citizens.fnlwgt)
sns.boxplot(ax=ax[0,2], x=us_citizens.capital_gain)
sns.boxplot(ax=ax[1,0], x=us_citizens.capital_loss)
sns.boxplot(ax=ax[1,1], x=us_citizens.hours_per_week);

# %%
fig, ax = plt.subplots(figsize=(16,30), nrows=5, ncols=2)

sns.boxplot(ax=ax[0,0], x=us_citizens.age)
sns.histplot(ax=ax[0,1], x=us_citizens.age)
sns.boxplot(ax=ax[1,0], x=us_citizens.fnlwgt)
sns.histplot(ax=ax[1,1], x=us_citizens.fnlwgt)
sns.boxplot(ax=ax[2,0], x=us_citizens.capital_gain)
sns.histplot(ax=ax[2,1], x=us_citizens.capital_gain)
sns.boxplot(ax=ax[3,0], x=us_citizens.capital_loss)
sns.histplot(ax=ax[3,1], x=us_citizens.capital_loss)
sns.boxplot(ax=ax[4,0], x=us_citizens.hours_per_week)
sns.histplot(ax=ax[4,1], x=us_citizens.hours_per_week);

# %%
# checking the statistical values for all numeric features

us_citizens.loc[:,us_citizens.columns[us_citizens.dtypes == "int64"]].describe().T

# %% [markdown]
# ### 1. After analyzing all features, we have decided that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.
#
# ### 2. So let's examine "age and hours_per_week" features and detect extreme values which could be outliers by using IQR Rule.

# %% [markdown]
# # Age

# %%
# box plot and histplot for age feature

fig, ax = plt.subplots(figsize=(15,6), nrows=1, ncols=2)

sns.boxplot(ax=ax[0], y=us_citizens.age)
sns.histplot(ax=ax[1], x=us_citizens.age);

# %%
# finding q1, q3 and IQR values for age feature

q1_age = us_citizens.age.quantile(0.25)
q3_age = us_citizens.age.quantile(0.75)
IQR_age = q3_age-q1_age
q1_age, q3_age, IQR_age
# Out:
# (28.0, 47.0, 19.0)

# %%
# finding upper and lower limit using IQR method for age feature

lower_lim_age = q1_age - 1.5 * IQR_age
upper_lim_age = q3_age + 1.5 * IQR_age
lower_lim_age, upper_lim_age
# Out:
# (-0.5, 75.5)

# %%
# finding the count of observations whose age greater than upper limit

us_citizens[us_citizens.age > upper_lim_age].age.value_counts()
# Out:
# 90    35
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
# Defining the observations whose age greater than upper limit and sorting these observations by age in descending order

us_citizens[us_citizens.age > upper_lim_age].sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt       occupation                race  \
# 8806    90           Private   87372   Prof-specialty               White
# 14159   90         Local-gov  187749     Adm-clerical  Asian-Pac-Islander
# 28463   90       Federal-gov  195433     Craft-repair               White
# 12975   90           Private  250832  Exec-managerial               White
# 11996   90           Private   40388  Exec-managerial               White
# ...    ...               ...     ...              ...                 ...
# 15102   76         Local-gov  169133     Adm-clerical               White
# 19085   76           Private  125784  Exec-managerial               White
# 23515   76           Private  142535     Adm-clerical               White
# 8240    76  Self-emp-not-inc  225964            Sales               White
# 23354   76           Private  199949     Adm-clerical               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# # Hours_per_week

# %%
# box plot and histplot for hours_per_week feature

fig, ax = plt.subplots(figsize=(15,6), nrows=1, ncols=2)

sns.boxplot(ax=ax[0], y=us_citizens.hours_per_week)
sns.histplot(ax=ax[1], x=us_citizens.hours_per_week);

# %%
# finding q1, q3 and IQR values for hours_per_week feature

q1_hpw = us_citizens.hours_per_week.quantile(0.25)
q3_hpw = us_citizens.hours_per_week.quantile(0.75)
IQR_hpw = q3_hpw-q1_hpw
q1_hpw, q3_hpw, IQR_hpw
# Out:
# (40.0, 45.0, 5.0)

# %%
# finding upper and lower limit using IQR method for hours_per_week feature

lower_lim_hpw = q1_hpw - 1.5 * IQR_hpw
upper_lim_hpw = q3_hpw + 1.5 * IQR_hpw
lower_lim_hpw, upper_lim_hpw
# Out:
# (32.5, 52.5)

# %%
# finding the count of observations whose hours_per_week greater than upper limit
# sorting these values in descending order

us_citizens[us_citizens.hours_per_week > upper_lim_hpw].hours_per_week.value_counts().sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     683
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
# finding the observations whose hours_per_week greater than upper limit

us_citizens[us_citizens.hours_per_week > upper_lim_hpw].sort_values(by="hours_per_week", ascending=False)
# Out:
#        age         workclass  fnlwgt        occupation   race     sex  \
# 25986   44         Local-gov  212665   Protective-serv  Black    Male
# 19529   38           Private   66326  Transport-moving  White    Male
# 8796    39           Private   70995  Transport-moving  White    Male
# 15534   29           Private  167716     Other-service  White  Female
# 22313   26  Self-emp-not-inc  258306   Farming-fishing  White    Male
# ...    ...               ...     ...               ...    ...     ...
# 1138    27           Private  138705      Craft-repair  White    Male
# 23244   58           Private  248739   Farming-fishing  White    Male
# 28858   62           Private  123411  Transport-moving  White    Male
# 18417   24           Private  117167     Other-service  White  Female
# 31622   61  Self-emp-not-inc  268831             Sales  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary   education_summary  \
# ...

# %%
# finding the count of observations whose hours_per_week less than upper limit

us_citizens[us_citizens.hours_per_week < lower_lim_hpw].hours_per_week.value_counts().sort_index()
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     223
# 11       9
# 12     143
# 13      19
# 14      28
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1009
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %%
# defining a dataframe from observations whose hours per week is less than lower limit of hours per week

df_hpw_lower = us_citizens[us_citizens.hours_per_week < lower_lim_hpw]
df_hpw_lower
# Out:
#        age         workclass  fnlwgt         occupation                race  \
# 1       50  Self-emp-not-inc   83311    Exec-managerial               White
# 6       49           Private  160187      Other-service               Black
# 12      23           Private  122272       Adm-clerical               White
# 21      54           Private  302146      Other-service               Black
# 34      22         State-gov  311512      Other-service               Black
# ...    ...               ...     ...                ...                 ...
# 32524   26           Private  191648  Machine-op-inspct               White
# 32544   31           Private  199655      Other-service               Other
# 32545   39         Local-gov  111499       Adm-clerical               White
# 32553   32           Private  116138       Tech-support  Asian-Pac-Islander
# 32559   22           Private  201490       Adm-clerical               White
#
# ...

# %%
# finding the statistical values of hours_per_week feature by salary for df_hpw_lower dataframe

us_citizens[us_citizens.hours_per_week < lower_lim_hpw].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4372.000 21.548 7.343 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
# finding the statistical values of age feature by salary for df_hpw_lower dataframe

us_citizens[us_citizens.hours_per_week < lower_lim_hpw].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4372.000 34.052 17.730 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %% [markdown]
# **Result :** As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, **domain knowledge** comes to the fore.
#
# **Domain Knowledge for this dataset:**
# 1. In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# 2. In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# 3. In this respect, our sample space ranges for some features are as follows.
#     - **age : 17 to 80**
#     - **hours_per_week : 7 to 70**
#     - **if somebody's age is more than 60, he/she can't work more than 60 hours in a week**

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# ### 2. Take a look at correlation between features by utilizing power of visualizing

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
