# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %%
plt.figure(figsize=(10,4), dpi=150)
sns.scatterplot(data=fandango, x="RATING", y="VOTES")
# Out:
# <AxesSubplot:xlabel='RATING', ylabel='VOTES'>

# %%
fandango.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
fandango["FILM"].str.extract("(.+\s)\((.+)\)")[1]
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2015
#        ...
# 499    2015
# 500    2015
# 501    2015
# 502    1964
# 503    2012
# Name: 1, Length: 504, dtype: object

# %%
fandango.FILM.str.extract(".+\((.+)\)").value_counts()
# Out:
# 2015    478
# 2014     23
# 1964      1
# 2012      1
# 2016      1
# dtype: int64

# %%
fandango
# Out:
#                                      FILM  STARS  RATING  VOTES  year
# 0             Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                   Jurassic World (2015)    4.5     4.5  34390  2015
# 2                  American Sniper (2015)    5.0     4.8  34085  2015
# 3                        Furious 7 (2015)    5.0     4.8  33538  2015
# 4                       Inside Out (2015)    4.5     4.5  15749  2015
# ..                                    ...    ...     ...    ...   ...
# 499                      Valiyavan (2015)    0.0     0.0      0  2015
# 500            WWE SummerSlam 2015 (2015)    0.0     0.0      0  2015
# 501       Yagavarayinum Naa Kaakka (2015)    0.0     0.0      0  2015
# 502  Yesterday, Today and Tomorrow (1964)    0.0     0.0      0  1964
# 503                         Zarafa (2012)    0.0     0.0      0  2012
#
# [504 rows x 5 columns]

# %%
fandango["year"] = fandango.FILM.str.extract(".+\((\d+)\)")

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES  year
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1        Jurassic World (2015)    4.5     4.5  34390  2015
# 2       American Sniper (2015)    5.0     4.8  34085  2015
# 3             Furious 7 (2015)    5.0     4.8  33538  2015
# 4            Inside Out (2015)    4.5     4.5  15749  2015

# %%
fandango.year.value_counts()
# Out:
# 2015    478
# 2014     23
# 2016      1
# 1964      1
# 2012      1
# Name: year, dtype: int64

# %%
sns.countplot(data=fandango, x="year");
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
fandango.iloc[fandango.VOTES.sort_values(ascending=False).index].head(10)
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
fandango.sort_values(by="VOTES", ascending=False).head(10)
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#    year
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015
# 5  2014
# 6  2015
# 7  2015
# 8  2015
# 9  2014

# %%
(fandango.VOTES==0).sum()
# Out:
# 69

# %%
fan_rev = fandango[fandango.VOTES>0]

# %%
fan_rev
# Out:
#                             FILM  STARS  RATING  VOTES  year
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1          Jurassic World (2015)    4.5     4.5  34390  2015
# 2         American Sniper (2015)    5.0     4.8  34085  2015
# 3               Furious 7 (2015)    5.0     4.8  33538  2015
# 4              Inside Out (2015)    4.5     4.5  15749  2015
# ..                           ...    ...     ...    ...   ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015
# 431            The Intern (2015)    5.0     5.0      1  2015
# 432        The Park Bench (2015)    5.0     5.0      1  2015
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015
#
# [435 rows x 5 columns]

# %%
fandango.shape
# Out:
# (504, 5)

# %%
plt.figure(figsize=(8,4), dpi=150)
sns.kdeplot(data=fan_rev, x="RATING", label="True Rating", fill=True, clip=(0,5))
sns.kdeplot(data=fan_rev, x="STARS", label="Star Displayed", fill=True, clip=(0,5))
plt.legend(loc="upper left");

# %%
fan_rev["star_diff"] = round(fan_rev["STARS"] - fan_rev["RATING"],1)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_2816/1790294776.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fan_rev["star_diff"] = round(fan_rev["STARS"] - fan_rev["RATING"],1)

# %%
# fan_rev["star_diff"] =fan_rev["star_diff"].round(2)
fan_rev.head()
# Out:
#                           FILM  STARS  RATING  VOTES  year  star_diff
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015        0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015        0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015        0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015        0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015        0.0

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.countplot(data=fan_rev, x="star_diff")
# Out:
# <AxesSubplot:xlabel='star_diff', ylabel='count'>

# %%
fan_rev[fan_rev.star_diff==1]
# Out:
#                  FILM  STARS  RATING  VOTES  year  star_diff
# 381  Turbo Kid (2015)    5.0     4.0      2  2015        1.0

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.scatterplot(data=all_sites, x="RottenTomatoes", y="RottenTomatoes_User")
# Out:
# <AxesSubplot:xlabel='RottenTomatoes', ylabel='RottenTomatoes_User'>

# %%
all_sites["Rotten_Diff"] = all_sites["RottenTomatoes"] - all_sites["RottenTomatoes_User"]

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  Rotten_Diff
# 0                271107          -12
# 1                 65709            5
# ...

# %%
all_sites["Rotten_Diff"].apply(abs).mean()
# Out:
# 15.095890410958905

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.histplot(data=all_sites, x= "Rotten_Diff", kde=True, bins=25)
# Out:
# <AxesSubplot:xlabel='Rotten_Diff', ylabel='Count'>

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.histplot(x=all_sites["Rotten_Diff"].apply(abs), kde=True, bins=25)
# Out:
# <AxesSubplot:xlabel='Rotten_Diff', ylabel='Count'>

# %%
all_sites.nsmallest(5, columns="Rotten_Diff")[["FILM","Rotten_Diff"]]  # user rating > critics
# Out:
#                           FILM  Rotten_Diff
# 3       Do You Believe? (2015)          -66
# 85           Little Boy (2015)          -61
# 105    Hitman: Agent 47 (2015)          -42
# 134    The Longest Ride (2015)          -42
# 125  The Wedding Ringer (2015)          -39

# %%
all_sites.iloc[all_sites.Rotten_Diff.apply(abs).nlargest(5).index][["FILM","Rotten_Diff"]] # all differences is gretaer
# Out:
#                         FILM  Rotten_Diff
# 3     Do You Believe? (2015)          -66
# 85         Little Boy (2015)          -61
# 69         Mr. Turner (2014)           42
# 105  Hitman: Agent 47 (2015)          -42
# 134  The Longest Ride (2015)          -42

# %%
all_sites.nlargest(5, columns="Rotten_Diff")
# Out:
#                                  FILM  RottenTomatoes  RottenTomatoes_User  \
# 69                  Mr. Turner (2014)              98                   56
# 112                 It Follows (2015)              96                   65
# 115          While We're Young (2015)              83                   52
# 37               Welcome to Me (2015)              71                   47
# 40   I'll See You In My Dreams (2015)              94                   70
#
#      Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 69           94              6.6   6.9                          98
# 112          83              7.5   6.9                         551
# 115          76              6.7   6.4                          65
# 37           67              6.9   5.9                          33
# 40           75              6.9   6.9                          14
#
#      IMDB_user_vote_count  Rotten_Diff
# 69                  13296           42
# ...

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.scatterplot(data=all_sites, x="Metacritic", y="Metacritic_User")
# Out:
# <AxesSubplot:xlabel='Metacritic', ylabel='Metacritic_User'>

# %%
plt.figure(figsize=(10,5), dpi=150)
sns.scatterplot(data=all_sites, x="Metacritic_user_vote_count", y="IMDB_user_vote_count")
# Out:
# <AxesSubplot:xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %%
all_sites.nlargest(1, "IMDB_user_vote_count")
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count  Rotten_Diff
# 14                334164           -2

# %%
all_sites.nlargest(1, "Metacritic_user_vote_count")
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count  Rotten_Diff
# 88                292023            9

# %%
fan_rev
# Out:
#                             FILM  STARS  RATING  VOTES  year  star_diff
# 0    Fifty Shades of Grey (2015)    4.0     3.9  34846  2015        0.1
# 1          Jurassic World (2015)    4.5     4.5  34390  2015        0.0
# 2         American Sniper (2015)    5.0     4.8  34085  2015        0.2
# 3               Furious 7 (2015)    5.0     4.8  33538  2015        0.2
# 4              Inside Out (2015)    4.5     4.5  15749  2015        0.0
# ..                           ...    ...     ...    ...   ...        ...
# 430       That Sugar Film (2015)    5.0     5.0      1  2015        0.0
# 431            The Intern (2015)    5.0     5.0      1  2015        0.0
# 432        The Park Bench (2015)    5.0     5.0      1  2015        0.0
# 433         The Wanted 18 (2015)    5.0     5.0      1  2015        0.0
# 434       Z For Zachariah (2015)    5.0     5.0      1  2015        0.0
#
# [435 rows x 6 columns]

# %%
all_sites
# Out:
#                                           FILM  RottenTomatoes  \
# 0               Avengers: Age of Ultron (2015)              74
# 1                            Cinderella (2015)              85
# 2                               Ant-Man (2015)              80
# 3                       Do You Believe? (2015)              18
# 4                Hot Tub Time Machine 2 (2015)              14
# ..                                         ...             ...
# 141                          Mr. Holmes (2015)              87
# 142                                 '71 (2015)              97
# 143                 Two Days, One Night (2014)              97
# 144  Gett: The Trial of Viviane Amsalem (2015)             100
# 145         Kumiko, The Treasure Hunter (2015)              87
#
#      RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                     86          66              7.1   7.8
# 1                     80          67              7.5   7.1
# ...

# %%
df= pd.merge(fandango, all_sites, on="FILM", how="inner")

# %%
df
# Out:
#                                    FILM  STARS  RATING  VOTES  year  \
# 0           Fifty Shades of Grey (2015)    4.0     3.9  34846  2015
# 1                 Jurassic World (2015)    4.5     4.5  34390  2015
# 2                American Sniper (2015)    5.0     4.8  34085  2015
# 3                      Furious 7 (2015)    5.0     4.8  33538  2015
# 4                     Inside Out (2015)    4.5     4.5  15749  2015
# ..                                  ...    ...     ...    ...   ...
# 140  Kumiko, The Treasure Hunter (2015)    3.5     3.5     41  2015
# 141  The Diary of a Teenage Girl (2015)    4.0     3.6     38  2015
# 142            The Wrecking Crew (2015)    4.5     4.2     38  2015
# 143                    Tangerine (2015)    4.0     3.9     36  2015
# 144            Maps to the Stars (2015)    3.5     3.1     35  2015
#
#      RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 145 entries, 0 to 144
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   year                        145 non-null    object
#  5   RottenTomatoes              145 non-null    int64
#  6   RottenTomatoes_User         145 non-null    int64
#  7   Metacritic                  145 non-null    int64
#  8   Metacritic_User             145 non-null    float64
#  9   IMDB                        145 non-null    float64
#  10  Metacritic_user_vote_count  145 non-null    int64
#  11  IMDB_user_vote_count        145 non-null    int64
#  12  Rotten_Diff                 145 non-null    int64
# ...

# %%
df.describe()
# Out:
#             STARS      RATING         VOTES  RottenTomatoes  \
# count  145.000000  145.000000    145.000000      145.000000
# mean     4.086207    3.841379   3817.696552       60.634483
# std      0.541169    0.502437   6368.668671       30.161098
# min      3.000000    2.700000     35.000000        5.000000
# 25%      3.500000    3.500000    218.000000       31.000000
# 50%      4.000000    3.900000   1430.000000       63.000000
# 75%      4.500000    4.200000   4279.000000       89.000000
# max      5.000000    4.800000  34846.000000      100.000000
#
#        RottenTomatoes_User  Metacritic  Metacritic_User        IMDB  \
# count           145.000000  145.000000       145.000000  145.000000
# mean             63.696552   58.696552         6.508966    6.729655
# std              19.974749   19.538183         1.510883    0.957944
# min              20.000000   13.000000         2.400000    4.000000
# 25%              50.000000   43.000000         5.700000    6.300000
# ...

# %%
df["RT_NORM"] = np.round(df["RottenTomatoes"]/20,1)
df["RTU_NORM"] = np.round(df["RottenTomatoes_User"]/20,1)

# %%
df["Meta_NORM"] = np.round(df["Metacritic"]/20,1)
df["Meta_U_NORM"] = np.round(df["Metacritic_User"]/2,1)

# %%
df["IMDB_NORM"] = np.round(df["IMDB"]/2,1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  year  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015              25
# 1        Jurassic World (2015)    4.5     4.5  34390  2015              71
# 2       American Sniper (2015)    5.0     4.8  34085  2015              72
# 3             Furious 7 (2015)    5.0     4.8  33538  2015              81
# 4            Inside Out (2015)    4.5     4.5  15749  2015              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Rotten_Diff  IMDB_NORM  \
# 0                         778                179506          -17        2.1
# ...

# %%
df.columns
# Out:
# Index(['FILM', 'STARS', 'RATING', 'VOTES', 'year', 'RottenTomatoes',
#        'RottenTomatoes_User', 'Metacritic', 'Metacritic_User', 'IMDB',
#        'Metacritic_user_vote_count', 'IMDB_user_vote_count', 'Rotten_Diff',
#        'IMDB_NORM', 'RT_NORM', 'RTU_NORM', 'Meta_NORM', 'Meta_U_NORM'],
#       dtype='object')

# %%
df_norm=df[['STARS', 'RATING','IMDB_NORM', 'RT_NORM', 'RTU_NORM', 'Meta_NORM', 'Meta_U_NORM']]

# %%
df_norm
# Out:
#      STARS  RATING  IMDB_NORM  RT_NORM  RTU_NORM  Meta_NORM  Meta_U_NORM
# 0      4.0     3.9        2.1      1.2       2.1        2.3          1.6
# 1      4.5     4.5        3.6      3.6       4.0        3.0          3.5
# 2      5.0     4.8        3.7      3.6       4.2        3.6          3.3
# 3      5.0     4.8        3.7      4.0       4.2        3.4          3.4
# 4      4.5     4.5        4.3      4.9       4.5        4.7          4.4
# ..     ...     ...        ...      ...       ...        ...          ...
# 140    3.5     3.5        3.4      4.4       3.2        3.4          3.2
# 141    4.0     3.6        3.5      4.8       4.0        4.4          3.2
# 142    4.5     4.2        3.9      4.6       4.2        3.4          3.5
# 143    4.0     3.9        3.7      4.8       4.3        4.3          3.6
# 144    3.5     3.1        3.2      3.0       2.3        3.4          2.9
#
# [145 rows x 7 columns]

# %%
sns.displot(data=df_norm, height=4, aspect=2,)

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
ax= sns.kdeplot(data=df_norm, shade=True, clip=(0,5), palette="Set1")
sns.move_legend(ax, loc="upper left")

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
ax= sns.kdeplot(data=df_norm[["RT_NORM","STARS"]], shade=True, clip=(0,5), palette="Set1")
sns.move_legend(ax, loc="upper left")

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
sns.histplot(data=df_norm)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.clustermap(df_norm, cmap="magma", figsize=(15, 15),)

# %%
df_norm.columns
# Out:
# Index(['STARS', 'RATING', 'IMDB_NORM', 'RT_NORM', 'RTU_NORM', 'Meta_NORM',
#        'Meta_U_NORM'],
#       dtype='object')

# %%
norm_film= df[["FILM",'STARS', 'RATING', 'IMDB_NORM', 'RT_NORM', 'RTU_NORM', 'Meta_NORM',
       'Meta_U_NORM']]

# %%
norm_film.head()
# Out:
#                           FILM  STARS  RATING  IMDB_NORM  RT_NORM  RTU_NORM  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9        2.1      1.2       2.1
# 1        Jurassic World (2015)    4.5     4.5        3.6      3.6       4.0
# 2       American Sniper (2015)    5.0     4.8        3.7      3.6       4.2
# 3             Furious 7 (2015)    5.0     4.8        3.7      4.0       4.2
# 4            Inside Out (2015)    4.5     4.5        4.3      4.9       4.5
#
#    Meta_NORM  Meta_U_NORM
# 0        2.3          1.6
# 1        3.0          3.5
# 2        3.6          3.3
# 3        3.4          3.4
# 4        4.7          4.4

# %%
norm_film.nsmallest(10, "RT_NORM")
# Out:
#                              FILM  STARS  RATING  IMDB_NORM  RT_NORM  \
# 49  Paul Blart: Mall Cop 2 (2015)    3.5     3.5        2.2      0.2
# 25                 Taken 3 (2015)    4.5     4.1        3.0      0.4
# 28          Fantastic Four (2015)    3.0     2.7        2.0      0.4
# 54             Hot Pursuit (2015)    4.0     3.7        2.4      0.4
# 84        Hitman: Agent 47 (2015)    4.0     3.9        3.0      0.4
# 50       The Boy Next Door (2015)    4.0     3.6        2.3      0.5
# 77             Seventh Son (2015)    3.5     3.2        2.8      0.6
# 78               Mortdecai (2015)    3.5     3.2        2.8      0.6
# 83              Sinister 2 (2015)    3.5     3.3        2.8      0.6
# 87     Unfinished Business (2015)    3.5     3.2        2.7      0.6
#
#     RTU_NORM  Meta_NORM  Meta_U_NORM
# 49       1.8        0.6          1.2
# 25       2.3        1.3          2.3
# 28       1.0        1.4          1.2
# 54       1.8        1.6          1.8
# ...

# %%
worst_fimls=norm_film.nsmallest(10, "RT_NORM")

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
ax= sns.kdeplot(data=worst_fimls, shade=True, clip=(0,5), palette="Set1")
;
# Out:
# ''

# %%
norm_film.nlargest(10, "RT_NORM")
# Out:
#                                           FILM  STARS  RATING  IMDB_NORM  \
# 23                                Selma (2014)    5.0     4.6        3.8
# 85                Shaun the Sheep Movie (2015)    4.5     4.0        3.7
# 122                            Timbuktu (2015)    4.0     3.6        3.6
# 123                             Phoenix (2015)    3.5     3.4        3.6
# 124                     Song of the Sea (2014)    4.5     4.3        4.1
# 126                           Leviathan (2014)    4.0     3.5        3.8
# 128  Gett: The Trial of Viviane Amsalem (2015)    3.5     3.5        3.9
# 139            Seymour: An Introduction (2015)    4.5     4.2        3.8
# 4                            Inside Out (2015)    4.5     4.5        4.3
# 39                           Paddington (2015)    4.5     4.3        3.6
#
#      RT_NORM  RTU_NORM  Meta_NORM  Meta_U_NORM
# 23       5.0       4.3        4.4          3.6
# 85       5.0       4.1        4.0          4.4
# ...

# %%
best_films=norm_film.nlargest(10, "RT_NORM")

# %%
fig, ax = plt.subplots(figsize=(15,6), dpi=150)
ax= sns.kdeplot(data=best_films, shade=True, clip=(0,5), palette="Set1")
;
# Out:
# ''
